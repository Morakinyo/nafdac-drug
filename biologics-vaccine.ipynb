# %%
import pandas as pd
import numpy as np

# %%
biologics_vaccine = pd.read_excel('updated-list-vaccines-biologics.xlsx', sheet_name=None, parse_dates=True)
#sheet_name=None because the excel workbook contains  several sheets.

# %%
biologics_vaccine
# Out:
# {'2015-2020':      S/N                                            PRODUCT    NAFDAC  \
#  0     67      Biosulin R Suspension for Injection Cartridge  'A6-0279
#  1    141  RotaTeq (Rotavirus Vaccine, Live, Oral, Pentav...  'A6-0397
#  2    142  Bipolio (Poliomyelitis Vaccine Live Oral Triva...  'A6-0398
#  3    143           Tetglob (tetanus Immunoglobulin Vaccine)  'A6-0046
#  4    144                                Prevenar 13 Vaccine  'A6-0117
#  ..   ...                                                ...       ...
#  183  336       INSULATARD 100IU/ML SUSPENSION FOR INJECTION  'A6-0072
#  184  337  TYPBAR VI CAPSULAR POLYSACCHARIDE TYPHOID VACCINE  'A6-0146
#  185  338  TYPBAR VI CAPSULAR POLYSACCHARIDE TYPHOID VACCINE  'A6-0446
#  186  339  HEXAXIM SUSPENSION FOR INJECTION IN PREFILED S...  'A6-0447
#  187  340                                    HERCEPTIN 150MG  'A6-0103
#
#             BRAND                                       GENERIC NAME  \
# ...

# %%
biologics_vaccine.keys() #the key method is used to show the sheetnames.
# Out:
# dict_keys(['2015-2020', '2020', '2019', '2015, 2016', '2017', '2018'])

# %%
bvm_15_20 = biologics_vaccine['2015-2020']

# %%
bvm_15_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   S/N                     188 non-null    int64
#  1   PRODUCT                 188 non-null    object
#  2   NAFDAC                  188 non-null    object
#  3   BRAND                   181 non-null    object
#  4   GENERIC NAME            187 non-null    object
#  5   PRODUCT CATEGORY        186 non-null    object
#  6   PHARM CLASS             188 non-null    object
#  7   ROUTE OF ADMINITRATION  188 non-null    object
#  8   GROUP                   188 non-null    object
#  9   ACTIVE INGREDIENT       188 non-null    object
#  10  STRENGTH                188 non-null    object
#  11  PRESENTATION            185 non-null    object
#  12  DOSAGE                  185 non-null    object
#  13  PACK SIZE               188 non-null    object
# ...

# %%
bvm = bvm_15_20.drop(bvm_15_20.columns[[17,18,22,23,28,29,30,31,32,33,34]], axis=1)

# %%
bvm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   S/N                     188 non-null    int64
#  1   PRODUCT                 188 non-null    object
#  2   NAFDAC                  188 non-null    object
#  3   BRAND                   181 non-null    object
#  4   GENERIC NAME            187 non-null    object
#  5   PRODUCT CATEGORY        186 non-null    object
#  6   PHARM CLASS             188 non-null    object
#  7   ROUTE OF ADMINITRATION  188 non-null    object
#  8   GROUP                   188 non-null    object
#  9   ACTIVE INGREDIENT       188 non-null    object
#  10  STRENGTH                188 non-null    object
#  11  PRESENTATION            185 non-null    object
#  12  DOSAGE                  185 non-null    object
#  13  PACK SIZE               188 non-null    object
# ...

# %%
bvm.rename(columns={'ROUTE OF ADMINITRATION':'ROUTE OF ADMINISTRATION'}, inplace=True)

# %%
bvm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   S/N                      188 non-null    int64
#  1   PRODUCT                  188 non-null    object
#  2   NAFDAC                   188 non-null    object
#  3   BRAND                    181 non-null    object
#  4   GENERIC NAME             187 non-null    object
#  5   PRODUCT CATEGORY         186 non-null    object
#  6   PHARM CLASS              188 non-null    object
#  7   ROUTE OF ADMINISTRATION  188 non-null    object
#  8   GROUP                    188 non-null    object
#  9   ACTIVE INGREDIENT        188 non-null    object
#  10  STRENGTH                 188 non-null    object
#  11  PRESENTATION             185 non-null    object
#  12  DOSAGE                   185 non-null    object
#  13  PACK SIZE                188 non-null    object
# ...

# %%
# %run null_values.py

# %%
nullcols(bvm)
# Out:
# BRAND               7
# GENERIC NAME        1
# PRODUCT CATEGORY    2
# PRESENTATION        3
# DOSAGE              3
# INDICATION          5
# dtype: int64

# %%
brand = bvm[bvm['BRAND'].isnull()]

# %%
brand
# Out:
#      S/N                                            PRODUCT    NAFDAC BRAND  \
# 48   190              R2B STRAIN (RANIKHET DISEASE) VACCINE  'A6-0364   NaN
# 111  258     ITA-NEW (ND) INACTIVATED, OIL EMULSION VACCINE  'A6-0500   NaN
# 112  259         ITA ND+IB INACTIVATED OIL EMULSION VACCINE  'A6-0501   NaN
# 113  260  ITA ND+IB + EDS INACTIVATED, OIL EMULSION VACCINE  'A6-0502   NaN
# 142  290              NEWCASTLE DISEASE, R2B STRAIN, LIVING  'A6-0518   NaN
# 143  291                    MAREK'S DISEASE VACCINE, LIVING  'A6-0519   NaN
# 160  313                                    MEASLES VACCINE  'A6-0487   NaN
#
#                                           GENERIC NAME    PRODUCT CATEGORY  \
# 48                NEWCASTLE DISEASE (RANIKHET) VACCINE             VACCINE
# 111  INACTIVATED, OIL EMULSION VACCINE AGAINST NEWC...  VETERINARY VACCINE
# 112  ITA ND+IB INACTIVATED OIL EMULSION VACCINE AGA...     POULTRY VACCINE
# ...

# %%
bvm.sample(n=5, random_state=42)
# Out:
#      S/N                                        PRODUCT    NAFDAC       BRAND  \
# 183  336   INSULATARD 100IU/ML SUSPENSION FOR INJECTION  'A6-0072  INSULATARD
# 162  315                        MENOGON 75 IU INJECTION  'A6-0220     MENOGON
# 18   160          RECOMBIVAX (HEPATITIS B VACCINE) VIAL  'A6-0406  RECOMBIVAX
# 15   155  Biosulin N Suspension for Injection Cartridge  'A6-0278  Biosulin N
# 67   209                                NEMOVAC VACCINE  'A6-0453     NEMOVAC
#
#                                      GENERIC NAME PRODUCT CATEGORY  \
# 183                         INSULIN HUMAN (r DNA)        BIOLOGICS
# 162  HUMAN MENOPAUSAL GONADOTROPHIN FOR INJECTION        BIOLOGICS
# 18                            HEPATITIS B VACCINE          VACCINE
# 15                                  HUMAN INSULIN        BIOLOGICS
# 67                  LIVE PNEUMOVIRUS PL 21 STRAIN          VACCINE
#
#          PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# ...

# %%
vaccine_biologics = bvm.fillna('No values') 
#to identify the null values because the astype would render as string later and null values won't render as null.

# %%
vaccine_biologics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   S/N                      188 non-null    int64
#  1   PRODUCT                  188 non-null    object
#  2   NAFDAC                   188 non-null    object
#  3   BRAND                    188 non-null    object
#  4   GENERIC NAME             188 non-null    object
#  5   PRODUCT CATEGORY         188 non-null    object
#  6   PHARM CLASS              188 non-null    object
#  7   ROUTE OF ADMINISTRATION  188 non-null    object
#  8   GROUP                    188 non-null    object
#  9   ACTIVE INGREDIENT        188 non-null    object
#  10  STRENGTH                 188 non-null    object
#  11  PRESENTATION             188 non-null    object
#  12  DOSAGE                   188 non-null    object
#  13  PACK SIZE                188 non-null    object
# ...

# %%
vaccine_biologics_2 = vaccine_biologics.apply(lambda x: x.astype(str).str.upper())

# %%
vaccine_biologics_2.sample(n=5, random_state=42)
# Out:
#      S/N                                        PRODUCT    NAFDAC       BRAND  \
# 183  336   INSULATARD 100IU/ML SUSPENSION FOR INJECTION  'A6-0072  INSULATARD
# 162  315                        MENOGON 75 IU INJECTION  'A6-0220     MENOGON
# 18   160          RECOMBIVAX (HEPATITIS B VACCINE) VIAL  'A6-0406  RECOMBIVAX
# 15   155  BIOSULIN N SUSPENSION FOR INJECTION CARTRIDGE  'A6-0278  BIOSULIN N
# 67   209                                NEMOVAC VACCINE  'A6-0453     NEMOVAC
#
#                                      GENERIC NAME PRODUCT CATEGORY  \
# 183                         INSULIN HUMAN (R DNA)        BIOLOGICS
# 162  HUMAN MENOPAUSAL GONADOTROPHIN FOR INJECTION        BIOLOGICS
# 18                            HEPATITIS B VACCINE          VACCINE
# 15                                  HUMAN INSULIN        BIOLOGICS
# 67                  LIVE PNEUMOVIRUS PL 21 STRAIN          VACCINE
#
#          PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# ...

# %%
vaccine_biologics_2.replace(['NO VALUES'], np.nan, inplace=True)

# %%
nullcols(vaccine_biologics_2)
# Out:
# BRAND               7
# GENERIC NAME        1
# PRODUCT CATEGORY    2
# PRESENTATION        3
# DOSAGE              3
# INDICATION          5
# dtype: int64

# %%
vaccine_biologics_2.iloc[[48, 111, 112, 113, 142]]
# Out:
#      S/N                                            PRODUCT    NAFDAC BRAND  \
# 48   190              R2B STRAIN (RANIKHET DISEASE) VACCINE  'A6-0364   NaN
# 111  258     ITA-NEW (ND) INACTIVATED, OIL EMULSION VACCINE  'A6-0500   NaN
# 112  259         ITA ND+IB INACTIVATED OIL EMULSION VACCINE  'A6-0501   NaN
# 113  260  ITA ND+IB + EDS INACTIVATED, OIL EMULSION VACCINE  'A6-0502   NaN
# 142  290              NEWCASTLE DISEASE, R2B STRAIN, LIVING  'A6-0518   NaN
#
#                                           GENERIC NAME    PRODUCT CATEGORY  \
# 48                NEWCASTLE DISEASE (RANIKHET) VACCINE             VACCINE
# 111  INACTIVATED, OIL EMULSION VACCINE AGAINST NEWC...  VETERINARY VACCINE
# 112  ITA ND+IB INACTIVATED OIL EMULSION VACCINE AGA...     POULTRY VACCINE
# 113  ITA ND+IB + EDS INACTIVATED, OIL EMULSION VACC...     POULTRY VACCINE
# 142               NEWCASTLE DISEASE, R2B STRAIN LIVING  VETERINARY VACCINE
#
#       PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# ...

# %%
vaccine_biologics_2['NAFDAC'] = vaccine_biologics_2['NAFDAC'].replace('\'', '', regex=True)

# %%
vaccine_biologics_2.sample(n=5, random_state=42)
# Out:
#      S/N                                        PRODUCT   NAFDAC       BRAND  \
# 183  336   INSULATARD 100IU/ML SUSPENSION FOR INJECTION  A6-0072  INSULATARD
# 162  315                        MENOGON 75 IU INJECTION  A6-0220     MENOGON
# 18   160          RECOMBIVAX (HEPATITIS B VACCINE) VIAL  A6-0406  RECOMBIVAX
# 15   155  BIOSULIN N SUSPENSION FOR INJECTION CARTRIDGE  A6-0278  BIOSULIN N
# 67   209                                NEMOVAC VACCINE  A6-0453     NEMOVAC
#
#                                      GENERIC NAME PRODUCT CATEGORY  \
# 183                         INSULIN HUMAN (R DNA)        BIOLOGICS
# 162  HUMAN MENOPAUSAL GONADOTROPHIN FOR INJECTION        BIOLOGICS
# 18                            HEPATITIS B VACCINE          VACCINE
# 15                                  HUMAN INSULIN        BIOLOGICS
# 67                  LIVE PNEUMOVIRUS PL 21 STRAIN          VACCINE
#
#          PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# ...

# %%
prodCat = vaccine_biologics_2['PRODUCT CATEGORY']

# %%
prodCat
# Out:
# 0      BIOLOGICS
# 1        VACCINE
# 2        VACCINE
# 3        VACCINE
# 4        VACCINE
#          ...
# 183    BIOLOGICS
# 184      VACCINE
# 185      VACCINE
# 186      VACCINE
# 187    BIOLOGICS
# Name: PRODUCT CATEGORY, Length: 188, dtype: object

# %%
# %run trimming.py

# %%
# %whos
# Out:
# Variable              Type         Data/Info
# --------------------------------------------
# biologics_vaccine     dict         n=6
# brand                 DataFrame         S/N                 <...>\n\n[7 rows x 24 columns]
# bvm                   DataFrame         S/N                 <...>\n[188 rows x 24 columns]
# bvm_15_20             DataFrame         S/N                 <...>\n[188 rows x 35 columns]
# nans                  function     <function nans at 0x00000203AE5754C0>
# np                    module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# nullcols              function     <function nullcols at 0x00000203AE575160>
# nullqty               function     <function nullqty at 0x00000203AE5751F0>
# pd                    module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# prodCat               Series       0      BIOLOGICS\n1      <...>ength: 188, dtype: object
# ...

# %%
bvm_2 = trim_all_columns(vaccine_biologics_2)

# %%
prodCat2 = bvm_2['PRODUCT CATEGORY'].unique()

# %%
prodCat2
# Out:
# array(['BIOLOGICS', 'VACCINE', 'VETERINARY VACCINE', 'POULTRY VACCINE',
#        'VETERANRY VACCINE', nan], dtype=object)

# %%
bvm_2['PRODUCT CATEGORY'].replace({'VETERANRY VACCINE':'VETERINARY VACCINE'}, inplace=True)

# %%
prodCat3 = bvm_2['PRODUCT CATEGORY'].unique()

# %%
prodCat3
# Out:
# array(['BIOLOGICS', 'VACCINE', 'VETERINARY VACCINE', 'POULTRY VACCINE',
#        nan], dtype=object)

# %%
no_ProdCat = bvm_2.loc[bvm_2['PRODUCT CATEGORY'].isnull(),:]

# %%
no_prodCat
# Out:
#      S/N                         PRODUCT   NAFDAC     BRAND GENERIC NAME  \
# 164  317            ACTILYSE 50MG POWDER  A6-0592  ACTILYSE    ALTEPLASE
# 173  326  SHAN5 VACCINE SINGLE DOSE VIAL  A6-0442     SHAN5      VACCINE
#
#     PRODUCT CATEGORY    PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 164              NaN  HUMAN VACCINE              PARENTERAL   BVM
# 173              NaN        VACCINE              PARENTERAL   BVM
#
#                                      ACTIVE INGREDIENT  ...  \
# 164                                          ALTEPLASE  ...
# 173  DIPHTHERIA TOXOID, TETANUS TOXOID, B. PERTUSSI...  ...
#
#              MARKETING CATEGORY  \
# 164  PRESCRIPTION ONLY MEDICINE
# 173  PRESCRIPTION ONLY MEDICINE
#
#                                             INDICATION  \
# 164  FIBRINOLYTIC TREATMENT OF ACCUTE ISCHAEMIC STROKE
# 173  ACTIVE IMMUNIZATION OF INFANTS AGAINST DIPHTHE...
#
#                          NAME OF APPLICANT  \
# ...

# %%
no_Generic = bvm_2.loc[bvm_2['GENERIC NAME'].isnull(),:]

# %%
no_Generic
# Out:
#     S/N                               PRODUCT   NAFDAC              BRAND  \
# 34  176  TETRAVALENT -LCHP VETERINARY VACCINE  A6-0418  TETRAVALENT -LCHP
#
#    GENERIC NAME    PRODUCT CATEGORY   PHARM CLASS ROUTE OF ADMINISTRATION  \
# 34          NaN  VETERINARY VACCINE  PROPHYLACTIC              PARENTERAL
#
#    GROUP                                  ACTIVE INGREDIENT  ...  \
# 34   BVM  CANINE DISTEMPER VIRUS CDV/WHO-134 STRAIN 10, ...  ...
#
#             MARKETING CATEGORY  \
# 34  PRESCRIPTION ONLY MEDICINE
#
#                                            INDICATION  \
# 34  ACTIVE IMMUNIZATION AGAINST CANINE DISTEMPER, ...
#
#                    NAME OF APPLICANT  \
# 34  CHROMOGENE INTERNATIONAL LIMITED
#
#                                     APPLICANT ADDRESS APPLICANT COUNTRY  \
# 34  5TH FLOOR, WING B ELEPHANT HOUSE, CBD, ALAUSA,...           NIGERIA
#
#       MANUFACTURER                                       MAN. ADDRESS  \
# ...

# %%
no_Brand = bvm_2.loc[bvm_2['BRAND'].isnull(),:]

# %%
no_Brand
# Out:
#      S/N                                            PRODUCT   NAFDAC BRAND  \
# 48   190              R2B STRAIN (RANIKHET DISEASE) VACCINE  A6-0364   NaN
# 111  258     ITA-NEW (ND) INACTIVATED, OIL EMULSION VACCINE  A6-0500   NaN
# 112  259         ITA ND+IB INACTIVATED OIL EMULSION VACCINE  A6-0501   NaN
# 113  260  ITA ND+IB + EDS INACTIVATED, OIL EMULSION VACCINE  A6-0502   NaN
# 142  290              NEWCASTLE DISEASE, R2B STRAIN, LIVING  A6-0518   NaN
# 143  291                    MAREK'S DISEASE VACCINE, LIVING  A6-0519   NaN
# 160  313                                    MEASLES VACCINE  A6-0487   NaN
#
#                                           GENERIC NAME    PRODUCT CATEGORY  \
# 48                NEWCASTLE DISEASE (RANIKHET) VACCINE             VACCINE
# 111  INACTIVATED, OIL EMULSION VACCINE AGAINST NEWC...  VETERINARY VACCINE
# 112  ITA ND+IB INACTIVATED OIL EMULSION VACCINE AGA...     POULTRY VACCINE
# ...

# %%
no_Presentation = bvm_2.loc[bvm_2['PRESENTATION'].isnull(),:]

# %%
no_Presentation
# Out:
#     S/N                              PRODUCT   NAFDAC    BRAND  \
# 26  168  GONAL-F INJECTION PREFILLED SYRINGE  A6-0410  GONAL-F
# 27  169  GONAL-F INJECTION PREFILLED SYRINGE  A6-0411  GONAL-F
# 28  170  GONAL-F INJECTION PREFILLED SYRINGE  A6-0412  GONAL-F
#
#                                          GENERIC NAME PRODUCT CATEGORY  \
# 26  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...        BIOLOGICS
# 27  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...        BIOLOGICS
# 28  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...        BIOLOGICS
#
#        PHARM CLASS ROUTE OF ADMINISTRATION GROUP ACTIVE INGREDIENT  ...  \
# 26  GONADOTROPHINS              PARENTERAL   BVM  FOLLITROPIN ALFA  ...
# 27  GONADOTROPHINS              PARENTERAL   BVM  FOLLITROPIN ALFA  ...
# 28  GONADOTROPHINS              PARENTERAL   BVM  FOLLITROPIN ALFA  ...
#
#             MARKETING CATEGORY INDICATION  \
# 26  PRESCRIPTION ONLY MEDICINE        NaN
# 27  PRESCRIPTION ONLY MEDICINE        NaN
# ...

# %%
no_Dosage = bvm_2.loc[bvm_2['DOSAGE'].isnull(),:]

# %%
no_Dosage
# Out:
#     S/N                              PRODUCT   NAFDAC    BRAND  \
# 26  168  GONAL-F INJECTION PREFILLED SYRINGE  A6-0410  GONAL-F
# 27  169  GONAL-F INJECTION PREFILLED SYRINGE  A6-0411  GONAL-F
# 28  170  GONAL-F INJECTION PREFILLED SYRINGE  A6-0412  GONAL-F
#
#                                          GENERIC NAME PRODUCT CATEGORY  \
# 26  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...        BIOLOGICS
# 27  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...        BIOLOGICS
# 28  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...        BIOLOGICS
#
#        PHARM CLASS ROUTE OF ADMINISTRATION GROUP ACTIVE INGREDIENT  ...  \
# 26  GONADOTROPHINS              PARENTERAL   BVM  FOLLITROPIN ALFA  ...
# 27  GONADOTROPHINS              PARENTERAL   BVM  FOLLITROPIN ALFA  ...
# 28  GONADOTROPHINS              PARENTERAL   BVM  FOLLITROPIN ALFA  ...
#
#             MARKETING CATEGORY INDICATION  \
# 26  PRESCRIPTION ONLY MEDICINE        NaN
# 27  PRESCRIPTION ONLY MEDICINE        NaN
# ...

# %%
no_Indication = bvm_2.loc[bvm_2['INDICATION'].isnull(),:]

# %%
no_Indication
# Out:
#      S/N                                            PRODUCT   NAFDAC  \
# 26   168                GONAL-F INJECTION PREFILLED SYRINGE  A6-0410
# 27   169                GONAL-F INJECTION PREFILLED SYRINGE  A6-0411
# 28   170                GONAL-F INJECTION PREFILLED SYRINGE  A6-0412
# 29   171          VITASULIN N SUSPENSION FOR INJECTION VIAL  A6-0413
# 165  318  ESPOGEN PREFILLED INJECTION (RH ERYTHROPOIETIN...  A6-0593
#
#            BRAND                                       GENERIC NAME  \
# 26       GONAL-F  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...
# 27       GONAL-F  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...
# 28       GONAL-F  RECOMBINANT HUMAN FOLLICLE STIMULATING HORMONE...
# 29   VITASULIN N                                      HUMAN INSULIN
# 165      ESPOGEN                                  RH ERYTHROPOIETIN
#
#     PRODUCT CATEGORY                        PHARM CLASS  \
# 26         BIOLOGICS                     GONADOTROPHINS
# ...

# %%
with pd.ExcelWriter('cleaning_bvm2015-2020.xlsx') as writer1:
    no_Brand.to_excel(writer1, sheet_name='missing-brand-name')
    no_Generic.to_excel(writer1, sheet_name='missing-generic-name')
    no_ProdCat.to_excel(writer1, sheet_name='missing-product-category')
    no_Presentation.to_excel(writer1, sheet_name='missing-presentation')
    no_Dosage.to_excel(writer1, sheet_name='missing-dosage')
    no_Indication.to_excel(writer1, sheet_name='missing-indication')

# %%
pharmclass = bvm_2['PHARM CLASS'].unique()

# %%
pharmclass
# Out:
# array(['ANTIDIABETIC', 'PROPHYLACTIC', 'GONADOTROPHINS',
#        'ERYTHROPOIESIS-STIMULATING AGENTS', 'MONOCLONAL ANTIBODY',
#        'GRANULOCYTE COLONY STIMULATING FACTOR', 'ANTINEOPLASTIC',
#        'ANTITHROMBOTIC', 'IMMUNOSUPPRESSANT', 'ANTIVIRAL',
#        'ANTICOAGULANT', 'ANIMAL VACCINE', 'ANTICANCER',
#        'VOLUMEN EXPANDER', 'IMMUNOSUPPRESANT', 'ANTIRABIES',
#        'IMMUNOGLOBULIN', 'ANTI-LYMPHOCYTE MONOCLONAL ANTIBODIES',
#        'CYTOKINE MODULATOR', 'ANTI-NEOPLATISTIC',
#        'HUMAN MENOPAUSAL GONADOTROPHINS', 'VETERINARY VACCINE',
#        'ANTI-DIABETIC', 'ANT-INFERTILITY', 'HUMAN VACCINE',
#        'CHORIONIC GONADOTROPIN', 'HUMAN GLYCOPROTEIN HORMONE', 'VACCINE',
#        'GROWTH HORMONE', 'BIOLOGICS', 'ANTINEOPLASTIC AGENT'],
#       dtype=object)

# %%
bvm_2['PHARM CLASS'].replace({'GONADOTROPHINS':'GONADOTROPINS', 'HUMAN MENOPAUSAL GONADOTROPHINS':'HUMAN MENOPAUSAL GONADOTROPINS'}, inplace=True)

# %%
pharmclass2 = bvm_2['PHARM CLASS'].unique()

# %%
pharmclass2
# Out:
# array(['ANTIDIABETIC', 'PROPHYLACTIC', 'GONADOTROPINS',
#        'ERYTHROPOIESIS-STIMULATING AGENTS', 'MONOCLONAL ANTIBODY',
#        'GRANULOCYTE COLONY STIMULATING FACTOR', 'ANTINEOPLASTIC',
#        'ANTITHROMBOTIC', 'IMMUNOSUPPRESSANT', 'ANTIVIRAL',
#        'ANTICOAGULANT', 'ANIMAL VACCINE', 'ANTICANCER',
#        'VOLUMEN EXPANDER', 'IMMUNOSUPPRESANT', 'ANTIRABIES',
#        'IMMUNOGLOBULIN', 'ANTI-LYMPHOCYTE MONOCLONAL ANTIBODIES',
#        'CYTOKINE MODULATOR', 'ANTI-NEOPLATISTIC',
#        'HUMAN MENOPAUSAL GONADOTROPINS', 'VETERINARY VACCINE',
#        'ANTI-DIABETIC', 'ANT-INFERTILITY', 'HUMAN VACCINE',
#        'CHORIONIC GONADOTROPIN', 'HUMAN GLYCOPROTEIN HORMONE', 'VACCINE',
#        'GROWTH HORMONE', 'BIOLOGICS', 'ANTINEOPLASTIC AGENT'],
#       dtype=object)
