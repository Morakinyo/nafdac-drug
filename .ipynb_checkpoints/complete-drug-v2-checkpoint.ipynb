# %%
import pandas as pd
import numpy as np

# %%
drug = pd.read_excel('new-drug.xlsx', index_col=0)

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         4631 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5844 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
drug.shape
# Out:
# (5854, 23)

# %%
category = drug['PRODUCT CATEGORY'].value_counts()

# %%
category
# Out:
# HUMAN DRUG    4631
# Name: PRODUCT CATEGORY, dtype: int64

# %%
updated_df = drug

# %%
drug['PRODUCT CATEGORY'].unique()
# Out:
# array(['HUMAN DRUG', nan], dtype=object)

# %%
len(drug['PRODUCT CATEGORY'].isnull())
# Out:
# 5854

# %%
null_prodCat = drug.loc[drug['PRODUCT CATEGORY'].isnull(),:]

# %%
null_prodCat
# Out:
#                                  PRODUCT NAME   NAFDAC        BRAND  \
# 1867                         REAMOTIL TABLETS  B4-9282     REAMOTIL
# 1868                         KALMANOL TABLETS  B4-9260     KALMANOL
# 1869                SAM GLIMEPIRIDE 2 TABLETS  B4-9248          SAM
# 1870  SAM CYPROHEPTADINE & MULTIVITAMIN SYRUP  B4-9303          SAM
# 1871          SD DICLOFENAC POTASSIUM TABLETS  B4-9285           SD
# ...                                       ...      ...          ...
# 3089                                   ALUVIA  A4-1004       ALUVIA
# 3090                               TOPAMAX 25  B4-8211      TOPAMAX
# 3091                               TOPAMAX 50  B4-8212      TOPAMAX
# 3092                      WELLMAN 50+ TABLETS  A4-7491      WELLMAN
# 3093                      KOALA MULTI TABLETS  B4-9058  KOALA MULTI
#
#                           GENERICS PRODUCT CATEGORY  \
# 1867           DOMPERIDONE MALEATE              NaN
# ...

# %%
drug.loc[drug['PRODUCT CATEGORY'].isnull(), 'PRODUCT CATEGORY']='HUMAN DRUG'

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5844 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
updated_df = drug

# %%
null_Group = drug.loc[drug['GROUP'].isnull(),:]

# %%
len(null_Group)
# Out:
# 10

# %%
null_Group
# Out:
#                                    PRODUCT NAME   NAFDAC      BRAND  \
# 2431            FECCOX METOCLOPRAMIDE INJECTION  B4-8491     FECCOX
# 2902                     PENTABETA-30 INJECTION  A4-8361  PENTABETA
# 2908  LOSARTAN POTASSIUM AND AMLODIPINE TABLETS  B4-9077  UNBRANDED
# 3062                             AMINODYN SYRUP  A4-6885   AMINODYN
# 3197                         DICLOWIN INJECTION  A4-7921   DICLOWIN
# 3205                           NUCARD 80 TABLET  B4-9622     NUCARD
# 3539                          MIDOZOL EYE DROPS  B4-9608    MIDOZOL
# 3583                    ARAMAC FORTE 550 TABLET  B4-9662     ARAMAC
# 3638                            FLUEZZE TABLETS  B4-9729    FLUEZZE
# 3736          EPOCOD 300 COD LIVER OIL CAPSULES  A4-9199     EPOCOD
#
#                                      GENERICS PRODUCT CATEGORY  \
# 2431                           METOCLOPRAMIDE       HUMAN DRUG
# 2902                              PENTAZOCINE       HUMAN DRUG
# ...

# %%
drug.fillna({"GROUP":"DRUG"}, inplace=True)

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
updated_df = drug

# %%
null_Dose = drug.loc[drug['DOSAGE FORM'].isnull(), :]

# %%
len(null_Dose)
# Out:
# 8

# %%
null_Dose
# Out:
#                            PRODUCT NAME   NAFDAC          BRAND  \
# 293   CHIMEXBON GENTAMICIN EYE/EAR DROP  B4-6687      CHIMEXBON
# 631               CEFUNAT 250MG TABLETS  04-5298  CEFUNAT 250MG
# 632                       JADURON TONIC  A4-3457        JADURON
# 869                       BRUXINE 50GMS  04-3514        BRUXINE
# 870              VAMI'S VITAMINS POWDER  04-8310         VAMI'S
# 1744                           GENPAYNE  B4-6775       GENPAYNE
# 2474                   SALBUTAMOL 100MG  B4-8493      UNBRANDED
# 3780                   CELOPRO CAPSULES  B4-9895        CELOPRO
#
#                                            GENERICS PRODUCT CATEGORY  \
# 293                                      GENTAMICIN       HUMAN DRUG
# 631                               CEFUROXIME AXETIL       HUMAN DRUG
# 632                 FERRIC AMMONIUM CITRATE USP ETC       HUMAN DRUG
# 869                                  OXYTETACYCLINE       HUMAN DRUG
# ...

# %%
pd.set_option('display.max_column', None)

# %%
null_Applicant = drug.loc[drug['NAME OF APPLICANT'].isnull(), :]

# %%
len(null_Applicant)
# Out:
# 23

# %%
null_Applicant
# Out:
#                                           PRODUCT NAME    NAFDAC  \
# 633                                   JADURON CAPSULES   A4-4061
# 1348  BIORAJ PARACETAMOL & DICLOFENAC POTASSIUM TABLET  A11-0323
# 1349                              JAWALK ORAL SOLUTION  A11-0138
# 1350                                    PECRITON SYRUP  A11-0325
# 1351                                   GARYLONG TABLET   B4-3550
# 1352     ANNMOX AMOXICILLIN POWDER FOR ORAL SUSPENSION  A11-0326
# 1353                                     MOBITIN SYRUP  A11-0115
# 1354                                 MYZITH 500 TABLET  A11-0327
# 1355                                    VARSPAR TABLET   A4-5476
# 1356                                      NESTIN CREAM   04-6365
# 1357                                    VARSPAR TABLET   A4-5475
# 1358                                   BOND CPM TABLET   04-0490
# 1359                                IRON BOND IB TONIC   04-1833
# ...

# %%
null_Route = drug.loc[drug['ROUTE OF ADMINISTRATION'].isnull(), :]

# %%
len(null_Route)
# Out:
# 1

# %%
null_Route
# Out:
#                            PRODUCT NAME   NAFDAC   BRAND          GENERICS  \
# 2637  JANIFY PROMETHAZINE HCL INJECTION  B4-9137  JANIFY  PROMETHAZINE HCL
#
#      PRODUCT CATEGORY   PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 2637       HUMAN DRUG  ANTI- EMETIC                     NaN  DRUG
#
#                       ACTIVE ING   STRENGTH                PRESENTATION  \
# 2637  PROMETHAZINE HCL 50MG/ 2ML  50MG/ 2ML  INJECTION/AMPOULE 2ML X 10
#
#      DOSAGE FORM PACK SIZE          MARKETING CATEGORY   APPROVED INDICATION  \
# 2637   INJECTION  2ML X 10  PRESCRIPTION ONLY MEDICINE  MANAGEMENT OF EMESIS
#
#          NAME OF APPLICANT                         APPLICANT ADDRESS  COUNTRY  \
# 2637  JANIFY PHARM CO. LTD  2, ADESOYE STREET, MANDA MARYLAND, LAGOS  NIGERIA
#
#                                    NAME OF MANUFACTURER  \
# 2637  TIANJIN KINGYORK GROUP HUBEI TIANYAO PHARMACEU...
#
#                                    MANUFACTURER ADDRESS COUNTRY.1  \
# ...

# %%
null_Strength = drug.loc[drug['STRENGTH'].isnull(), :]

# %%
len(null_Strength)
# Out:
# 130

# %%
null_Strength
# Out:
#                                            PRODUCT NAME    NAFDAC      BRAND  \
# 19                           CHEWABLE VIT A,C,D3 TABLET  A11-0280  UNBRANDED
# 103                                   NUEL YEAST TABLET  A11-0124       NUEL
# 278                                  GINOFORCE CAPSULES   B4-6634  GINOFORCE
# 281                                  PREGNAFIT CAPSULES   B4-6637  PREGNAFIT
# 284                                    VERAGIN CAPSULES   A4-4579    VERAGIN
# ...                                                 ...       ...        ...
# 5678                             GASCOL CHEWABLE TABLET   A4-9254     GASCOL
# 5790                     DETTOL ANTISEPTIC DISINFECTANT   04-2487     DETTOL
# 5840                  DONISTREP LOZENGES (MINT FLAVOUR)  A4-4479L  DONISTREP
# 5847                                 AYRTONS CASTOR OIL   B4-1365    AYRTONS
# 5848  MULTISENG MULTIVITAMIN & MINERALS CAPSULES WIT...   B4-5036  MULTISENG
#
# ...

# %%
null_Presentation = drug.loc[drug['PRESENTATION'].isnull(), :]

# %%
len(null_Presentation)
# Out:
# 26

# %%
null_Presentation
# Out:
#                               PRODUCT NAME    NAFDAC          BRAND  \
# 631                  CEFUNAT 250MG TABLETS   04-5298  CEFUNAT 250MG
# 632                          JADURON TONIC   A4-3457        JADURON
# 714                        AMCIN INJECTION   B4-6216          AMCIN
# 763                    FRAFENAC 50 CAPSULE   A4-2688    FRAFENAC 50
# 836                   CRESTOR 40MG TABLETS   A4-5405   CRESTOR 40MG
# 837                       RADOFLOX TABLETS   A4-3914       RADOFLOX
# 869                          BRUXINE 50GMS   04-3514        BRUXINE
# 870                 VAMI'S VITAMINS POWDER   04-8310         VAMI'S
# 1744                              GENPAYNE   B4-6775       GENPAYNE
# 1777  OMEPRAZOLE DELAYED-RELEASED CAPSULES   B4-9447      UNBRANDED
# 1827  EMPROFEN IBUPROFEN SOFTGELS CAPSULES   A4-9467       EMPROFEN
# 2153           MEDLEY ATORVASTATIN TABLETS   B4-8186         MEDLEY
# 3237                         CINEX TABLETS   B4-9640          CINEX
# ...

# %%
null_Packsize = drug.loc[drug['PACK SIZE'].isnull(), :]

# %%
len(null_Packsize)
# Out:
# 12

# %%
null_Packsize
# Out:
#                                   PRODUCT NAME    NAFDAC         BRAND  \
# 279   SOFTHEALTH COD LIVER OIL CAPSULES 1000MG   B4-6635    SOFTHEALTH
# 731                           CETIL 250 TABLET   B4-6259     CETIL 250
# 844                        EGLOFEDIPINE TABLET   B4-6269  EGLOFEDIPINE
# 845                         ODASOL-20 CAPSULES   B4-6270     ODASOL-20
# 1057                  BEXALOL STERILE EYE DROP   B4-7090       BEXALOL
# 2368    BIRON-12 HAEMATINIC WITH VITAMIN SYRUP  A11-0666      BIRON-12
# 3039                        NOVACAN-50 TABLETS   04-7690       NOVACAN
# 3196             WOODS' PEPPERMINT EXPECTORANT   B4-9628        WOODS'
# 3780                          CELOPRO CAPSULES   B4-9895       CELOPRO
# 4861                        OMEPRAZOLE CAPSULE   C4-0135    OMEPRAZOLE
# 4862       MAYATEO DICLOFENAC POTASSIUM TABLET   C4-0136       MAYATEO
# 4863                  MAYANIL PROGUANIL TABLET   C4-0137       MAYANIL
#
# ...

# %%
null_MC = drug.loc[drug['MARKETING CATEGORY'].isnull(), :]

# %%
len(null_MC)
# Out:
# 1

# %%
null_MC
# Out:
#                PRODUCT NAME   NAFDAC           BRAND  \
# 1683  SHREE MANSIFED TABLET  B4-6719  SHREE MANSIFED
#
#                       GENERICS PRODUCT CATEGORY     PHARM CLASS  \
# 1683  CHLORPHENIRAMINE MALEATE       HUMAN DRUG  ANTI HISTAMINE
#
#      ROUTE OF ADMINISTRATION  GROUP                ACTIVE ING STRENGTH  \
# 1683                    ORAL  DRUGS  CHLORPHENIRAMINE MALEATE      4MG
#
#           PRESENTATION DOSAGE FORM PACK SIZE MARKETING CATEGORY  \
# 1683  TABLETS, 10 X 10     TABLETS   10 X 10                NaN
#
#                 APPROVED INDICATION        NAME OF APPLICANT  \
# 1683  RELIEF OF ALLERGIC CONDITIONS  SHREE ALOE PHARM CO LTD
#
#                                       APPLICANT ADDRESS  COUNTRY  \
# 1683  F46, NWANGENE STREET HOUSING ESTATE FEGGE ONIT...  NIGERIA
#
#        NAME OF MANUFACTURER  \
# 1683  IMPUSLE PHARM PVT LTD
#
#                                    MANUFACTURER ADDRESS COUNTRY.1  \
# ...

# %%
null_ApprovedIndication = drug.loc[drug['APPROVED INDICATION'].isnull(), :]

# %%
len(null_ApprovedIndication)
# Out:
# 2

# %%
null_ApprovedIndication
# Out:
#               PRODUCT NAME   NAFDAC      BRAND   GENERICS PRODUCT CATEGORY  \
# 3579   MIDAZOLAM INJECTION  B4-9661  MIDAZOLAM  MIDAZOLAM       HUMAN DRUG
# 4100  GRAPROFEN SUSPENSION  A4-8078  GRAPROFEN  IBUPROFEN       HUMAN DRUG
#
#      PHARM CLASS     ROUTE OF ADMINISTRATION GROUP    ACTIVE ING   STRENGTH  \
# 3579    SEDATIVE  INTRAVENOUS/ INTRAMUSCULAR  DRUG     MIDAZOLAM       15MG
# 4100       NSAID                        ORAL  DRUG  IBUPROFEN BP  100MG/5ML
#
#                     PRESENTATION DOSAGE FORM          PACK SIZE  \
# 3579  INJECTION, 5 AMPOULES X3ML   INJECTION  5 AMPOULES OF 3ML
# 4100          SUSPENSION,1X100ML  SUSPENSION          1 X 100ML
#
#               MARKETING CATEGORY APPROVED INDICATION  \
# 3579  PRESCRIPTION ONLY MEDICINE                 NaN
# 4100            OVER THE COUNTER                 NaN
#
#              NAME OF APPLICANT  \
# 3579  EXCEL CHARIS PHARMA. LTD
# 4100     GRAMS PHARMACEUTICALS
#
# ...

# %%
null_Applicant = drug.loc[drug['NAME OF APPLICANT'].isnull(), :]

# %%
len(null_Applicant)
# Out:
# 23

# %%
null_Applicant
# Out:
#                                           PRODUCT NAME    NAFDAC  \
# 633                                   JADURON CAPSULES   A4-4061
# 1348  BIORAJ PARACETAMOL & DICLOFENAC POTASSIUM TABLET  A11-0323
# 1349                              JAWALK ORAL SOLUTION  A11-0138
# 1350                                    PECRITON SYRUP  A11-0325
# 1351                                   GARYLONG TABLET   B4-3550
# 1352     ANNMOX AMOXICILLIN POWDER FOR ORAL SUSPENSION  A11-0326
# 1353                                     MOBITIN SYRUP  A11-0115
# 1354                                 MYZITH 500 TABLET  A11-0327
# 1355                                    VARSPAR TABLET   A4-5476
# 1356                                      NESTIN CREAM   04-6365
# 1357                                    VARSPAR TABLET   A4-5475
# 1358                                   BOND CPM TABLET   04-0490
# 1359                                IRON BOND IB TONIC   04-1833
# ...

# %%
null_ApplicantAddress = drug.loc[drug['APPLICANT ADDRESS'].isnull(), :]

# %%
len(null_ApplicantAddress)
# Out:
# 2

# %%
null_ApplicantAddress
# Out:
#            PRODUCT NAME   NAFDAC     BRAND              GENERICS  \
# 2850  VITASOPT EYE DROP  B4-9091  VITASOPT  DORZOLAMIDE +TIMOLOL
# 3043            GEMTERO  B4-8260   GEMTERO           GEMCITABINE
#
#      PRODUCT CATEGORY                          PHARM CLASS  \
# 2850       HUMAN DRUG  INTRAOCULAR PRESSURE LOWERING AGENT
# 3043       HUMAN DRUG                ANTI-NEOPLASTIC AGENT
#
#      ROUTE OF ADMINISTRATION GROUP                    ACTIVE ING  STRENGTH  \
# 2850              OPHTHALMIC  DRUG  DORZOLAMIDE 2%, TIMOLOL 0.5%  2%, 0.5%
# 3043             INTRAVENOUS  DRUG                   GEMCITABINE        1G
#
#                       PRESENTATION           DOSAGE FORM PACK SIZE  \
# 2850             EYE DROP, 1 X 5ML   OPHTHALMIC SOLUTION   1 X 5ML
# 3043  POWDER FOR INJECTION, 1 VIAL  POWDER FOR INJECTION    1 VIAL
#
#               MARKETING CATEGORY    APPROVED INDICATION  \
# 2850  PRESCRIPTION ONLY MEDICINE  TREATMENT OF GLAUCOMA
# ...

# %%
null_Country = drug.loc[drug['COUNTRY'].isnull(), :]

# %%
len(null_Country)
# Out:
# 77

# %%
pd.set_option('display.max_row', None)
pd.set_option('display.max_colwidth', None)
null_Country
# Out:
#                                            PRODUCT NAME    NAFDAC  \
# 871                                        BIOREX SYRUP  A11-0309
# 872                            ANIRON BLOOD TONIC SYRUP  A11-0313
# 873                                    BLOOMVITE TABLET  A11-0314
# 874                                        AFVITE SYRUP  A11-0315
# 875                 UCAN-CET ANTIMICROBIAL DISINFECTANT  A11-0316
# 876                           MISBAH SAFLIN COUGH SYRUP  A11-0317
# 877                               BIORAMOL EXTRA TABLET  A11-0318
# 878                     AVROLIN FOR CHILDREN COLD SYRUP   A4-5667
# 879                                       FRANOL TABLET   04-1776
# 880                                      JUNIVITE SYRUP   04-1236
# 881                                       MONOVER SYRUP   A4-6293
# 882                                   BEECODEEN TABLETS   04-1370
# 885                                   GESTID SUSPENSION   04-0480
# ...

# %%
# Filling in for ['COUNTRY'] null values

# %%
updated_df = drug

# %%
drug.loc[drug['COUNTRY'].isnull(), 'COUNTRY']='NIGERIA'

# %%
# Checking for null values in the column "COUNTRY"

# %%
null_Country = drug.loc[drug['COUNTRY'].isnull(), :]

# %%
len(null_Country) # If 0 there is therefore no more null values in the column "COUNTRY"
# Out:
# 0

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
null_ManufacturerAddress = drug.loc[drug['MANUFACTURER ADDRESS'].isnull(), :]

# %%
len(null_ManufacturerAddress)
# Out:
# 4

# %%
null_ManufacturerAddress
# Out:
#                                    PRODUCT NAME   NAFDAC      BRAND  \
# 803                        LISIKRIS 5MG TABLETS  B4-6327   LISIKRIS
# 3175                      BRADFERON BLOOD TONIC  A4-8303  BRADFERON
# 3187                    DR. MEYER'S LIQUID IRON  04-1155  DR. MEYER
# 5638  HANBET METRONIDAZOLE 500MG/100ML INFUSION  A4-8794     HANBET
#
#                                                                                        GENERICS  \
# 803                                                                        LISINOPRIL DIHYDRATE
# 3175  FERRIC AMMONIUM CITRATE, CYANOCOBALAMIN, VITAMIN B1, VITAMIN B2, NICOTINAMIDE, FOLIC ACID
# 3187                                           FERRIC AMMONIUM CITRATE, FOLIC ACID, VITAMIN B12
# 5638                                                                  METRONIDAZOLE 500MG/100ML
#
#      PRODUCT CATEGORY                              PHARM CLASS  \
# 803        HUMAN DRUG  ANGIOTENSIN-CONVERTING ENZYME INHIBITOR
# ...

# %%
updated_df = drug

# %%
#
drug.loc[drug['NAME OF MANUFACTURER'] == 'GENRX PHARMACEUTICALS PVT LTD']
# Out:
#               PRODUCT NAME   NAFDAC     BRAND              GENERICS  \
# 800  AMLOKRIS 10MG TABLETS  B4-6324  AMLOKRIS   AMLODIPINE BESILATE
# 801   AMLOKRIS 5MG TABLETS  B4-6325  AMLOKRIS   AMLODIPINE BESILATE
# 802  LISIKRIS 10MG TABLETS  B4-6326  LISIKRIS  LISINOPRIL DIHYDRATE
# 803   LISIKRIS 5MG TABLETS  B4-6327  LISIKRIS  LISINOPRIL DIHYDRATE
#
#     PRODUCT CATEGORY                              PHARM CLASS  \
# 800       HUMAN DRUG                  CALCIUM CHANNEL BLOCKER
# 801       HUMAN DRUG                  CALCIUM CHANNEL BLOCKER
# 802       HUMAN DRUG  ANGIOTENSIN-CONVERTING ENZYME INHIBITOR
# 803       HUMAN DRUG  ANGIOTENSIN-CONVERTING ENZYME INHIBITOR
#
#     ROUTE OF ADMINISTRATION  GROUP  \
# 800                    ORAL  DRUGS
# 801                    ORAL  DRUGS
# 802                    ORAL  DRUGS
# 803                    ORAL  DRUGS
#
#                                      ACTIVE ING STRENGTH  \
# 800    AMLODIPINE BESILATE BP EQV TO AMLODIPINE     10MG
# ...

# %%
#filling in Missing values for Manufacturer's Address using the indices

# %%
drug.iat[803, 19] = 'A-52, MALEGAON MIDC AREA, SINNAR DIST. NASHIK-422113 INDIA'

# %%
drug.loc[drug['NAME OF MANUFACTURER'] == 'OAK-PHARMACEUTICAL LTD.']
# Out:
#                     PRODUCT NAME   NAFDAC      BRAND  \
# 3173       BRADFEREX BLOOD TONIC  A4-8006  BRADFEREX
# 3174  BRADCUFF EXPECTORANT SYRUP  A4-8283   BRADCUFF
# 3175       BRADFERON BLOOD TONIC  A4-8303  BRADFERON
#
#                                                                                        GENERICS  \
# 3173  FERRIC AMMONIUM CITRATE, CYANOCOBALAMIN, VITAMIN B1, VITAMIN B2, NICOTINAMIDE, FOLIC ACID
# 3174                               AMMONIUM CHLORIDE, AMMONIUM BICARBONATE, DIPHENHYDRAMINE HCL
# 3175  FERRIC AMMONIUM CITRATE, CYANOCOBALAMIN, VITAMIN B1, VITAMIN B2, NICOTINAMIDE, FOLIC ACID
#
#      PRODUCT CATEGORY                   PHARM CLASS ROUTE OF ADMINISTRATION  \
# 3173       HUMAN DRUG   IRON AND VITAMIN SUPPLEMENT                    ORAL
# 3174       HUMAN DRUG             COUGH EXPECTORANT                    ORAL
# 3175       HUMAN DRUG  IRON AND VITAMIN SUPPLEMENNT                    ORAL
#
#      GROUP  \
# 3173  DRUG
# 3174  DRUG
# 3175  DRUG
#
# ...

# %%
drug.iat[3175,19] = '10-12, JALOGUN PALACE WAY, OFF KM. 44, LAGOS-IBADAN EXPRESSWAY, IMEDU-NLA, MOWE, OGUN STATE'

# %%
drug.loc[drug['NAME OF MANUFACTURER'] == 'FARMEX MEYER LIMITED']
# Out:
#                  PRODUCT NAME    NAFDAC      BRAND  \
# 3187  DR. MEYER'S LIQUID IRON   04-1155  DR. MEYER
# 4470  FARMEX SALBUTAMOL SYRUP   04-1730     FARMEX
# 4763             FARMEX TONIC  A11-0905     FARMEX
#
#                                               GENERICS PRODUCT CATEGORY  \
# 3187  FERRIC AMMONIUM CITRATE, FOLIC ACID, VITAMIN B12       HUMAN DRUG
# 4470                                        SALBUTAMOL       HUMAN DRUG
# 4763  FERRIC AMMONIUM CITRATE, VITAMIN B12, FOLIC ACID       HUMAN DRUG
#
#                       PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 3187                    HEMATINIC                    ORAL  DRUG
# 4470               BRONCHODILATOR                    ORAL  DRUG
# 4763  IRON AND VITAMIN SUPPLEMENT                    ORAL  DRUG
#
#                                               ACTIVE ING            STRENGTH  \
# 3187    FERRIC AMMONIUM CITRATE, FOLIC ACID, VITAMIN B12       200MG, 200MCG
# ...

# %%
drug.iat[3187,19] = 'KM. 38, LAGOS-ABEOKUTA ROAD, SANGO OTA, OGUN STATE.'

# %%
drug.loc[drug['NAME OF MANUFACTURER'] == 'HEBEI TIACHENG PHARMACEUTICAL CO. LTD']
# Out:
#                                    PRODUCT NAME   NAFDAC   BRAND  \
# 5638  HANBET METRONIDAZOLE 500MG/100ML INFUSION  A4-8794  HANBET
#
#                        GENERICS PRODUCT CATEGORY  PHARM CLASS  \
# 5638  METRONIDAZOLE 500MG/100ML       HUMAN DRUG  ANTIBIOTICS
#
#      ROUTE OF ADMINISTRATION GROUP     ACTIVE ING STRENGTH  \
# 5638                IV ROUTE  DRUG  METRONIDAZOLE    100ML
#
#             PRESENTATION DOSAGE FORM   PACK SIZE          MARKETING CATEGORY  \
# 5638  INFUSION1 X 1 VIAL    INFUSION  1 X 1 VIAL  PRESCRIPTION ONLY MEDICINE
#
#                                APPROVED INDICATION   NAME OF APPLICANT  \
# 5638  TREATMENT OF INFECTION CAUSED BY SUSCEPTIBLE  HANBET PHARM. LTD.
#
#                                         APPLICANT ADDRESS  COUNTRY  \
# 5638  118, MURTALA MOHAMMED WAY, EBUTE METTA, LAGOS STATE  NIGERIA
#
#                        NAME OF MANUFACTURER MANUFACTURER ADDRESS COUNTRY.1  \
# ...

# %%
updated_df = drug

# %%
manufacturerName = drug[drug['NAME OF MANUFACTURER'].str.contains('hebei', case=False)]

# %%
manufacturerName
# Out:
#                                            PRODUCT NAME   NAFDAC      BRAND  \
# 2613                          NELB PARACETAMOL INFUSION  B4-9129       NELB
# 3972                                  CEDAZOLE INFUSION  B4-5050   CEDAZOLE
# 3973                                 CEDFLOXAC INFUSION  B4-4736  CEDFLOXAC
# 5015               NCPC CEFUROXIME POWDER FOR INJECTION  C4-1231       NCPC
# 5518  NCPC CEFTRIAXONE SODIUM POWDER FOR INJECTION (IM)  B4-2307       NCPC
# 5638          HANBET METRONIDAZOLE 500MG/100ML INFUSION  A4-8794     HANBET
#
#                        GENERICS PRODUCT CATEGORY    PHARM CLASS  \
# 2613                PARACETAMOL       HUMAN DRUG          NSAID
# 3972              METRONIDAZOLE       HUMAN DRUG  ANTIMICROBIAL
# 3973              CIPROFLOXACIN       HUMAN DRUG    ANTIBIOTICS
# 5015                 CEFUROXIME       HUMAN DRUG     ANTIBIOTIC
# 5518         CEFTRIAXONE SODIUM       HUMAN DRUG     ANTIBIOTIC
# ...

# %%
type(drug)
# Out:
# pandas.core.frame.DataFrame

# %%
drug.iat[5638,19] = 'NO. 18, JINGUANG STREET, ECONOMIC AND TECHNOLOGICAL DEVELOPMENT ZONE, CANGZHOU, HEBEI PROVINCE, CHINA.'

# %%
# Checking for null values in the column "COUNTRY"

# %%
null_ManufacturerAddress = drug.loc[drug['MANUFACTURER ADDRESS'].isnull(), :]

# %%
len(null_ManufacturerAddress) # If 0 there is therefore no more null values in the column "MANUFACTURER ADDRESS"
# Out:
# 0

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
null_expCountry = drug.loc[drug['COUNTRY.1'].isnull(), :]

# %%
len(null_expCountry)
# Out:
# 105

# %%
null_expCountry
# Out:
#                                            PRODUCT NAME    NAFDAC  \
# 871                                        BIOREX SYRUP  A11-0309
# 872                            ANIRON BLOOD TONIC SYRUP  A11-0313
# 873                                    BLOOMVITE TABLET  A11-0314
# 874                                        AFVITE SYRUP  A11-0315
# 875                 UCAN-CET ANTIMICROBIAL DISINFECTANT  A11-0316
# 876                           MISBAH SAFLIN COUGH SYRUP  A11-0317
# 877                               BIORAMOL EXTRA TABLET  A11-0318
# 878                     AVROLIN FOR CHILDREN COLD SYRUP   A4-5667
# 879                                       FRANOL TABLET   04-1776
# 880                                      JUNIVITE SYRUP   04-1236
# 881                                       MONOVER SYRUP   A4-6293
# 882                                   BEECODEEN TABLETS   04-1370
# 885                                   GESTID SUSPENSION   04-0480
# ...

# %%
# filling in for the null values of "COUNTRY.1" the exporting country

# %%
updated_df = drug

# %%
drug['COUNTRY.1'] = np.where(drug['NAME OF MANUFACTURER'] == 'SAME AS APPLICANT', 'NIGERIA', drug['COUNTRY.1'])

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
null_expCountry = drug.loc[drug['COUNTRY.1'].isnull(), :]

# %%
len(null_expCountry)
# Out:
# 56

# %%
updated_df = drug

# %%
drug['COUNTRY.1'] = np.where(drug['MANUFACTURER ADDRESS'].str.contains('KWARA|LAGOS|KANO|OGUN|ENUGU'), 'NIGERIA', drug['COUNTRY.1'])

# %%
type(drug)
# Out:
# pandas.core.frame.DataFrame

# %%
null_expCountry = drug.loc[drug['COUNTRY.1'].isnull(), :]

# %%
len(null_expCountry)
# Out:
# 26

# %%
null_expCountry
# Out:
#                                      PRODUCT NAME   NAFDAC  \
# 1293                           SPEDRA 100 TABLETS  B4-7413
# 1420                         CELTAX 100 INJECTION  A4-4848
# 3345                          LASTAVIN 160 TABLET  B4-9575
# 3346                          LASTAVIN HTZ TABLET  B4-9576
# 3347                            MEDLANTIC CAPSULE  B4-9614
# 3348                       SPARE COD 1000 CAPSULE  A4-3099
# 3349                        SPARE COD 300 CAPSULE  A4-3098
# 3350                            CERTA KIT CAPSULE  B4-7956
# 3351                   GLOBAL GOLDEN SEA CAPSULES  A4-0936
# 3352                    GLOBAL GOLDEN SEA CAPSULE  A4-4091
# 3353                             BARIPHAGE TABLET  B4-9590
# 3354                 BG TRAGESIC TRAMADOL CAPSULE  A4-2740
# 3355                    POLITOR PLUS 10/20 TABLET  B4-9578
# 3488                            METFORMIN TABLETS  B4-9596
# 3498                            SIGRA-100 TABLETS  B4-9600
# ...

# %%
updated_df = drug

# %%
drug['COUNTRY.1'] = np.where(drug['MANUFACTURER ADDRESS'].str.contains('TELANGANA|INDIA'), 'INDIA', drug['COUNTRY.1'])

# %%
null_expCountry = drug.loc[drug['COUNTRY.1'].isnull(), :]

# %%
len(null_expCountry)
# Out:
# 6

# %%
null_expCountry
# Out:
#                                    PRODUCT NAME   NAFDAC      BRAND  \
# 1293                         SPEDRA 100 TABLETS  B4-7413     SPEDRA
# 3860                                VOLIGEL GEL  C4-0013    VOLIGEL
# 3862                           WATE-ON EMULSION  04-1232    WATE-ON
# 3969                          OCEXONE INJECTION  A4-9169    OCEXONE
# 3973                         CEDFLOXAC INFUSION  B4-4736  CEDFLOXAC
# 5638  HANBET METRONIDAZOLE 500MG/100ML INFUSION  A4-8794     HANBET
#
#                          GENERICS PRODUCT CATEGORY  \
# 1293                     AVANAFIL       HUMAN DRUG
# 3860      DICLOFENAC DIETHYLAMINE       HUMAN DRUG
# 3862  NICOTINAMIDE+ MULTIVITAMINS       HUMAN DRUG
# 3969                  CEFTRIAXONE       HUMAN DRUG
# 3973                CIPROFLOXACIN       HUMAN DRUG
# 5638    METRONIDAZOLE 500MG/100ML       HUMAN DRUG
#
#                              PHARM CLASS    ROUTE OF ADMINISTRATION  GROUP  \
# ...

# %%
drug.iat[1293,20] = 'FRANCE'

# %%
drug.iat[3860, 20] = 'BANGLADESH'

# %%
drug.iat[3862, 20] = 'ENGLAND'

# %%
drug.iat[3969, 20] = 'PORTUGAL'

# %%
drug.iat[3973, 20] = 'CHINA'

# %%
drug.iat[5738, 20] = 'NIGERIA'

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
null_expCountry = drug.loc[drug['COUNTRY.1'].isnull(), :]

# %%
len(null_expCountry)
# Out:
# 1

# %%
null_expCountry
# Out:
#                                    PRODUCT NAME   NAFDAC   BRAND  \
# 5638  HANBET METRONIDAZOLE 500MG/100ML INFUSION  A4-8794  HANBET
#
#                        GENERICS PRODUCT CATEGORY  PHARM CLASS  \
# 5638  METRONIDAZOLE 500MG/100ML       HUMAN DRUG  ANTIBIOTICS
#
#      ROUTE OF ADMINISTRATION GROUP     ACTIVE ING STRENGTH  \
# 5638                IV ROUTE  DRUG  METRONIDAZOLE    100ML
#
#             PRESENTATION DOSAGE FORM   PACK SIZE          MARKETING CATEGORY  \
# 5638  INFUSION1 X 1 VIAL    INFUSION  1 X 1 VIAL  PRESCRIPTION ONLY MEDICINE
#
#                                APPROVED INDICATION   NAME OF APPLICANT  \
# 5638  TREATMENT OF INFECTION CAUSED BY SUSCEPTIBLE  HANBET PHARM. LTD.
#
#                                         APPLICANT ADDRESS  COUNTRY  \
# 5638  118, MURTALA MOHAMMED WAY, EBUTE METTA, LAGOS STATE  NIGERIA
#
#                        NAME OF MANUFACTURER  \
# 5638  HEBEI TIACHENG PHARMACEUTICAL CO. LTD
#
# ...

# %%
drug.iloc[5738, :]
# Out:
# PRODUCT NAME                                                                   AVROMAL TABLET
# NAFDAC                                                                                A4-4050
# BRAND                                                                                 AVROMAL
# GENERICS                                                             ARTEMETHER, LUMEFANTRINE
# PRODUCT CATEGORY                                                                   HUMAN DRUG
# PHARM CLASS                                                                       ANTIMALARIA
# ROUTE OF ADMINISTRATION                                                                  ORAL
# GROUP                                                                                    DRUG
# ACTIVE ING                                                          ARTEMETHER , LUMEFANTRINE
# STRENGTH                                                                                240MG
# ...

# %%
drug.iat[5638, 20] = 'CHINA'

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
# %run null_values.py

# %%
nullcols(drug)
# Out:
# ROUTE OF ADMINISTRATION      1
# STRENGTH                   130
# PRESENTATION                26
# DOSAGE FORM                  8
# PACK SIZE                   12
# MARKETING CATEGORY           1
# APPROVED INDICATION          2
# NAME OF APPLICANT           23
# APPLICANT ADDRESS            2
# dtype: int64

# %%
len(nullcols(drug))
# Out:
# 9

# %%
null_ApplicantAddress = drug.loc[drug['APPLICANT ADDRESS'].isnull(), :]

# %%
null_ApplicantAddress
# Out:
#            PRODUCT NAME   NAFDAC     BRAND              GENERICS  \
# 2850  VITASOPT EYE DROP  B4-9091  VITASOPT  DORZOLAMIDE +TIMOLOL
# 3043            GEMTERO  B4-8260   GEMTERO           GEMCITABINE
#
#      PRODUCT CATEGORY                          PHARM CLASS  \
# 2850       HUMAN DRUG  INTRAOCULAR PRESSURE LOWERING AGENT
# 3043       HUMAN DRUG                ANTI-NEOPLASTIC AGENT
#
#      ROUTE OF ADMINISTRATION GROUP                    ACTIVE ING  STRENGTH  \
# 2850              OPHTHALMIC  DRUG  DORZOLAMIDE 2%, TIMOLOL 0.5%  2%, 0.5%
# 3043             INTRAVENOUS  DRUG                   GEMCITABINE        1G
#
#                       PRESENTATION           DOSAGE FORM PACK SIZE  \
# 2850             EYE DROP, 1 X 5ML   OPHTHALMIC SOLUTION   1 X 5ML
# 3043  POWDER FOR INJECTION, 1 VIAL  POWDER FOR INJECTION    1 VIAL
#
#               MARKETING CATEGORY    APPROVED INDICATION  \
# 2850  PRESCRIPTION ONLY MEDICINE  TREATMENT OF GLAUCOMA
# ...
