# %%
import pandas as pd
import numpy as np

# %%
drug = pd.read_excel('new-drug-v5.xlsx', index_col=0, parse_dates=['APPROVAL DATE', 'EXPIRY DATE'])

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5758 non-null   object
#  10  PRESENTATION             5854 non-null   object
#  11  DOSAGE FORM              5854 non-null   object
#  12  PACK SIZE                5854 non-null   object
#  13  MARKETING CATEGORY       5854 non-null   object
# ...

# %%
#drugs.drop(['date_time'], axis=1, inplace=True)

# %%
#drugs.to_excel('new-drug-v5.xlsx')

# %%
#updated_df['date_time'] = pd.to_datetime(updated_df['APPROVAL DATE'], errors='coerce')
#print(updated_df[updated_df.date_time.isnull()])

# %%
#null_apptime = drug.loc[drug['APPROVAL DATE'].isnull(), :]

# %%
#null_apptime

# %%
pd.set_option('display.max_colwidth', 60)
drug.iloc[1293]
# Out:
# PRODUCT NAME                                                        SPEDRA 100 TABLETS
# NAFDAC                                                                         B4-7413
# BRAND                                                                           SPEDRA
# GENERICS                                                                      AVANAFIL
# PRODUCT CATEGORY                                                            HUMAN DRUG
# PHARM CLASS                                         TYPE 5 PHOSPHODIESTERASE INHIBITOR
# ROUTE OF ADMINISTRATION                                                           ORAL
# GROUP                                                                             DRUG
# ACTIVE ING                                                              AVANAFIL 100MG
# STRENGTH                                                                         100MG
# PRESENTATION                                                             TABLETS, 1X4,
# ...

# %%
drug['NAME OF MANUFACTURER'] = drug['NAME OF MANUFACTURER'].str.rstrip(',')

# %%
manu = drug['NAME OF MANUFACTURER'].unique()

# %%
pd.set_option('display.max_row', None)

# %%
manuList = list(manu)

# %%
manuList.sort()

# %%
manuList
# Out:
# ['13, HUGHES AVENUE,\nYABA,\nLAGOS STATE',
#  'A & J PHARM NIG LTD',
#  'A & J PHARMACEUTICAL NIGERIA LIMITED',
#  'A C DRUGS LIMITED',
#  'A. C. DRUGS LTD',
#  'A.C DRUGS LTD.',
#  'ABARIS HEALTHCARE PVT LTD',
#  'ABARIS HEALTHCARE PVT. LTD',
#  'ABBOT BIOLOGICCALS B.V.',
#  'ABBOTT GMBH & CO. KG',
#  'ABBVIE DEUTSCHLAND GMBH & CO. KG',
#  'ABBVIE INC.',
#  'ABBVIE S.R.L.',
#  'AC DRUGS LIMITED',
#  'ACCORD UK LTD',
#  'ACINO PHARMA AG',
#  'ACME FORMULATION PVT LTD',
#  'ACME FORMULATION PVT. LTD.',
#  'ACROMAX DOMINICANA S.A',
#  'ACULIFE HEALTHCARE PVT LTD',
#  'ACULIFE HEALTHCARE PVT. LTD',
#  'ADAMS PHARMACEUTICAL (ANHUI) CO. LTD',
#  'ADAMS PHARMACEUTICALS (ANHUI) CO. LTD',
#  'ADLER PRODUCTS LTD.',
#  'ADLEY FORMULATIONS',
#  'ADMAC LIFESCIENCE',
#  'ADORE PHARMA PVT. LTD.',
#  'ADORE PHARMACEUTICAL PVT LTD',
#  'AEROPHARM GMBH',
#  'AESICA PHARMACEUTICALS S.R.L',
#  'AESICA QUEENBOROUGH LTD',
#  'AESICA QUEENBOROUGH LTD.',
#  'AFRAB CHEM LTD',
#  'AFRAB-CHEM LIMITED',
# ...

# %%
#manuFrame = pd.DataFrame(manuList, columns=['Name of Manufacturer'])

# %%
#def append_to_excel(fpath,df,sheet_name):
 #   with pd.ExcelWriter(fpath, mode='a', engine='openpyxl') as f:
  #      df.to_excel(f, sheet_name=sheet_name)

#append_to_excel('C:/Users/kiels/nafdac/drug-dataset/drug-data-list.xlsx',manuFrame, 'Manufacturers')

# %%
drug.rename(columns={'COUNTRY':'COUNTRY OF APPLICANT', 'COUNTRY.1':'COUNTRY OF MANUFACTURE'}, inplace=True)

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5758 non-null   object
#  10  PRESENTATION             5854 non-null   object
#  11  DOSAGE FORM              5854 non-null   object
#  12  PACK SIZE                5854 non-null   object
#  13  MARKETING CATEGORY       5854 non-null   object
# ...

# %%
drugList = pd.read_excel('drug-data-list-v2.xlsx', sheet_name=None, index_col=0)

# %%
drugList.keys()
# Out:
# dict_keys(['pharm-class', 'dosage-form'])

# %%
pharmclass = drugList['pharm-class']

# %%
pharmclass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 786 entries, 0 to 785
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PHARM CLASS    786 non-null    object
#  1   PHARM CLASSes  763 non-null    object
# dtypes: object(2)
# memory usage: 18.4+ KB

# %%
dosage = drugList['dosage-form']

# %%
dosage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DOSAGE FORM   145 non-null    object
#  1   DOSAGE FORMs  140 non-null    object
# dtypes: object(2)
# memory usage: 3.4+ KB

# %%
dose_dictionary = dict(dosage.values)

# %%
pharma_dictionary = dict(pharmclass.values)

# %%
#pharma_dictionary

# %%
drug['PHARM CLASS'].replace(pharma_dictionary, inplace=True)

# %%
drug['DOSAGE FORM'].replace(dose_dictionary, inplace=True)

# %%
# %run null_values.py

# %%
nullcols(drug)
# Out:
# PHARM CLASS            31
# STRENGTH               96
# DOSAGE FORM             4
# APPROVED INDICATION     1
# NAME OF APPLICANT       2
# dtype: int64

# %%
drugList2 = pd.read_excel('drug-data-list-v3.xlsx', sheet_name=None)

# %%
drugList2.keys()
# Out:
# dict_keys(['pharm-class', 'dosage-form', 'Manufacturers'])

# %%
manu = drugList2['Manufacturers']

# %%
manu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1750 entries, 0 to 1749
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Manufacturer   1750 non-null   object
#  1   Name of Manufacturers  1747 non-null   object
# dtypes: object(2)
# memory usage: 27.5+ KB

# %%
manu_dictionary = dict(manu.values)

# %%
drug['NAME OF MANUFACTURER'].replace(manu_dictionary, inplace=True)

# %%
drug['NAME OF MANUFACTURER'].fillna('No Manufacturer', inplace = True)

# %%
manufacturer = drug['NAME OF MANUFACTURER'].unique()

# %%
list(manufacturer).sort()

# %%
manufacturer.sort()
print(manufacturer)
# Out:
# ['A & J PHARMACEUTICAL NIGERIA LIMITED' 'A C DRUGS LIMITED'
#  'ABARIS HEALTHCARE PVT LTD' 'ABBOT BIOLOGICALS B.V.'
#  'ABBOTT GMBH & CO. KG' 'ABBVIE DEUTSCHLAND GMBH & CO. KG' 'ABBVIE INC.'
#  'ABBVIE S.R.L.' 'AC DRUGS LIMITED' 'ACCORD UK LTD' 'ACINO PHARMA AG'
#  'ACME FORMULATION PVT LTD' 'ACROMAX DOMINICANA S.A'
#  'ACULIFE HEALTHCARE PVT LTD' 'ACULIFE HEALTHCARE PVT. LTD'
#  'ADAMS PHARMACEUTICAL (ANHUI) CO. LTD' 'ADLER PRODUCTS LTD.'
#  'ADLEY FORMULATIONS' 'ADMAC LIFESCIENCE' 'ADORE PHARM PVT LTD.'
#  'ADORE PHARMACEUTICAL PVT LTD' 'AEROPHARM GMBH'
#  'AESICA PHARMACEUTICALS S.R.L' 'AESICA QUEENBOROUGH LTD'
#  'AFRAB-CHEM LIMITED' 'AGARY PHARMACEUTICAL LIMITED'
#  'AGIO PHARMACEUTICAL LTD' 'AHLCON PARENTERALS (INDIA) LTD'
#  'AISHWARYA LIFESCIENCES' 'AJANTA PHARMA LIMITED' 'AKORN INC.'
#  'AKRITI PHARMACEUTICALS PVT LTD.' 'AKUMS DRUGS & PHARMACEUTICALS LTD'
#  'ALBEN HEALTHCARE INDUSTRIES LIMITED' 'ALCHEMY MEDICINE PVT LTD'
#  'ALCON-COUVREUR' 'ALKEM LABORATORIES'
# ...

# %%
sort_drug = drug.sort_values(by=['NAFDAC'])

# %%
duplicate_drug = sort_drug[sort_drug.duplicated(['NAFDAC'],keep=False)]

# %%
pd.set_option('display.max_row', None)
duplicate_drug
# Out:
#                                                      PRODUCT NAME    NAFDAC  \
# 3036                                          VOLTAREN EMULGEL 1%   04-0038
# 3209                                          VOLTAREN EMULGEL 1%   04-0038
# 4545                                          HEATOL CHINESE BALM   04-0242
# 3483                                          HEATOL CHINESE BALM   04-0242
# 2053                                                 EMCAP CAPLET   04-0261
# 4761                                     EMCAP PARACETAMOL CAPLET   04-0261
# 4814                                     THERACIN 500 PARACETAMOL   04-0458
# 4815                                            HYDROGEN PEROXIDE   04-0458
# 3143                                             BRUSTAN-N TABLET   04-0694
# 2690                                            BRUSTAN-N TABLETS   04-0694
# 2338                                  NICHBEN PARACETAMOL TABLETS   04-0833
# ...

# %%
#np.sum(drug[drug['NAFDAC'] == 'NAFDAC']['NAFDAC'].value_counts())

# %%
ariable = duplicate_drug.pivot_table(index=['NAFDAC'], aggfunc='size')
print(ariable)
# Out:
# NAFDAC
# 04-0038     2
# 04-0242     2
# 04-0261     2
# 04-0458     2
# 04-0694     2
# 04-0833     2
# 04-1984     2
# 04-2021     9
# 04-2078     2
# 04-2087     2
# 04-2221     2
# 04-2458     2
# 04-2737     2
# 04-2826     2
# 04-3444     3
# 04-3514     2
# 04-3552     2
# 04-3686     2
# 04-3919     2
# 04-4244     2
# 04-4304     2
# 04-4449     2
# 04-4642     2
# 04-4671     2
# 04-4779     2
# 04-4929     2
# 04-5049     2
# 04-5566     2
# 04-5677     2
# 04-5731     2
# 04-6433     2
# 04-6844     3
# 04-6992     2
# 04-7113     2
# 04-7365     2
# 04-7907     2
# 04-7989     2
# 04-8020     2
# 04-8344     3
# 04-9094     4
# 04-9128     2
# 04-9764     2
# A11-0138    2
# A11-0292    3
# A11-0293    2
# A11-0325    2
# A11-0655    2
# A11-0686    2
# A11-0837    2
# A11-0838    2
# A11-0839    2
# A11-0840    2
# A11-0855    2
# A11-0951    2
# A11-0952    2
# A11-0953    2
# A11-0954    2
# A11-0957    2
# A11-0963    2
# A11-0985    2
# A11-1009    2
# ...

# %%
duplicate_drug[duplicate_drug['NAFDAC'] == '04-0038']
# Out:
#              PRODUCT NAME   NAFDAC     BRAND                 GENERICS  \
# 3036  VOLTAREN EMULGEL 1%  04-0038  VOLTAREN  DICLOFENAC DIETHYLAMINE
# 3209  VOLTAREN EMULGEL 1%  04-0038  VOLTAREN  DICLOFENAC DIETHYLAMINE
#
#      PRODUCT CATEGORY PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 3036       HUMAN DRUG       NSAID                 TOPICAL  DRUG
# 3209       HUMAN DRUG      NSAIDS                 TOPICAL  DRUG
#
#                       ACTIVE ING    STRENGTH  ...      MARKETING CATEGORY  \
# 3036  DICLOFENAC DIETHYLAMINE 1%        0.01  ...  OVER THE COUNTER (OTC)
# 3209     DICLOFENAC DIETHYLAMINE  1.16G/100G  ...  OVER THE COUNTER (OTC)
#
#                                               APPROVED INDICATION  \
# 3036  RELIEF OF MILD TO MODERATE PAIN, REDUCE SWELLING AND INF...
# 3209                          MANAGEMENT OF PAIN AND INFLAMMATION
#
#                      NAME OF APPLICANT  \
# 3036             GSK CONSUMER NIG PLC.
# 3209  GLAXOSMITHKLINE CONSUMER NIG PLC
#
# ...

# %%
drug['DOSAGE FORM'].unique()
# Out:
# array(['SYRUP', 'SUSPENSION', 'SOLUTION', 'LIQUID', 'CAPSULE', 'POWDER',
#        'TABLET', 'CAPLET', 'OINTMENT', 'CREAM', 'DROPS', 'EMULSION',
#        'INJECTION', 'DISPERSIBLE TABLET', 'CHEWABLE TABLET', 'SOFT GELS',
#        'SPRAY', 'POWDER FOR ORAL SUSPENSION', 'SOFTGEL CAPSULES',
#        'EYE/EAR DROPS', 'POWDER FOR INJECTION',
#        'POWDER FOR ORAL SOLUTION', 'DISPERSIBLE TABLETS', 'GEL',
#        'LOZENGES', 'INHALANT', 'OPHTHALMIC SOLUTION', 'ORAL SOLUTION',
#        'SOFT GEL CAPSULES', 'SUPPOSITORY', 'INJECTABLE LIQUID', 'TONIC',
#        'LOTION', 'POWDER FOR SUSPENSION', 'ORAL SUSPENSION', 'INJECTABLE',
#        'POWDER & TABLET', 'CAPSULE & TABLET', 'INFUSION', 'PESSARY',
#        'BOLUS', 'EXTERNAL  PREPARATION', 'AEROSOL',
#        'GRANULE FOR ORAL SUSPENSION', 'SOLUTION FOR INFUSION', 'ORAL GEL',
#        'POWDER FOR SOLUTION', 'MOUTHWASH', 'ELIXIR', nan,
#        'POWDER FOR SOLUTION FOR INFUSION', 'GRANULES FOR ORAL SUSPENSION',
# ...

# %%
drug['DOSAGE FORM'].nunique()
# Out:
# 94

# %%
drug['DOSAGE FORM'] = drug['DOSAGE FORM'].str.strip()

# %%
# %run similarity.py
# Out:
#   Name of Manufacturer
# 0                 None

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5823 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5758 non-null   object
#  10  PRESENTATION             5854 non-null   object
#  11  DOSAGE FORM              5850 non-null   object
#  12  PACK SIZE                5854 non-null   object
#  13  MARKETING CATEGORY       5854 non-null   object
# ...

# %%
duplicate_drug.to_excel('duplicate-drug.xlsx')

# %%
drug.to_excel('new-drug-v6.xlsx')

# %%
drug['APPROVAL DATE'].dt.date
# Out:
# 0       2016-07-28
# 1       2016-07-28
# 2       2016-07-28
# 3       2016-07-28
# 4       2016-08-25
# 5       2016-10-05
# 6       2016-10-05
# 7       2016-10-05
# 8       2016-10-05
# 9       2016-10-05
# 10      2016-10-05
# 11      2016-10-05
# 12      2016-10-05
# 13      2016-10-05
# 14      2016-10-05
# 15      2016-11-15
# 16      2016-11-15
# 17      2016-11-15
# 18      2016-11-15
# 19      2016-11-15
# 20      2016-11-15
# 21      2016-11-15
# 22      2016-11-15
# 23      2016-11-15
# 24      2016-11-15
# 25      2016-11-15
# 26      2016-11-15
# 27      2016-11-15
# 28      2016-11-15
# 29      2016-11-15
# 30      2016-11-15
# 31      2016-11-15
# 32      2016-11-15
# 33      2016-11-15
# 34      2016-11-15
# 35      2016-11-15
# 36      2016-11-15
# 37      2016-11-15
# 38      2016-11-15
# 39      2016-11-15
# 40      2016-11-15
# 41      2016-11-29
# 42      2016-11-29
# 43      2016-11-29
# 44      2016-11-29
# 45      2016-11-29
# 46      2016-11-29
# ...

# %%
#drug.drop(['APPROVAL DATE2'], axis=1, inplace=True)

# %%
approval_date = drug['APPROVAL DATE']

# %%
approval_date
# Out:
# 0      2016-07-28
# 1      2016-07-28
# 2      2016-07-28
# 3      2016-07-28
# 4      2016-08-25
# 5      2016-10-05
# 6      2016-10-05
# 7      2016-10-05
# 8      2016-10-05
# 9      2016-10-05
# 10     2016-10-05
# 11     2016-10-05
# 12     2016-10-05
# 13     2016-10-05
# 14     2016-10-05
# 15     2016-11-15
# 16     2016-11-15
# 17     2016-11-15
# 18     2016-11-15
# 19     2016-11-15
# 20     2016-11-15
# 21     2016-11-15
# 22     2016-11-15
# 23     2016-11-15
# 24     2016-11-15
# 25     2016-11-15
# 26     2016-11-15
# 27     2016-11-15
# 28     2016-11-15
# 29     2016-11-15
# 30     2016-11-15
# 31     2016-11-15
# 32     2016-11-15
# 33     2016-11-15
# 34     2016-11-15
# 35     2016-11-15
# 36     2016-11-15
# 37     2016-11-15
# 38     2016-11-15
# 39     2016-11-15
# 40     2016-11-15
# 41     2016-11-29
# 42     2016-11-29
# 43     2016-11-29
# 44     2016-11-29
# 45     2016-11-29
# 46     2016-11-29
# 47     2016-11-29
# 48     2016-11-29
# 49     2016-11-29
# ...

# %%
drug.iloc[1293]
# Out:
# PRODUCT NAME                                                        SPEDRA 100 TABLETS
# NAFDAC                                                                         B4-7413
# BRAND                                                                           SPEDRA
# GENERICS                                                                      AVANAFIL
# PRODUCT CATEGORY                                                            HUMAN DRUG
# PHARM CLASS                                         TYPE 5 PHOSPHODIESTERASE INHIBITOR
# ROUTE OF ADMINISTRATION                                                           ORAL
# GROUP                                                                             DRUG
# ACTIVE ING                                                              AVANAFIL 100MG
# STRENGTH                                                                         100MG
# PRESENTATION                                                             TABLETS, 1X4,
# ...

# %%
pd.DatetimeIndex(drug['APPROVAL DATE']).normalize()
# Out:
# DatetimeIndex(['2016-07-28', '2016-07-28', '2016-07-28', '2016-07-28',
#                '2016-08-25', '2016-10-05', '2016-10-05', '2016-10-05',
#                '2016-10-05', '2016-10-05',
#                ...
#                '2020-11-10', '2020-11-10', '2020-11-10', '2020-11-30',
#                '2020-11-30', '2020-11-30', '2020-11-30', '2020-11-30',
#                '2020-11-30', '2020-11-30'],
#               dtype='datetime64[ns]', name='APPROVAL DATE', length=5854, freq=None)

# %%
drug['APPROVAL DATE'] = pd.to_datetime(drug['APPROVAL DATE']).dt.date

# %%
drug['EXPIRY DATE'] = pd.to_datetime(drug['EXPIRY DATE']).dt.date

# %%
drug.iloc[1293]
# Out:
# PRODUCT NAME                                                        SPEDRA 100 TABLETS
# NAFDAC                                                                         B4-7413
# BRAND                                                                           SPEDRA
# GENERICS                                                                      AVANAFIL
# PRODUCT CATEGORY                                                            HUMAN DRUG
# PHARM CLASS                                         TYPE 5 PHOSPHODIESTERASE INHIBITOR
# ROUTE OF ADMINISTRATION                                                           ORAL
# GROUP                                                                             DRUG
# ACTIVE ING                                                              AVANAFIL 100MG
# STRENGTH                                                                         100MG
# PRESENTATION                                                             TABLETS, 1X4,
# ...

# %%
drug.to_excel('new-drug-v6.xlsx')

# %%
same_applicant = drug.loc[drug['NAME OF MANUFACTURER'] == 'SAME AS APPLICANT']

# %%
same_applicant
# Out:
#                                                      PRODUCT NAME  \
# 81                                       PAUCO MEBENDAZOLE TABLET
# 885                                             GESTID SUSPENSION
# 886                                            OMEPRAZOLE CAPSULE
# 888                         NISPO VITAMIN C 100MG CHEWABLE TABLET
# 889                   ALBEN FERROUS SULPHATE + FOLIC ACID CAPSULE
# 890                                   ALBEN AMLODIPINE 5MG TABLET
# 891                                  ALBEN AMLODIPINE 10MG TABLET
# 892                                BABUFLAM PAEDIATRIC SUSPENSION
# 893                      PREMIER ORIGINAL ANTISEPTIC DISINFECTANT
# 894                    PREMIER LIME FRESH ANTISEPTIC DISINFECTANT
# 895                                          ESOMEPRAZOLE CAPSULE
# 896                                       CEFALEXIN 500MG CAPSULE
# 897                                  ALBEN NIFEDIPINE 10MG TABLET
# ...
