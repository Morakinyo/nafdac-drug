# %%
import pandas as pd
import numpy as np

# %%
druglist = pd.read_excel('drug-data-list-v2.xlsx', sheet_name=None, index_col=0)

# %%
type(druglist)
# Out:
# dict

# %%
druglist.keys()
# Out:
# dict_keys(['pharm-class', 'dosage-form'])

# %%
pharmclass = druglist['pharm-class']

# %%
pharmclass
# Out:
#                  PHARM CLASS              PHARM CLASSes
# 0     NUTRITIONAL SUPPLEMENT    NUTRITIONAL SUPPLEMENTS
# 1                    ANTACID                    ANTACID
# 2                   VITAMINS                   VITAMINS
# 3                    VITAMIN                   VITAMINS
# 4                 ANTISEPTIC                ANTISEPTICS
# ..                       ...                        ...
# 781   H₂ RECEPTOR ANTAGONIST     H2 RECEPTOR ANTAGONIST
# 782  PROSTAGLANDIN E1 ANALOG  PROSTAGLANDIN E1 ANALOGUE
# 783      NSAID, ANTIPLATELET     NSAIDs & ANTIPLATELETS
# 784             SULFONYLUREA               SULFONYLUREA
# 785            HERBAL REMEDY              HERBAL REMEDY
#
# [786 rows x 2 columns]

# %%
type(pharmclass)
# Out:
# pandas.core.frame.DataFrame

# %%
pharmclasses = pharmclass['PHARM CLASSes']

# %%
pharmclasses.hasnans
# Out:
# True

# %%
pharmclasses.fillna("Not Available", inplace=True)

# %%
pharmList = pharmclasses.unique().tolist()

# %%
pharmList.sort()

# %%
pharmList
# Out:
# ['5Α-REDUCTASE INHIBITOR/Α1 INHIBITOR',
#  '5ꭤ-REDUCTASE INHIBITOR / ꭤ-ADRENOCEPTOR AGONIST',
#  'ALDOSTERONE ANTAGONIST',
#  'ALKALINISING AGENT',
#  'ALPHA 2 ADRENERGIC RECEPTOR AGONIST',
#  'ALPHA-1 BLOCKERS',
#  'ALPHA-ADRENERGIC AGONIST',
#  'ALPHA-ADRENOCEPTOR BLOCKER',
#  'AMEBIASIS',
#  'AMEBICIDES',
#  'AMINO ACIDS',
#  'AMINO ACIDS & VITAMINS',
#  'AMINO ACIDS & VITAMINS ',
#  'AMLODIPINE USP 10MG',
#  'ANAESTHETICS',
#  'ANALGESIC CREAM',
#  'ANALGESICS',
#  'ANALGESICS & ANTIHISTAMINES',
#  'ANALGESICS & ANTIHISTAMINES & ANTITUSSIVES & CNS STIMULANTS',
#  'ANALGESICS & ANTIHISTAMINES & VITAMINS',
#  'ANALGESICS & ANTIHISTAMINS & VITAMINS',
#  'ANALGESICS & ANTINEURALGIA',
#  'ANALGESICS & ANTINFLAMMATORY',
#  'ANALGESICS & ANTIPYRETIC',
#  'ANALGESICS & NASAL DECONGESTANT & MUCOLYTIC',
#  'ANALGESICS & NASAL DECONGESTANTS',
#  'ANALGESICS & NSAIDs',
#  'ANGIOTENSIN RECEPTOR BLOCKER',
#  'ANGIOTENSIN-CONVERTING ENZYME INHIBITOR',
#  'ANGIOTENSIN-II RECEPTOR ANTAGONIST',
# ...

# %%
len(pharmList)
# Out:
# 432
