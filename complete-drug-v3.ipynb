# %%
import pandas as pd
import numpy as np

# %%
drug = pd.read_excel('new-drug-v2.xlsx',parse_dates=["APPROVAL DATE", "EXPIRY DATE"])

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
drug
# Out:
#                                            PRODUCT NAME    NAFDAC  \
# 0                                       MIM TONIC SYRUP   04-1194
# 1            DR MEYER'S FEROTAL EXTRA BLOOD TONIC SYRUP   04-7927
# 2                                         JAWARON TONIC   04-2037
# 3                             AVROTON BLOOD TONIC SYRUP   A4-5661
# 4                                    SOFAMAG SUSPENSION  A11-0251
# ...                                                 ...       ...
# 5849                             ENHANZ SOFTGEL CAPSULE   A4-5163
# 5850              CROWTHER COD LIVER OIL 1000MG CAPSULE   A4-4282
# 5851  GINTAMINE MULTIVITAMIN & MULTIVITAMIN MINERAL ...   A4-4281
# 5852          TESTYMIN AMINO ACIDS & MULTIVITAMIN SYRUP   B4-5007
# 5853                  TESTYFER AMINO ACIDS & IRON SYRUP   B4-7896
#
#                          BRAND  \
# 0                          MIM
# 1     DR MEYER'S FEROTAL EXTRA
# 2                      JAWARON
# 3                      AVROTON
# ...

# %%
drug.iloc[3172]
# Out:
# PRODUCT NAME                                      OSWORTH PARACETAMOL TABLET
# NAFDAC                                                               A4-4053
# BRAND                                                                OSWORTH
# GENERICS                                                         PARACETAMOL
# PRODUCT CATEGORY                                                  HUMAN DRUG
# PHARM CLASS                                          ANALGESIC & ANTIPYRETIC
# ROUTE OF ADMINISTRATION                                                 ORAL
# GROUP                                                                   DRUG
# ACTIVE ING                                                       PARACETAMOL
# STRENGTH                                                               500MG
# PRESENTATION                                                TABLET, 1 X 1000
# DOSAGE FORM                                                           TABLET
# ...

# %%
route = drug.loc[drug['ROUTE OF ADMINISTRATION'].isnull(), :]

# %%
route
# Out:
#                            PRODUCT NAME   NAFDAC   BRAND          GENERICS  \
# 2637  JANIFY PROMETHAZINE HCL INJECTION  B4-9137  JANIFY  PROMETHAZINE HCL
#
#      PRODUCT CATEGORY   PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 2637       HUMAN DRUG  ANTI- EMETIC                     NaN  DRUG
#
#                       ACTIVE ING   STRENGTH  ...          MARKETING CATEGORY  \
# 2637  PROMETHAZINE HCL 50MG/ 2ML  50MG/ 2ML  ...  PRESCRIPTION ONLY MEDICINE
#
#        APPROVED INDICATION     NAME OF APPLICANT  \
# 2637  MANAGEMENT OF EMESIS  JANIFY PHARM CO. LTD
#
#                              APPLICANT ADDRESS  COUNTRY  \
# 2637  2, ADESOYE STREET, MANDA MARYLAND, LAGOS  NIGERIA
#
#                                    NAME OF MANUFACTURER  \
# 2637  TIANJIN KINGYORK GROUP HUBEI TIANYAO PHARMACEU...
#
#                                    MANUFACTURER ADDRESS COUNTRY.1  \
# 2637  NO. 99, HANJIANG BEI ROAD, XIANGYANG, HUBEI, C...     CHINA
#
#             APPROVAL DATE EXPIRY DATE
# ...

# %%
drug.iloc[2637,:]
# Out:
# PRODUCT NAME                               JANIFY PROMETHAZINE HCL INJECTION
# NAFDAC                                                               B4-9137
# BRAND                                                                 JANIFY
# GENERICS                                                    PROMETHAZINE HCL
# PRODUCT CATEGORY                                                  HUMAN DRUG
# PHARM CLASS                                                     ANTI- EMETIC
# ROUTE OF ADMINISTRATION                                                  NaN
# GROUP                                                                   DRUG
# ACTIVE ING                                        PROMETHAZINE HCL 50MG/ 2ML
# STRENGTH                                                           50MG/ 2ML
# PRESENTATION                                      INJECTION/AMPOULE 2ML X 10
# DOSAGE FORM                                                        INJECTION
# ...

# %%
updated_df = drug

# %%
updated_df['date_time'] = pd.to_datetime(updated_df['APPROVAL DATE'], errors='coerce')
print(updated_df[updated_df.date_time.isnull()])
# Out:
#                                    PRODUCT NAME   NAFDAC      BRAND  \
# 1293                         SPEDRA 100 TABLETS  B4-7413     SPEDRA
# 3860                                VOLIGEL GEL  C4-0013    VOLIGEL
# 3862                           WATE-ON EMULSION  04-1232    WATE-ON
# 3969                          OCEXONE INJECTION  A4-9169    OCEXONE
# 3973                         CEDFLOXAC INFUSION  B4-4736  CEDFLOXAC
# 5638  HANBET METRONIDAZOLE 500MG/100ML INFUSION  A4-8794     HANBET
# 5738                             AVROMAL TABLET  A4-4050    AVROMAL
#
#                          GENERICS PRODUCT CATEGORY  \
# 1293                     AVANAFIL       HUMAN DRUG
# 3860      DICLOFENAC DIETHYLAMINE       HUMAN DRUG
# 3862  NICOTINAMIDE+ MULTIVITAMINS       HUMAN DRUG
# 3969                  CEFTRIAXONE       HUMAN DRUG
# 3973                CIPROFLOXACIN       HUMAN DRUG
# 5638    METRONIDAZOLE 500MG/100ML       HUMAN DRUG
# 5738     ARTEMETHER, LUMEFANTRINE       HUMAN DRUG
#
# ...

# %%
type(updated_df['date_time'])
# Out:
# pandas.core.series.Series

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
updated_df.iloc[1293,21]
# Out:
# 'FRANCE'

# %%
drug[drug['APPROVAL DATE'] == 'FRANCE']
# Out:
#             PRODUCT NAME   NAFDAC   BRAND  GENERICS PRODUCT CATEGORY  \
# 1293  SPEDRA 100 TABLETS  B4-7413  SPEDRA  AVANAFIL       HUMAN DRUG
#
#                              PHARM CLASS ROUTE OF ADMINISTRATION  GROUP  \
# 1293  TYPE 5 PHOSPHODIESTERASE INHIBITOR                    ORAL  DRUGS
#
#           ACTIVE ING STRENGTH  ...                APPROVED INDICATION  \
# 1293  AVANAFIL 100MG    100MG  ...  TREATMENT OF ERECTILE DYSFUNCTION
#
#                  NAME OF APPLICANT  \
# 1293  SANOFI AVENTIS NIG. LIMITED.
#
#                                       APPLICANT ADDRESS  COUNTRY  \
# 1293  PLOT 120513, AMODU OJIKULU STREET, VICTORIA IS...  NIGERIA
#
#             NAME OF MANUFACTURER  \
# 1293  SANOFI WINTHROP INDUSTRIE,
#
#                                    MANUFACTURER ADDRESS COUNTRY.1  \
# 1293  1, RUE DE LA VIERGE, AMBARES-ET-LAGRAVE 33565 ...    FRANCE
#
#      APPROVAL DATE EXPIRY DATE date_time
# 1293        FRANCE  2022-08-07       NaT
#
# [1 rows x 24 columns]

# %%
updated_df.iloc[1293, :]
# Out:
# PRODUCT NAME                                              SPEDRA 100 TABLETS
# NAFDAC                                                               B4-7413
# BRAND                                                                 SPEDRA
# GENERICS                                                            AVANAFIL
# PRODUCT CATEGORY                                                  HUMAN DRUG
# PHARM CLASS                               TYPE 5 PHOSPHODIESTERASE INHIBITOR
# ROUTE OF ADMINISTRATION                                                 ORAL
# GROUP                                                                  DRUGS
# ACTIVE ING                                                    AVANAFIL 100MG
# STRENGTH                                                               100MG
# PRESENTATION                                                   TABLETS, 1X4,
# DOSAGE FORM                                                          TABLETS
# ...

# %%
# Removing the leading and trailing spaces

# %%
# %run trimming.py

# %%
updated_df = drug

# %%
drug = trim_all_columns(drug)

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
#drug.drop(['date_time'], axis=1)
# Out:
#                                            PRODUCT NAME    NAFDAC  \
# 0                                       MIM TONIC SYRUP   04-1194
# 1            DR MEYER'S FEROTAL EXTRA BLOOD TONIC SYRUP   04-7927
# 2                                         JAWARON TONIC   04-2037
# 3                             AVROTON BLOOD TONIC SYRUP   A4-5661
# 4                                    SOFAMAG SUSPENSION  A11-0251
# ...                                                 ...       ...
# 5849                             ENHANZ SOFTGEL CAPSULE   A4-5163
# 5850              CROWTHER COD LIVER OIL 1000MG CAPSULE   A4-4282
# 5851  GINTAMINE MULTIVITAMIN & MULTIVITAMIN MINERAL ...   A4-4281
# 5852          TESTYMIN AMINO ACIDS & MULTIVITAMIN SYRUP   B4-5007
# 5853                  TESTYFER AMINO ACIDS & IRON SYRUP   B4-7896
#
#                          BRAND  \
# 0                          MIM
# 1     DR MEYER'S FEROTAL EXTRA
# 2                      JAWARON
# 3                      AVROTON
# ...

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
pharmclass = drug['PHARM CLASS']

# %%
pharmclass.unique()
# Out:
# array(['NUTRITIONAL SUPPLEMENT', 'ANTACID', 'VITAMINS', 'VITAMIN',
#        'ANTISEPTIC', 'NSAID', 'ANTI-DIARRHOEA',
#        'ANALGESIC/ ANTI-HISTAMINE/ANTITUSSIVE/CNS STIMULANT', 'ANTIULCER',
#        'ANTITUSSIVE', 'ANTIDIABETES', 'ANALGESIC', 'ANTIHYPERTENSIVE',
#        'ANTIHISTAMINE', 'HAEMATINIC', 'RUBIFACIENT', 'ANTIBIOTIC',
#        'ANTIMALARIA', 'ELECTROLYTE', 'ANTIPLATELET', 'ANTIMUSCARINIC',
#        'ANTHELMINTIC', 'ANTIBACTERIAL, ANTIFUNGAL, ANTI INFLAMMATORY',
#        'DISINFECTANT AND ANTISEPTIC', 'ANTIBIOTICS', 'DIURETIC',
#        'ANALGESIC, ANTIPYRETIC AND ANTIINFLAMMATORY (NSAID)',
#        'NON STEROIDAL ANTI-INFLAMMATORY AGENT', 'ANTIDIARRHEA',
#        'ANTIBIOTRIC', 'ANTIRETROVIRAL',
#        'HISTAMINE H2 -RECEPTOR ANTAGONIST', 'BRONCHODILATOR',
#        'ANTIMALARIAL', 'OPIOID ANAGELSIC', 'ANTI-DIABETIS',
#        'ANTI-PSYCHOTIC', 'ANTITUBERCULOSIS', 'VITAMIN SUPPLEMENT',
#        'INTRAVENOUS ELECTROLYTE', 'ANTI-INFLAMMATORY, ANAGELSIC',
# ...

# %%
# Ensuring there are no spaces between separated values

# %%
# %run sac.py

# %%
pharmclass = pharmclass.apply(sap)

# %%
pharmclass.unique()
# Out:
# array(['NUTRITIONAL SUPPLEMENT', 'ANTACID', 'VITAMINS', 'VITAMIN',
#        'ANTISEPTIC', 'NSAID', 'ANTI-DIARRHOEA',
#        'ANALGESIC/ANTI-HISTAMINE/ANTITUSSIVE/CNS STIMULANT', 'ANTIULCER',
#        'ANTITUSSIVE', 'ANTIDIABETES', 'ANALGESIC', 'ANTIHYPERTENSIVE',
#        'ANTIHISTAMINE', 'HAEMATINIC', 'RUBIFACIENT', 'ANTIBIOTIC',
#        'ANTIMALARIA', 'ELECTROLYTE', 'ANTIPLATELET', 'ANTIMUSCARINIC',
#        'ANTHELMINTIC', 'ANTIBACTERIAL, ANTIFUNGAL, ANTI INFLAMMATORY',
#        'DISINFECTANT AND ANTISEPTIC', 'ANTIBIOTICS', 'DIURETIC',
#        'ANALGESIC, ANTIPYRETIC AND ANTIINFLAMMATORY (NSAID)',
#        'NON STEROIDAL ANTI-INFLAMMATORY AGENT', 'ANTIDIARRHEA',
#        'ANTIBIOTRIC', 'ANTIRETROVIRAL',
#        'HISTAMINE H2 -RECEPTOR ANTAGONIST', 'BRONCHODILATOR',
#        'ANTIMALARIAL', 'OPIOID ANAGELSIC', 'ANTI-DIABETIS',
#        'ANTI-PSYCHOTIC', 'ANTITUBERCULOSIS', 'VITAMIN SUPPLEMENT',
#        'INTRAVENOUS ELECTROLYTE', 'ANTI-INFLAMMATORY, ANAGELSIC',
# ...

# %%
route = drug['ROUTE OF ADMINISTRATION']

# %%
route.unique()
# Out:
# array(['ORAL', 'TOPICAL', 'INTRAVENOUS', 'OCULAR', 'INTRAMUSCULAR',
#        'OCULAR/OTIC', 'BUCCAL', 'INTRAMUSCULAR/INTRAVENOUS',
#        'INTRAVENOUS/INTRAMUSCULAR', 'RECTAL', 'OTIC', 'VAGINAL',
#        'CUTANEOUS', 'INTRAVENOUS/ INTRAMUSCULAR', 'OPHTHALMIC', 'NASAL',
#        'BUCCAL/ORAL', 'OPHTHALMIC/OTIC', 'BUCCAL/ ORAL',
#        'INTRAVENOUS/ INTRAMUSCULAR/ SUBCUTANEOUS',
#        'OPHTHALMIC/ OTIC/ NASAL', 'ORAL/ TOPICAL', 'SUBCUTANEOUS',
#        'INTRAMUSCULAR/ INTRAVENOUS', nan, 'INTRAVENOUS/ INTREMUSCULAR',
#        'INTRAMUSCULAR/ SUBCUTANEOUS',
#        'INTRAVENOUS/ INTREMUSCULAR/ SUBCUTANEOUS', 'INTRA ARTICULAR',
#        'SUBCUTANEOUS/ INTRAMUSCULAR', 'OPHTHALMIC/ NASAL',
#        'INTRATRACHEAL', 'INHALATION', 'GARGLE', 'INTRAVENOUS (IV) ROUTE',
#        'INTRAMUSCULAR (IM) ROUTE', 'IV ROUTE', 'IM ROUTE', 'IM/IV ROUTE',
#        'IV/IM ROUTE', 'IM/SUBCUTANEOUS ROUTE', 'IV/IM/SUBCUTANEOUS ROUTE',
# ...

# %%
drug.fillna({'ROUTE OF ADMINISTRATION':'NO ROUTE'}, inplace=True)

# %%
route = drug['ROUTE OF ADMINISTRATION']

# %%
route.unique()
# Out:
# array(['ORAL', 'TOPICAL', 'INTRAVENOUS', 'OCULAR', 'INTRAMUSCULAR',
#        'OCULAR/OTIC', 'BUCCAL', 'INTRAMUSCULAR/INTRAVENOUS',
#        'INTRAVENOUS/INTRAMUSCULAR', 'RECTAL', 'OTIC', 'VAGINAL',
#        'CUTANEOUS', 'INTRAVENOUS/ INTRAMUSCULAR', 'OPHTHALMIC', 'NASAL',
#        'BUCCAL/ORAL', 'OPHTHALMIC/OTIC', 'BUCCAL/ ORAL',
#        'INTRAVENOUS/ INTRAMUSCULAR/ SUBCUTANEOUS',
#        'OPHTHALMIC/ OTIC/ NASAL', 'ORAL/ TOPICAL', 'SUBCUTANEOUS',
#        'INTRAMUSCULAR/ INTRAVENOUS', 'NO ROUTE',
#        'INTRAVENOUS/ INTREMUSCULAR', 'INTRAMUSCULAR/ SUBCUTANEOUS',
#        'INTRAVENOUS/ INTREMUSCULAR/ SUBCUTANEOUS', 'INTRA ARTICULAR',
#        'SUBCUTANEOUS/ INTRAMUSCULAR', 'OPHTHALMIC/ NASAL',
#        'INTRATRACHEAL', 'INHALATION', 'GARGLE', 'INTRAVENOUS (IV) ROUTE',
#        'INTRAMUSCULAR (IM) ROUTE', 'IV ROUTE', 'IM ROUTE', 'IM/IV ROUTE',
#        'IV/IM ROUTE', 'IM/SUBCUTANEOUS ROUTE', 'IV/IM/SUBCUTANEOUS ROUTE',
# ...

# %%
route = route.apply(sap)

# %%
route.unique()
# Out:
# array(['ORAL', 'TOPICAL', 'INTRAVENOUS', 'OCULAR', 'INTRAMUSCULAR',
#        'OCULAR/OTIC', 'BUCCAL', 'INTRAMUSCULAR/INTRAVENOUS',
#        'INTRAVENOUS/INTRAMUSCULAR', 'RECTAL', 'OTIC', 'VAGINAL',
#        'CUTANEOUS', 'OPHTHALMIC', 'NASAL', 'BUCCAL/ORAL',
#        'OPHTHALMIC/OTIC', 'INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS',
#        'OPHTHALMIC/OTIC/NASAL', 'ORAL/TOPICAL', 'SUBCUTANEOUS',
#        'NO ROUTE', 'INTRAVENOUS/INTREMUSCULAR',
#        'INTRAMUSCULAR/SUBCUTANEOUS',
#        'INTRAVENOUS/INTREMUSCULAR/SUBCUTANEOUS', 'INTRA ARTICULAR',
#        'SUBCUTANEOUS/INTRAMUSCULAR', 'OPHTHALMIC/NASAL', 'INTRATRACHEAL',
#        'INHALATION', 'GARGLE', 'INTRAVENOUS (IV) ROUTE',
#        'INTRAMUSCULAR (IM) ROUTE', 'IV ROUTE', 'IM ROUTE', 'IM/IV ROUTE',
#        'IV/IM ROUTE', 'IM/SUBCUTANEOUS ROUTE', 'IV/IM/SUBCUTANEOUS ROUTE',
#        'IM/IV/SUBCUTANEOUS', 'TOPICAL NSAID/RUBAFACIENT', 'OCCULAR',
#        'PARENTERALS'], dtype=object)

# %%
route = np.where(route.str.contains('INTREMUSCULAR'),'INTRAMUSCULAR',route)

# %%
type(route)
# Out:
# numpy.ndarray

# %%
type(drug)
# Out:
# pandas.core.frame.DataFrame

# %%
drug.loc[:, 'ROUTE OF ADMINISTRATION'] = drug['ROUTE OF ADMINISTRATION'].apply(sap)

# %%
drug['ROUTE OF ADMINISTRATION'] = np.where(drug['ROUTE OF ADMINISTRATION'].str.contains('INTREMUSCULAR'), 'INTRAMUSCULAR', drug['ROUTE OF ADMINISTRATION'])

# %%
route = drug['ROUTE OF ADMINISTRATION']

# %%
route.unique()
# Out:
# array(['ORAL', 'TOPICAL', 'INTRAVENOUS', 'OCULAR', 'INTRAMUSCULAR',
#        'OCULAR/OTIC', 'BUCCAL', 'INTRAMUSCULAR/INTRAVENOUS',
#        'INTRAVENOUS/INTRAMUSCULAR', 'RECTAL', 'OTIC', 'VAGINAL',
#        'CUTANEOUS', 'OPHTHALMIC', 'NASAL', 'BUCCAL/ORAL',
#        'OPHTHALMIC/OTIC', 'INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS',
#        'OPHTHALMIC/OTIC/NASAL', 'ORAL/TOPICAL', 'SUBCUTANEOUS',
#        'NO ROUTE', 'INTRAMUSCULAR/SUBCUTANEOUS', 'INTRA ARTICULAR',
#        'SUBCUTANEOUS/INTRAMUSCULAR', 'OPHTHALMIC/NASAL', 'INTRATRACHEAL',
#        'INHALATION', 'GARGLE', 'INTRAVENOUS (IV) ROUTE',
#        'INTRAMUSCULAR (IM) ROUTE', 'IV ROUTE', 'IM ROUTE', 'IM/IV ROUTE',
#        'IV/IM ROUTE', 'IM/SUBCUTANEOUS ROUTE', 'IV/IM/SUBCUTANEOUS ROUTE',
#        'IM/IV/SUBCUTANEOUS', 'TOPICAL NSAID/RUBAFACIENT', 'OCCULAR',
#        'PARENTERALS'], dtype=object)

# %%
drug["ROUTE OF ADMINISTRATION"].replace({"INTRAVENOUS (IV) ROUTE":"INTRAVENOUS", "INTRA ARTICULAR":"INTRA-ARTICULAR","IV ROUTE":"INTRAVENOUS","IM ROUTE":"INTRAMUSCULAR","INTRAMUSCULAR (IM) ROUTE":"INTRAMUSCULAR","IM/IV ROUTE":"INTRAMUSCULAR/INTRAVENOUS","IV/IM ROUTE":"INTRAVENOUS/INTRAMUSCULAR","IM/SUBCUTANEOUS ROUTE":"INTRAMUSCULAR/SUBCUTANEOUS","IV/IM/SUBCUTANEOUS ROUTE":"INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS","IM/IV/SUBCUTANEOUS":"INTRAMUSCULAR/INTRAVENOUS/SUBCUTANEOUS"},inplace=True)

# %%
route = drug['ROUTE OF ADMINISTRATION']

# %%
route.unique()
# Out:
# array(['ORAL', 'TOPICAL', 'INTRAVENOUS', 'OCULAR', 'INTRAMUSCULAR',
#        'OCULAR/OTIC', 'BUCCAL', 'INTRAMUSCULAR/INTRAVENOUS',
#        'INTRAVENOUS/INTRAMUSCULAR', 'RECTAL', 'OTIC', 'VAGINAL',
#        'CUTANEOUS', 'OPHTHALMIC', 'NASAL', 'BUCCAL/ORAL',
#        'OPHTHALMIC/OTIC', 'INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS',
#        'OPHTHALMIC/OTIC/NASAL', 'ORAL/TOPICAL', 'SUBCUTANEOUS',
#        'NO ROUTE', 'INTRAMUSCULAR/SUBCUTANEOUS', 'INTRA-ARTICULAR',
#        'SUBCUTANEOUS/INTRAMUSCULAR', 'OPHTHALMIC/NASAL', 'INTRATRACHEAL',
#        'INHALATION', 'GARGLE', 'INTRAMUSCULAR/INTRAVENOUS/SUBCUTANEOUS',
#        'TOPICAL NSAID/RUBAFACIENT', 'OCCULAR', 'PARENTERALS'],
#       dtype=object)

# %%
route.nunique()
# Out:
# 33

# %%
drug.loc[:, 'PHARM CLASS'] = drug['PHARM CLASS'].apply(sap)

# %%
pharmclass = drug['PHARM CLASS']

# %%
pharmclass.unique()
# Out:
# array(['NUTRITIONAL SUPPLEMENT', 'ANTACID', 'VITAMINS', 'VITAMIN',
#        'ANTISEPTIC', 'NSAID', 'ANTI-DIARRHOEA',
#        'ANALGESIC/ANTI-HISTAMINE/ANTITUSSIVE/CNS STIMULANT', 'ANTIULCER',
#        'ANTITUSSIVE', 'ANTIDIABETES', 'ANALGESIC', 'ANTIHYPERTENSIVE',
#        'ANTIHISTAMINE', 'HAEMATINIC', 'RUBIFACIENT', 'ANTIBIOTIC',
#        'ANTIMALARIA', 'ELECTROLYTE', 'ANTIPLATELET', 'ANTIMUSCARINIC',
#        'ANTHELMINTIC', 'ANTIBACTERIAL, ANTIFUNGAL, ANTI INFLAMMATORY',
#        'DISINFECTANT AND ANTISEPTIC', 'ANTIBIOTICS', 'DIURETIC',
#        'ANALGESIC, ANTIPYRETIC AND ANTIINFLAMMATORY (NSAID)',
#        'NON STEROIDAL ANTI-INFLAMMATORY AGENT', 'ANTIDIARRHEA',
#        'ANTIBIOTRIC', 'ANTIRETROVIRAL',
#        'HISTAMINE H2 -RECEPTOR ANTAGONIST', 'BRONCHODILATOR',
#        'ANTIMALARIAL', 'OPIOID ANAGELSIC', 'ANTI-DIABETIS',
#        'ANTI-PSYCHOTIC', 'ANTITUBERCULOSIS', 'VITAMIN SUPPLEMENT',
#        'INTRAVENOUS ELECTROLYTE', 'ANTI-INFLAMMATORY, ANAGELSIC',
# ...

# %%
pharmaclass = pharmclass.to_list()

# %%
routpharm = drug[['ROUTE OF ADMINISTRATION', 'PHARM CLASS']]

# %%
type(routpharm)
# Out:
# pandas.core.frame.DataFrame

# %%
routpharm.to_excel('routpharm.xlsx')

# %%
pharmclass.nunique()
# Out:
# 786

# %%
type(pharmaclass)
# Out:
# list

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
from fuzzywuzzy import process, fuzz

# %%
process.extract("ANTIFUNGAL/ANTIBACTERIAL/ANTI-INFLAMMATORY", ["ANTIFUNGAL", "ANTIFUNGAL/ANTIBACTERAIL/ANTI-INFLAMMATORY", "ANTIBACTERIAL, ANTIFUNGAL, ANTI INFLAMMATORY"])
# Out:
# [('ANTIFUNGAL/ANTIBACTERAIL/ANTI-INFLAMMATORY', 98),
#  ('ANTIBACTERIAL, ANTIFUNGAL, ANTI INFLAMMATORY', 95),
#  ('ANTIFUNGAL', 90)]

# %%
# %who
# Out:
# drug	 fuzz	 np	 pd	 pharmaclass	 pharmclass	 process	 route	 routpharm
# sap	 trim_all_columns	 updated_df

# %%
drug[drug['ROUTE OF ADMINISTRATION'] == 'NO ROUTE']
# Out:
#                            PRODUCT NAME   NAFDAC   BRAND          GENERICS  \
# 2637  JANIFY PROMETHAZINE HCL INJECTION  B4-9137  JANIFY  PROMETHAZINE HCL
#
#      PRODUCT CATEGORY   PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 2637       HUMAN DRUG  ANTI- EMETIC                NO ROUTE  DRUG
#
#                       ACTIVE ING   STRENGTH  ...   APPROVED INDICATION  \
# 2637  PROMETHAZINE HCL 50MG/ 2ML  50MG/ 2ML  ...  MANAGEMENT OF EMESIS
#
#          NAME OF APPLICANT                         APPLICANT ADDRESS  COUNTRY  \
# 2637  JANIFY PHARM CO. LTD  2, ADESOYE STREET, MANDA MARYLAND, LAGOS  NIGERIA
#
#                                    NAME OF MANUFACTURER  \
# 2637  TIANJIN KINGYORK GROUP HUBEI TIANYAO PHARMACEU...
#
#                                    MANUFACTURER ADDRESS COUNTRY.1  \
# 2637  NO. 99, HANJIANG BEI ROAD, XIANGYANG, HUBEI, C...     CHINA
#
#             APPROVAL DATE EXPIRY DATE  date_time
# 2637  2018-10-31 00:00:00  2023-10-30 2018-10-31
#
# ...

# %%
drug.iat[2637,6]= 'PARENTERAL'

# %%
# %run null_values.py

# %%
null_strength = drug.loc[drug['STRENGTH'].isnull(),:]

# %%
null_presentation = drug.loc[drug['PRESENTATION'].isnull(),:]

# %%
null_dosage = drug.loc[drug['DOSAGE FORM'].isnull(),:]

# %%
null_packsize = drug.loc[drug['PACK SIZE'].isnull(), :]

# %%
null_MC = drug.loc[drug['MARKETING CATEGORY'].isnull(), :]

# %%
null_approvedindication = drug.loc[drug['APPROVED INDICATION'].isnull(), :]

# %%
null_applicant = drug.loc[drug['NAME OF APPLICANT'].isnull(), :]

# %%
null_applicant.to_excel('cleaning_applicant.xlsx')

# %%
null_addressapplicant = drug.loc[drug['APPLICANT ADDRESS'].isnull(), :]

# %%
nullcols(drug)
# Out:
# STRENGTH               130
# PRESENTATION            26
# DOSAGE FORM              8
# PACK SIZE               12
# MARKETING CATEGORY       1
# APPROVED INDICATION      2
# NAME OF APPLICANT       23
# APPLICANT ADDRESS        2
# date_time                7
# dtype: int64

# %%
null_applicant
# Out:
#                                           PRODUCT NAME    NAFDAC  \
# 633                                   JADURON CAPSULES   A4-4061
# 1348  BIORAJ PARACETAMOL & DICLOFENAC POTASSIUM TABLET  A11-0323
# 1349                              JAWALK ORAL SOLUTION  A11-0138
# 1350                                    PECRITON SYRUP  A11-0325
# 1351                                   GARYLONG TABLET   B4-3550
# 1352     ANNMOX AMOXICILLIN POWDER FOR ORAL SUSPENSION  A11-0326
# 1353                                     MOBITIN SYRUP  A11-0115
# 1354                                 MYZITH 500 TABLET  A11-0327
# 1355                                    VARSPAR TABLET   A4-5476
# 1356                                      NESTIN CREAM   04-6365
# 1357                                    VARSPAR TABLET   A4-5475
# 1358                                   BOND CPM TABLET   04-0490
# 1359                                IRON BOND IB TONIC   04-1833
# ...

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
not_a_date = drug.loc[drug['date_time'].isnull(), :]

# %%
with pd.ExcelWriter('cleaning_drug.xlsx') as writer1:
    null_strength.to_excel(writer1, sheet_name = 'strength')
    null_presentation.to_excel(writer1, sheet_name = 'presentation')
    null_dosage.to_excel(writer1, sheet_name = 'dosage-form')
    null_packsize.to_excel(writer1, sheet_name = 'packsize')
    null_MC.to_excel(writer1, sheet_name = 'marketing-category')
    null_approvedindication.to_excel(writer1, sheet_name = 'approved-indication')
    null_applicant.to_excel(writer1, sheet_name = 'applicant')
    null_addressapplicant.to_excel(writer1, sheet_name = 'address-applicant')
    not_a_date.to_excel(writer1, sheet_name = 'missing-approval-date')

# %%
null_approvedindication
# Out:
#               PRODUCT NAME   NAFDAC      BRAND   GENERICS PRODUCT CATEGORY  \
# 3579   MIDAZOLAM INJECTION  B4-9661  MIDAZOLAM  MIDAZOLAM       HUMAN DRUG
# 4100  GRAPROFEN SUSPENSION  A4-8078  GRAPROFEN  IBUPROFEN       HUMAN DRUG
#
#      PHARM CLASS    ROUTE OF ADMINISTRATION GROUP    ACTIVE ING   STRENGTH  \
# 3579    SEDATIVE  INTRAVENOUS/INTRAMUSCULAR  DRUG     MIDAZOLAM       15MG
# 4100       NSAID                       ORAL  DRUG  IBUPROFEN BP  100MG/5ML
#
#       ... APPROVED INDICATION         NAME OF APPLICANT  \
# 3579  ...                 NaN  EXCEL CHARIS PHARMA. LTD
# 4100  ...                 NaN     GRAMS PHARMACEUTICALS
#
#                                       APPLICANT ADDRESS  COUNTRY  \
# 3579  10, UNITY DRIVE, UNITY ESTATE, OLUYOLE EXTENSI...  NIGERIA
# 4100     GRAMS PLAZA 76, ROYCEE ROAD, OWERRI, IMO STATE  NIGERIA
#
#                        NAME OF MANUFACTURER  \
# 3579      VERVE HUMAN CARE LABORATORIES LTD
# 4100  CIRON DRUGS & PHARMACEUTICALS PVT LTD
#
# ...

# %%
not_a_date
# Out:
#                                    PRODUCT NAME   NAFDAC      BRAND  \
# 1293                         SPEDRA 100 TABLETS  B4-7413     SPEDRA
# 3860                                VOLIGEL GEL  C4-0013    VOLIGEL
# 3862                           WATE-ON EMULSION  04-1232    WATE-ON
# 3969                          OCEXONE INJECTION  A4-9169    OCEXONE
# 3973                         CEDFLOXAC INFUSION  B4-4736  CEDFLOXAC
# 5638  HANBET METRONIDAZOLE 500MG/100ML INFUSION  A4-8794     HANBET
# 5738                             AVROMAL TABLET  A4-4050    AVROMAL
#
#                          GENERICS PRODUCT CATEGORY  \
# 1293                     AVANAFIL       HUMAN DRUG
# 3860      DICLOFENAC DIETHYLAMINE       HUMAN DRUG
# 3862  NICOTINAMIDE+ MULTIVITAMINS       HUMAN DRUG
# 3969                  CEFTRIAXONE       HUMAN DRUG
# 3973                CIPROFLOXACIN       HUMAN DRUG
# 5638    METRONIDAZOLE 500MG/100ML       HUMAN DRUG
# 5738     ARTEMETHER, LUMEFANTRINE       HUMAN DRUG
#
# ...

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
productCat = drug['PRODUCT CATEGORY'].unique()

# %%
productCat
# Out:
# array(['HUMAN DRUG'], dtype=object)

# %%
route = drug['ROUTE OF ADMINISTRATION'].unique()

# %%
route
# Out:
# array(['ORAL', 'TOPICAL', 'INTRAVENOUS', 'OCULAR', 'INTRAMUSCULAR',
#        'OCULAR/OTIC', 'BUCCAL', 'INTRAMUSCULAR/INTRAVENOUS',
#        'INTRAVENOUS/INTRAMUSCULAR', 'RECTAL', 'OTIC', 'VAGINAL',
#        'CUTANEOUS', 'OPHTHALMIC', 'NASAL', 'BUCCAL/ORAL',
#        'OPHTHALMIC/OTIC', 'INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS',
#        'OPHTHALMIC/OTIC/NASAL', 'ORAL/TOPICAL', 'SUBCUTANEOUS',
#        'PARENTERAL', 'INTRAMUSCULAR/SUBCUTANEOUS', 'INTRA-ARTICULAR',
#        'SUBCUTANEOUS/INTRAMUSCULAR', 'OPHTHALMIC/NASAL', 'INTRATRACHEAL',
#        'INHALATION', 'GARGLE', 'INTRAMUSCULAR/INTRAVENOUS/SUBCUTANEOUS',
#        'TOPICAL NSAID/RUBAFACIENT', 'OCCULAR', 'PARENTERALS'],
#       dtype=object)

# %%
drug.iloc[2637,:]
# Out:
# PRODUCT NAME                               JANIFY PROMETHAZINE HCL INJECTION
# NAFDAC                                                               B4-9137
# BRAND                                                                 JANIFY
# GENERICS                                                    PROMETHAZINE HCL
# PRODUCT CATEGORY                                                  HUMAN DRUG
# PHARM CLASS                                                     ANTI- EMETIC
# ROUTE OF ADMINISTRATION                                           PARENTERAL
# GROUP                                                                   DRUG
# ACTIVE ING                                        PROMETHAZINE HCL 50MG/ 2ML
# STRENGTH                                                           50MG/ 2ML
# PRESENTATION                                      INJECTION/AMPOULE 2ML X 10
# DOSAGE FORM                                                        INJECTION
# ...

# %%
null_route = drug.loc[drug['ROUTE OF ADMINISTRATION'].isnull(), :]

# %%
null_route
# Out:
# Empty DataFrame
# Columns: [PRODUCT NAME, NAFDAC, BRAND, GENERICS, PRODUCT CATEGORY, PHARM CLASS, ROUTE OF ADMINISTRATION, GROUP, ACTIVE ING, STRENGTH, PRESENTATION, DOSAGE FORM, PACK SIZE, MARKETING CATEGORY, APPROVED INDICATION, NAME OF APPLICANT, APPLICANT ADDRESS, COUNTRY, NAME OF MANUFACTURER, MANUFACTURER ADDRESS, COUNTRY.1, APPROVAL DATE, EXPIRY DATE, date_time]
# Index: []
#
# [0 rows x 24 columns]

# %%
route = drug['ROUTE OF ADMINISTRATION'].unique()

# %%
route
# Out:
# array(['ORAL', 'TOPICAL', 'INTRAVENOUS', 'OCULAR', 'INTRAMUSCULAR',
#        'OCULAR/OTIC', 'BUCCAL', 'INTRAMUSCULAR/INTRAVENOUS',
#        'INTRAVENOUS/INTRAMUSCULAR', 'RECTAL', 'OTIC', 'VAGINAL',
#        'CUTANEOUS', 'OPHTHALMIC', 'NASAL', 'BUCCAL/ORAL',
#        'OPHTHALMIC/OTIC', 'INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS',
#        'OPHTHALMIC/OTIC/NASAL', 'ORAL/TOPICAL', 'SUBCUTANEOUS',
#        'PARENTERAL', 'INTRAMUSCULAR/SUBCUTANEOUS', 'INTRA-ARTICULAR',
#        'SUBCUTANEOUS/INTRAMUSCULAR', 'OPHTHALMIC/NASAL', 'INTRATRACHEAL',
#        'INHALATION', 'GARGLE', 'INTRAMUSCULAR/INTRAVENOUS/SUBCUTANEOUS',
#        'TOPICAL NSAID/RUBAFACIENT', 'OCCULAR', 'PARENTERALS'],
#       dtype=object)

# %%
type(route)
# Out:
# numpy.ndarray

# %%
route = drug['ROUTE OF ADMINISTRATION'].unique()

# %%
route
# Out:
# array(['ORAL', 'TOPICAL', 'INTRAVENOUS', 'OCULAR', 'INTRAMUSCULAR',
#        'OCULAR/OTIC', 'BUCCAL', 'INTRAMUSCULAR/INTRAVENOUS',
#        'INTRAVENOUS/INTRAMUSCULAR', 'RECTAL', 'OTIC', 'VAGINAL',
#        'CUTANEOUS', 'OPHTHALMIC', 'NASAL', 'BUCCAL/ORAL',
#        'OPHTHALMIC/OTIC', 'INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS',
#        'OPHTHALMIC/OTIC/NASAL', 'ORAL/TOPICAL', 'SUBCUTANEOUS',
#        'PARENTERAL', 'INTRAMUSCULAR/SUBCUTANEOUS', 'INTRA-ARTICULAR',
#        'SUBCUTANEOUS/INTRAMUSCULAR', 'OPHTHALMIC/NASAL', 'INTRATRACHEAL',
#        'INHALATION', 'GARGLE', 'INTRAMUSCULAR/INTRAVENOUS/SUBCUTANEOUS',
#        'TOPICAL NSAID/RUBAFACIENT', 'OCCULAR', 'PARENTERALS'],
#       dtype=object)

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5853 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5846 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5853 non-null   object
# ...

# %%
route = list(route)

# %%
routes = pd.DataFrame(route, columns=['Route of Administration'])

# %%
routes.to_excel('route-admin.xlsx', index=False)

# %%
print(routes)
# Out:
#                    Route of Administration
# 0                                     ORAL
# 1                                  TOPICAL
# 2                              INTRAVENOUS
# 3                                   OCULAR
# 4                            INTRAMUSCULAR
# 5                              OCULAR/OTIC
# 6                                   BUCCAL
# 7                INTRAMUSCULAR/INTRAVENOUS
# 8                INTRAVENOUS/INTRAMUSCULAR
# 9                                   RECTAL
# 10                                    OTIC
# 11                                 VAGINAL
# 12                               CUTANEOUS
# 13                              OPHTHALMIC
# 14                                   NASAL
# 15                             BUCCAL/ORAL
# 16                         OPHTHALMIC/OTIC
# 17  INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS
# 18                   OPHTHALMIC/OTIC/NASAL
# 19                            ORAL/TOPICAL
# 20                            SUBCUTANEOUS
# ...

# %%
#drug = drug.drop(['date_time'], axis = 1)

# %%
type(drug)
# Out:
# pandas.core.frame.DataFrame

# %%
group = drug['GROUP']

# %%
type(group)
# Out:
# pandas.core.series.Series

# %%
group.unique()
# Out:
# array(['DRUGS', 'DRUG', 'ENTS', 'MOALES', 'SE NE INJECTION', 'DRUIG',
#        'DRUC', 'DRG', 'DROG'], dtype=object)

# %%
groups = list(group)

# %%
group_dictionary = dict.fromkeys(groups, "DRUG")

# %%
drug["GROUP"].replace(group_dictionary, inplace=True)

# %%
group = drug['GROUP']

# %%
group.unique()
# Out:
# array(['DRUG'], dtype=object)

# %%
dose = drug['DOSAGE FORM']

# %%
dose.unique()
# Out:
# array(['SYRUP', 'SUSPENSION', 'SOLUTION', 'LIQUID', 'CAPSULE,', 'POWDER,',
#        'TABLET', 'CAPLET', 'CAPSULES', 'OINTMENT', 'POWDER', 'CREAM',
#        'CAPSULE', 'DROPS', 'EMULSION', 'TABLETS', 'CAPLETS', 'INJECTION',
#        'ORAL POWDER', 'DISPERSIBLE TABLET', 'CHEWABLE TABLET',
#        'SOFT GELS', 'SPRAY', 'POWDER FOR ORAL SUSPENSION',
#        'SOFTGEL CAPSULES', 'EYE DROP', 'POWDER FOR INJECTION',
#        'POWDER FOR ORAL SOLUTION', 'SYRUP,', 'DISPERSIBLE TABLETS', 'GEL',
#        'LOZENGES', 'INHALER', 'OPHTHALMIC SOLUTION', 'ORAL SOLUTION',
#        'SOFT GEL CAPSULES', 'EYE/EAR DROPS', 'SUPPOSITORIES',
#        'INJECTABLE LIQUID', 'POWDERFOR INJECTION', 'LOTION',
#        'POWDER FOR SUSPENSION', 'ORAL SUSPENSIONL', 'INJECTABLE',
#        'EAR DROP', 'POWDER&TABLETS', 'EYE DROPS', 'CAPSULES & TABLETS',
#        'INFUSION', 'INJECTION,', 'TABLETS/', 'PESSARIES', 'BOLUS',
#        'Missing Dosage', 'EXT PREP', 'AEROSOL',
# ...

# %%
pd.set_option('display.max_column', None)
drug.loc[drug['DOSAGE FORM'] == 'INJECTION, 2 X 5']
# Out:
# Empty DataFrame
# Columns: [PRODUCT NAME, NAFDAC, BRAND, GENERICS, PRODUCT CATEGORY, PHARM CLASS, ROUTE OF ADMINISTRATION, GROUP, ACTIVE ING, STRENGTH, PRESENTATION, DOSAGE FORM, PACK SIZE, MARKETING CATEGORY, APPROVED INDICATION, NAME OF APPLICANT, APPLICANT ADDRESS, COUNTRY, NAME OF MANUFACTURER, MANUFACTURER ADDRESS, COUNTRY.1, APPROVAL DATE, EXPIRY DATE, date_time]
# Index: []

# %%
drug.iat[1810,11] = 'INJECTION'

# %%
drug.fillna({'DOSAGE FORM':'Missing Dosage'}, inplace=True)

# %%
drug.loc[:, 'DOSAGE FORM'] = drug['DOSAGE FORM'].apply(sap)

# %%
drug.loc[drug['DOSAGE FORM'] == 'Missing Dosage']
# Out:
#                 PRODUCT NAME   NAFDAC      BRAND  \
# 869            BRUXINE 50GMS  04-3514    BRUXINE
# 870   VAMI'S VITAMINS POWDER  04-8310     VAMI'S
# 1744                GENPAYNE  B4-6775   GENPAYNE
# 2474        SALBUTAMOL 100MG  B4-8493  UNBRANDED
#
#                                            GENERICS PRODUCT CATEGORY  \
# 869                                  OXYTETACYCLINE       HUMAN DRUG
# 870            VITAMINS, ELECTROLYTES , AMINO ACIDS       HUMAN DRUG
# 1744  PARACETAMOL, DICLOFENAC SODIUM, CHLORZOXAZONE       HUMAN DRUG
# 2474                                     SALBUTAMOL       HUMAN DRUG
#
#              PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 869           ANTIBIOTIC                    ORAL  DRUG
# 870   DIETARY SUPPLEMENT                    ORAL  DRUG
# 1744     NSAID/ANALGESIC                    ORAL  DRUG
# 2474     BRONCHODILATORS                    ORAL  DRUG
#
#                                              ACTIVE ING            STRENGTH  \
# ...

# %%
drug.iat[632,11] = 'SYRUP'

# %%
doses = list(dose.unique())

# %%
type(doses)
# Out:
# list

# %%
dose = pd.DataFrame(doses, columns=['DOSAGE FORM'])

# %%
nullcols(drug)
# Out:
# STRENGTH               130
# PRESENTATION            26
# PACK SIZE               12
# MARKETING CATEGORY       1
# APPROVED INDICATION      2
# NAME OF APPLICANT       23
# APPLICANT ADDRESS        2
# date_time                7
# dtype: int64

# %%
null_dosage
# Out:
# Empty DataFrame
# Columns: [PRODUCT NAME, NAFDAC, BRAND, GENERICS, PRODUCT CATEGORY, PHARM CLASS, ROUTE OF ADMINISTRATION, GROUP, ACTIVE ING, STRENGTH, PRESENTATION, DOSAGE FORM, PACK SIZE, MARKETING CATEGORY, APPROVED INDICATION, NAME OF APPLICANT, APPLICANT ADDRESS, COUNTRY, NAME OF MANUFACTURER, MANUFACTURER ADDRESS, COUNTRY.1, APPROVAL DATE, EXPIRY DATE, date_time]
# Index: []

# %%
pharmclass = drug['PHARM CLASS'].unique()

# %%
pharmclass = list(pharmclass)

# %%
pharma = pd.DataFrame(pharmclass, columns=['PHARM CLASS'])

# %%
mc = drug['MARKETING CATEGORY']

# %%
mc.unique()
# Out:
# array(['OTC', 'POM', 'OVER THE COUNTER', 'PRESCRIPTION ONLY MEDICINE',
#        'PRESCRIPTION ONLY MEDICINES', 'OVER THE COUNTER (OTC)',
#        'IBUPROFEN 400MG', 'TAMSULOSIN HCL 0.4MG',
#        'PRECRIPTION ONLY MEDICINE',
#        'RELIEF OF PAIN AND FEVERISH CONDITIONS', 'FOR DISINFECTION',
#        'TREATMENT OF SCURVY AND VITAMIN C DEFICIENCY',
#        'HOUSEHOLD DISINFECTION', 'RELIEF FROM PAIN & FEVERISH CONDITIONS',
#        'MANAGEMENT OF DIABETES MELLITUS',
#        'TREATMENT OF ANAEROBIC BACTERIAL INFECTIONS',
#        'TREATMENT OF IRON DEFICIENCY', 'TREATMENT OF COUGH',
#        'ANALGESIA FOR MINOR MUSCLE/JOINT PAIN',
#        'RELIEF OF HYPER-ACIDITY, INDIGESTION, HEART BURN & REFLUX GAS.',
#        'FLUID & ELECTROLYTE REPLACEMENT AND PROVISION OF ENERGY',
#        'RELIEF OF COUGH', 'RELIEF OF HYPER-ACIDITY, INDIGESTION',
#        'IRON DEFICIENCY ANAEMIA',
#        'TREATMENT OF PAIN AND FEVERISH CONDITIONS',
# ...

# %%
marketingCat = list(mc.unique())

# %%
marketingCat
# Out:
# ['OTC',
#  'POM',
#  'OVER THE COUNTER',
#  'PRESCRIPTION ONLY MEDICINE',
#  'PRESCRIPTION ONLY MEDICINES',
#  'OVER THE COUNTER (OTC)',
#  'IBUPROFEN 400MG',
#  'TAMSULOSIN HCL 0.4MG',
#  'PRECRIPTION ONLY MEDICINE',
#  'RELIEF OF PAIN AND FEVERISH CONDITIONS',
#  'FOR DISINFECTION',
#  'TREATMENT OF SCURVY AND VITAMIN C DEFICIENCY',
#  'HOUSEHOLD DISINFECTION',
#  'RELIEF FROM PAIN & FEVERISH CONDITIONS',
#  'MANAGEMENT OF DIABETES MELLITUS',
#  'TREATMENT OF ANAEROBIC BACTERIAL INFECTIONS',
#  'TREATMENT OF IRON DEFICIENCY',
#  'TREATMENT OF COUGH',
#  'ANALGESIA FOR MINOR MUSCLE/JOINT PAIN',
#  'RELIEF OF HYPER-ACIDITY, INDIGESTION, HEART BURN & REFLUX GAS.',
#  'FLUID & ELECTROLYTE REPLACEMENT AND PROVISION OF ENERGY',
#  'RELIEF OF COUGH',
#  'RELIEF OF HYPER-ACIDITY, INDIGESTION',
#  'IRON DEFICIENCY ANAEMIA',
#  'TREATMENT OF PAIN AND FEVERISH CONDITIONS',
#  'PREVENTION AND TREATMENT OF NUTRITIONAL DEFICIENCIES',
#  'PRESCRIPTION ONLY MEDICNE',
# ...

# %%
null_MC
# Out:
# Empty DataFrame
# Columns: [PRODUCT NAME, NAFDAC, BRAND, GENERICS, PRODUCT CATEGORY, PHARM CLASS, ROUTE OF ADMINISTRATION, GROUP, ACTIVE ING, STRENGTH, PRESENTATION, DOSAGE FORM, PACK SIZE, MARKETING CATEGORY, APPROVED INDICATION, NAME OF APPLICANT, APPLICANT ADDRESS, COUNTRY, NAME OF MANUFACTURER, MANUFACTURER ADDRESS, COUNTRY.1, APPROVAL DATE, EXPIRY DATE, date_time]
# Index: []

# %%
drug.fillna({'MARKETING CATEGORY':'OVER THE COUNTER (OTC)'}, inplace=True)

# %%
validMC = ['OVER THE COUNTER (OTC)','PRESCRIPTION ONLY MEDICINE (POM)','OVER THE COUNTER (OTC)','PRESCRIPTION ONLY MEDICINE (POM)','PRESCRIPTION ONLY MEDICINE (POM)','OVER THE COUNTER (OTC)','PRESCRIPTION ONLY MEDICINE (POM)','PRESCRIPTION ONLY MEDICINE (POM)','PRESCRIPTION ONLY MEDICINE (POM)','PRESCRIPTION ONLY MEDICINE (POM)']

# %%
mc_dictionary = dict(zip(marketingCat,validMC))

# %%
type(mc_dictionary)
# Out:
# dict

# %%
drug['MARKETING CATEGORY'].replace(mc_dictionary, inplace=True)

# %%
mc = drug['MARKETING CATEGORY']

# %%
mc.unique()
# Out:
# array(['OVER THE COUNTER (OTC)', 'PRESCRIPTION ONLY MEDICINE (POM)'],
#       dtype=object)

# %%
drug.loc[drug['MARKETING CATEGORY'] == 'NUTRITIONAL SUPPLEMENT']
# Out:
#                                    PRODUCT NAME   NAFDAC     BRAND  \
# 5852  TESTYMIN AMINO ACIDS & MULTIVITAMIN SYRUP  B4-5007  TESTYMIN
# 5853          TESTYFER AMINO ACIDS & IRON SYRUP  B4-7896  TESTYFER
#
#                                                GENERICS PRODUCT CATEGORY  \
# 5852  VITAMIN A IU, L-LEUCINE . , PYRIDOXINE HYDROCH...       HUMAN DRUG
# 5853  L-HISTIDINE HYDROCHLORIDE MONOHYDRATE , L-LYSI...       HUMAN DRUG
#
#                  PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 5852  NUTRITIONAL SUPPLEMENT                    ORAL  DRUG
# 5853  NUTRITIONAL SUPPLEMENT                    ORAL  DRUG
#
#                                              ACTIVE ING  \
# 5852  VITAMIN A IU, L-LEUCINE . , PYRIDOXINE HYDROCH...
# 5853  L-HISTIDINE HYDROCHLORIDE MONOHYDRATE , L-LYSI...
#
#                                                STRENGTH     PRESENTATION  \
# 5852  2500IU, L-LEUCINE 18.3MG, PYRIDOXINE HYDROCHLO...  LIQUID1 X 200ML
# ...

# %%
drug.iloc[[5852,5853],13] = 'OVER THE COUNTER (OTC)'

# %%
drug.iloc[3188,:]
# Out:
# PRODUCT NAME                                       NICHBEN PARACETAMOL SYRUP
# NAFDAC                                                               04-0835
# BRAND                                                                NICHBEN
# GENERICS                                                         PARACETAMOL
# PRODUCT CATEGORY                                                  HUMAN DRUG
# PHARM CLASS                                                        ANALGESIC
# ROUTE OF ADMINISTRATION                                                 ORAL
# GROUP                                                                   DRUG
# ACTIVE ING                                                       PARACETAMOL
# STRENGTH                                                               125MG
# PRESENTATION                                                     SYRUP, 60ML
# DOSAGE FORM                                                            SYRUP
# ...

# %%
drug.fillna({'MARKETING CATEGORY':'MC missing'}, inplace=True)

# %%
mc = list(mc)

# %%
mc = pd.DataFrame(mc, columns=['Marketing Category'])

# %%
nullcols(drug)
# Out:
# STRENGTH             130
# PRESENTATION          26
# PACK SIZE             12
# NAME OF APPLICANT     23
# APPLICANT ADDRESS      2
# date_time              7
# dtype: int64

# %%
drug.loc[drug['APPROVED INDICATION'].isnull(), :]
# Out:
# Empty DataFrame
# Columns: [PRODUCT NAME, NAFDAC, BRAND, GENERICS, PRODUCT CATEGORY, PHARM CLASS, ROUTE OF ADMINISTRATION, GROUP, ACTIVE ING, STRENGTH, PRESENTATION, DOSAGE FORM, PACK SIZE, MARKETING CATEGORY, APPROVED INDICATION, NAME OF APPLICANT, APPLICANT ADDRESS, COUNTRY, NAME OF MANUFACTURER, MANUFACTURER ADDRESS, COUNTRY.1, APPROVAL DATE, EXPIRY DATE, date_time]
# Index: []

# %%
drug.iat[3579,14] = 'FOR ANXIOLYTIC, SEDATION'

# %%
drug.iat[4100,14] = 'FOR PAIN RELIEF'

# %%
 drug.loc[drug['PACK SIZE'].isnull(), :]
# Out:
#                                   PRODUCT NAME    NAFDAC         BRAND  \
# 279   SOFTHEALTH COD LIVER OIL CAPSULES 1000MG   B4-6635    SOFTHEALTH
# 731                           CETIL 250 TABLET   B4-6259     CETIL 250
# 844                        EGLOFEDIPINE TABLET   B4-6269  EGLOFEDIPINE
# 845                         ODASOL-20 CAPSULES   B4-6270     ODASOL-20
# 1057                  BEXALOL STERILE EYE DROP   B4-7090       BEXALOL
# 2368    BIRON-12 HAEMATINIC WITH VITAMIN SYRUP  A11-0666      BIRON-12
# 3039                        NOVACAN-50 TABLETS   04-7690       NOVACAN
# 3196             WOODS' PEPPERMINT EXPECTORANT   B4-9628        WOODS'
# 3780                          CELOPRO CAPSULES   B4-9895       CELOPRO
# 4861                        OMEPRAZOLE CAPSULE   C4-0135    OMEPRAZOLE
# 4862       MAYATEO DICLOFENAC POTASSIUM TABLET   C4-0136       MAYATEO
# 4863                  MAYANIL PROGUANIL TABLET   C4-0137       MAYANIL
#
# ...

# %%
drug.iloc[3780,11] = 'CAPSULE'

# %%
drug.iloc[4100,:]
# Out:
# PRODUCT NAME                                            GRAPROFEN SUSPENSION
# NAFDAC                                                               A4-8078
# BRAND                                                              GRAPROFEN
# GENERICS                                                           IBUPROFEN
# PRODUCT CATEGORY                                                  HUMAN DRUG
# PHARM CLASS                                                            NSAID
# ROUTE OF ADMINISTRATION                                                 ORAL
# GROUP                                                                   DRUG
# ACTIVE ING                                                      IBUPROFEN BP
# STRENGTH                                                           100MG/5ML
# PRESENTATION                                              SUSPENSION,1X100ML
# DOSAGE FORM                                                       SUSPENSION
# ...

# %%
pharmclass
# Out:
# 0       NUTRITIONAL SUPPLEMENT
# 1       NUTRITIONAL SUPPLEMENT
# 2       NUTRITIONAL SUPPLEMENT
# 3       NUTRITIONAL SUPPLEMENT
# 4                      ANTACID
#                  ...
# 5849        DIETARY SUPPLEMENT
# 5850        DIETARY SUPPLEMENT
# 5851        DIETARY SUPPLEMENT
# 5852    NUTRITIONAL SUPPLEMENT
# 5853    NUTRITIONAL SUPPLEMENT
# Name: PHARM CLASS, Length: 5854, dtype: object

# %%
dose
# Out:
#            DOSAGE FORM
# 0                SYRUP
# 1           SUSPENSION
# 2             SOLUTION
# 3               LIQUID
# 4             CAPSULE,
# ..                 ...
# 140    SOFGEL CAPSULES
# 141      FOR INJECTION
# 142  CAPSULES & TABLET
# 143        SUSPENSION,
# 144            LINCTUS
#
# [145 rows x 1 columns]

# %%
routes
# Out:
#                    Route of Administration
# 0                                     ORAL
# 1                                  TOPICAL
# 2                              INTRAVENOUS
# 3                                   OCULAR
# 4                            INTRAMUSCULAR
# 5                              OCULAR/OTIC
# 6                                   BUCCAL
# 7                INTRAMUSCULAR/INTRAVENOUS
# 8                INTRAVENOUS/INTRAMUSCULAR
# 9                                   RECTAL
# 10                                    OTIC
# 11                                 VAGINAL
# 12                               CUTANEOUS
# 13                              OPHTHALMIC
# 14                                   NASAL
# 15                             BUCCAL/ORAL
# 16                         OPHTHALMIC/OTIC
# 17  INTRAVENOUS/INTRAMUSCULAR/SUBCUTANEOUS
# 18                   OPHTHALMIC/OTIC/NASAL
# 19                            ORAL/TOPICAL
# 20                            SUBCUTANEOUS
# ...

# %%
pharma
# Out:
#                  PHARM CLASS
# 0     NUTRITIONAL SUPPLEMENT
# 1                    ANTACID
# 2                   VITAMINS
# 3                    VITAMIN
# 4                 ANTISEPTIC
# ..                       ...
# 781   H₂ RECEPTOR ANTAGONIST
# 782  PROSTAGLANDIN E1 ANALOG
# 783      NSAID, ANTIPLATELET
# 784             SULFONYLUREA
# 785            HERBAL REMEDY
#
# [786 rows x 1 columns]

# %%
doses
# Out:
# ['SYRUP',
#  'SYRUP',
#  'SYRUP',
#  'SYRUP',
#  'SUSPENSION',
#  'SYRUP',
#  'SYRUP',
#  'SUSPENSION',
#  'SOLUTION',
#  'SOLUTION',
#  'LIQUID',
#  'CAPSULE,',
#  'POWDER,',
#  'LIQUID',
#  'LIQUID',
#  'TABLET',
#  'TABLET',
#  'TABLET',
#  'TABLET',
#  'TABLET',
#  'SYRUP',
#  'TABLET',
#  'SYRUP',
#  'CAPLET',
#  'TABLET',
#  'TABLET',
#  'SYRUP',
#  'CAPLET',
#  'TABLET',
#  'CAPSULES',
#  'SUSPENSION',
#  'SUSPENSION',
#  'LIQUID',
#  'CAPLET',
#  '1 X 200ML',
#  'TABLET',
#  'SUSPENSION',
#  'OINTMENT',
#  'SYRUP',
#  'TABLET',
#  'TABLET',
#  'SUSPENSION',
#  'TABLET',
#  'TABLET',
#  'SUSPENSION',
#  'CAPLET',
#  'POWDER',
#  'TABLET',
#  'SUSPENSION',
#  'SUSPENSION',
#  'SUSPENSION',
#  'LIQUID',
#  'LIQUID',
#  'LIQUID',
#  'TABLET',
#  'TABLET',
#  'TABLET',
#  'TABLET',
#  'TABLET',
#  'POWDER',
#  'POWDER',
#  'CREAM',
#  'TABLET',
#  'LIQUID',
#  'TABLET',
#  'CAPLET',
#  'SUSPENSION',
#  'TABLET',
#  'TABLET',
#  'TABLET',
#  'CAPSULE',
#  'CAPSULE',
#  'CAPLET',
# ...

# %%
drug.
