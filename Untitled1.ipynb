# %%
import pandas as pd
import numpy as np

# %%
drug = pd.read_excel('drug-2016-2020a.xlsx', index_col=0)

# %%
drug
# Out:
#                                            PRODUCT NAME    NAFDAC  \
# 0                                       MIM TONIC SYRUP   04-1194
# 1            DR MEYER'S FEROTAL EXTRA BLOOD TONIC SYRUP   04-7927
# 2                                         JAWARON TONIC   04-2037
# 3                             AVROTON BLOOD TONIC SYRUP   A4-5661
# 4                                    SOFAMAG SUSPENSION  A11-0251
# ...                                                 ...       ...
# 6231                             ENHANZ SOFTGEL CAPSULE   A4-5163
# 6232              CROWTHER COD LIVER OIL 1000MG CAPSULE   A4-4282
# 6233  GINTAMINE MULTIVITAMIN & MULTIVITAMIN MINERAL ...   A4-4281
# 6234          TESTYMIN AMINO ACIDS & MULTIVITAMIN SYRUP   B4-5007
# 6235                  TESTYFER AMINO ACIDS & IRON SYRUP   B4-7896
#
#                          BRAND  \
# 0                          MIM
# 1     DR MEYER'S FEROTAL EXTRA
# 2                      JAWARON
# 3                      AVROTON
# ...

# %%
cdrug = pd.read_excel('drug-complete.xlsx')

# %%
cdrug
# Out:
#                        PRODUCT NAME   NAFDAC       BRAND  \
# 0                  VALINEX-5 TABLET  04-0063     VALINEX
# 1         DR MEYER'S BECOPLEX SYRUP  04-0068  DR MEYER'S
# 2                        FOLIC ACID  04-0169           -
# 3                     ZADITEN SYRUP  04-0193     ZADITEN
# 4                   AFRABVITE DROPS  04-0213   AFRABVITE
# ...                             ...      ...         ...
# 1516  GREENLIFE VITAMIN C INJECTION  B4-7410   GREENLIFE
# 1517     FECCOX PIROXICAM INJECTION  B4-7411      FECCOX
# 1518             SPEDRA 200 TABLETS  B4-7412      SPEDRA
# 1519              SPEDRA 50 TABLETS  B4-7414      SPEDRA
# 1520           MELOFAN PLUS TABLETS  B4-7415     MELOFAN
#
#                                                GENERICS PRODUCT CATEGORY  \
# 0                                              DIAZEPAM       HUMAN DRUG
# 1                  VIT B1, VIT B2, NICOTINAMIDE, VIT B6       HUMAN DRUG
# ...

# %%
columns = cdrug.columns

# %%
index = cdrug.index

# %%
data = cdrug.to_numpy()

# %%
columns
# Out:
# Index(['PRODUCT NAME', 'NAFDAC', 'BRAND', 'GENERICS', 'PRODUCT CATEGORY',
#        'PHARM CLASS', 'ROUTE OF ADMINISTRATION', 'GROUP', 'ACTIVE ING',
#        'STRENGTH', 'PRESENTATION', 'DOSAGE FORM', 'PACK SIZE',
#        'MARKETING CATEGORY', 'APPROVED INDICATION', 'NAME OF APPLICANT',
#        'APPLICANT ADDRESS', 'COUNTRY', 'NAME OF MANUFACTURER',
#        'MANUFACTURER ADDRESS', 'COUNTRY.1', 'APPROVAL DATE', 'EXPIRY DATE',
#        'SF_USER_NAME', 'SF_DATE', 'SF_PRINT', 'SF_TYPE'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=1521, step=1)

# %%
data
# Out:
# array([['VALINEX-5 TABLET', '04-0063', 'VALINEX', ...,
#         datetime.datetime(2017, 9, 28, 0, 0), 0, 'NEW REGISTRATION'],
#        ["DR MEYER'S BECOPLEX SYRUP", '04-0068', "DR MEYER'S", ...,
#         datetime.datetime(2017, 7, 13, 0, 0), 0, 'RENEWAL'],
#        ['FOLIC ACID', '04-0169', '-', ...,
#         datetime.datetime(2017, 9, 28, 0, 0), 0, 'NEW REGISTRATION'],
#        ...,
#        ['SPEDRA 200 TABLETS', 'B4-7412', 'SPEDRA', ...,
#         datetime.datetime(2017, 9, 28, 0, 0), 0, 'NEW REGISTRATION'],
#        ['SPEDRA 50 TABLETS', 'B4-7414', 'SPEDRA', ...,
#         datetime.datetime(2017, 9, 28, 0, 0), 0, 'NEW REGISTRATION'],
#        ['MELOFAN PLUS TABLETS', 'B4-7415', 'MELOFAN', ...,
#         datetime.datetime(2017, 9, 28, 0, 0), 0, 'NEW REGISTRATION']],
#       dtype=object)

# %%
type(index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(data)
# Out:
# numpy.ndarray

# %%
issubclass(pd.RangeIndex, pd.Index)
# Out:
# True

# %%
issubclass(columns.__class__, pd.Index)
# Out:
# True

# %%
index.to_numpy()
# Out:
# array([   0,    1,    2, ..., 1518, 1519, 1520], dtype=int64)

# %%
columns.to_numpy()
# Out:
# array(['PRODUCT NAME', 'NAFDAC', 'BRAND', 'GENERICS', 'PRODUCT CATEGORY',
#        'PHARM CLASS', 'ROUTE OF ADMINISTRATION', 'GROUP', 'ACTIVE ING',
#        'STRENGTH', 'PRESENTATION', 'DOSAGE FORM', 'PACK SIZE',
#        'MARKETING CATEGORY', 'APPROVED INDICATION', 'NAME OF APPLICANT',
#        'APPLICANT ADDRESS', 'COUNTRY', 'NAME OF MANUFACTURER',
#        'MANUFACTURER ADDRESS', 'COUNTRY.1', 'APPROVAL DATE',
#        'EXPIRY DATE', 'SF_USER_NAME', 'SF_DATE', 'SF_PRINT', 'SF_TYPE'],
#       dtype=object)

# %%
cdrug.dtypes
# Out:
# PRODUCT NAME                       object
# NAFDAC                             object
# BRAND                              object
# GENERICS                           object
# PRODUCT CATEGORY                   object
# PHARM CLASS                        object
# ROUTE OF ADMINISTRATION            object
# GROUP                              object
# ACTIVE ING                         object
# STRENGTH                           object
# PRESENTATION                       object
# DOSAGE FORM                        object
# PACK SIZE                          object
# MARKETING CATEGORY                 object
# APPROVED INDICATION                object
# NAME OF APPLICANT                  object
# APPLICANT ADDRESS                  object
# COUNTRY                            object
# NAME OF MANUFACTURER               object
# MANUFACTURER ADDRESS               object
# COUNTRY.1                          object
# APPROVAL DATE              datetime64[ns]
# ...

# %%
cdrug.dtypes.value_counts()
# Out:
# object            24
# datetime64[ns]     2
# int64              1
# dtype: int64

# %%
cdrug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1521 entries, 0 to 1520
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             1521 non-null   object
#  1   NAFDAC                   1521 non-null   object
#  2   BRAND                    1521 non-null   object
#  3   GENERICS                 1521 non-null   object
#  4   PRODUCT CATEGORY         1521 non-null   object
#  5   PHARM CLASS              1521 non-null   object
#  6   ROUTE OF ADMINISTRATION  1521 non-null   object
#  7   GROUP                    1521 non-null   object
#  8   ACTIVE ING               1521 non-null   object
#  9   STRENGTH                 1521 non-null   object
#  10  PRESENTATION             1521 non-null   object
#  11  DOSAGE FORM              1521 non-null   object
#  12  PACK SIZE                1521 non-null   object
#  13  MARKETING CATEGORY       1521 non-null   object
# ...
