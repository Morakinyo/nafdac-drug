# %%
import pandas as pd
import numpy as np

# %%
drug_latest = pd.read_excel('drug-src-napams-latest-2021.xlsx', parse_dates=True)

# %%
drug_latest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ProductName              1036 non-null   object
#  1   GenericName              1025 non-null   object
#  2   ApplicationNumber        1036 non-null   object
#  3   NAFDACNumber             1034 non-null   object
#  4   CategoryName             1036 non-null   object
#  5   PharmacologicalClass     1036 non-null   object
#  6   RouteOfAdministration    1036 non-null   object
#  7   ActiveIngredients        1036 non-null   object
#  8   Strength                 0 non-null      float64
#  9   Presentation             1035 non-null   object
#  10  DosageForm               1036 non-null   object
#  11  PackSize                 1000 non-null   object
#  12  ApprovedIndications      1035 non-null   object
#  13  DrugType                 1026 non-null   object
# ...

# %%
pd.set_option('display.max_columns', None)
drug_latest.sample(n=5, random_state=34)
# Out:
#                              ProductName  \
# 842  ZOLEDRO-DENK SOLUTION FOR INJECTION
# 950                       ZICLOX CAPSULE
# 235          PANAGREEN-125 SUPPOSITORIES
# 853         SEFZITIL 125 ORAL SUSPENSION
# 683                  TECOTRIM 960 TABLET
#
#                                     GenericName ApplicationNumber  \
# 842                         ZOLEDRONIC ACID 4MG     RNW-PP-134019
# 950                    AMPICILLIN, CLOXACILLIN      RNW-PP-216135
# 235                 PANAGREEN-125 SUPPOSITORIES     RNW-PP-118554
# 853                     CEFUROXIME AXETIL 125MG     RNW-PP-167598
# 683  SULPHAMETHOXAZOLE 800MG,TRIMETHOPRIM 160MG      RNW-PP-81525
#
#     NAFDACNumber CategoryName          PharmacologicalClass  \
# 842      B4-5164        DRUGS  ANTINEOPLASTIC AND ADJUVANTS
# 950      A4-4154        DRUGS                    ANTIBIOTIC
# 235      04-8486        DRUGS  CENTRAL NERVOUS SYSTEM DRUGS
# 853      B4-5744        DRUGS               ANTI-INFECTIVES
# ...

# %%
drug_latest_rearrange = drug_latest[['ProductName', 'NAFDACNumber','GenericName','ActiveIngredients', 'PharmacologicalClass', 'RouteOfAdministration',\
                                     'Strength','DosageForm','DrugType',\
                                     'ApprovedIndications','ApplicantName','ApplicantAddress',\
                                     'ManufacturerName','ManufacturerCountry',\
                                     'ApprovalDate','ExpiryDate']]

# %%
drug_latest_rearrange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductName            1036 non-null   object
#  1   NAFDACNumber           1034 non-null   object
#  2   GenericName            1025 non-null   object
#  3   ActiveIngredients      1036 non-null   object
#  4   PharmacologicalClass   1036 non-null   object
#  5   RouteOfAdministration  1036 non-null   object
#  6   Strength               0 non-null      float64
#  7   DosageForm             1036 non-null   object
#  8   DrugType               1026 non-null   object
#  9   ApprovedIndications    1035 non-null   object
#  10  ApplicantName          1036 non-null   object
#  11  ApplicantAddress       1036 non-null   object
#  12  ManufacturerName       1012 non-null   object
#  13  ManufacturerCountry    985 non-null    object
# ...

# %%
drug_for_website = pd.read_excel('new-drug-v7-no-duplicates-v1.xlsx', index_col=0, parse_dates=True)

# %%
drug_for_website.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5443 entries, 0 to 5853
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5443 non-null   object
#  1   NAFDAC                   5443 non-null   object
#  2   BRAND                    5443 non-null   object
#  3   GENERICS                 5443 non-null   object
#  4   ACTIVE ING               5443 non-null   object
#  5   Unnamed: 6               0 non-null      float64
#  6   PRODUCT CATEGORY         5443 non-null   object
#  7   PHARM CLASS              5417 non-null   object
#  8   ROUTE OF ADMINISTRATION  5443 non-null   object
#  9   GROUP                    5443 non-null   object
#  10  ACTIVE ING.1             5443 non-null   object
#  11  STRENGTH                 5354 non-null   object
#  12  DOSAGE FORM              5439 non-null   object
#  13  MARKETING CATEGORY       5443 non-null   object
# ...

# %%
pd.set_option('display.max_columns', None)
drug_for_website.sample(n=5, random_state=42)
# Out:
#                                        PRODUCT NAME   NAFDAC          BRAND  \
# 1225             PHARMAMAX CIPROFLOXACIN TN TABLETS  B4-7188      PHARMAMAX
# 5108  ATAZANAVIR (AS SULFATE) AND RITONAVIR TABLETS  B4-0196      UNBRANDED
# 431                             GYNO-MASTATIN CREAM  B4-6650  GYNO-MASTATIN
# 2003                  FAITH MIST.POTASSUIM.CITRATE.  04-8449          FAITH
# 4128                    METOPROLOL TARTRATE TABLETS  C4-0048      UNBRANDED
#
#                             GENERICS  \
# 1225       CIPROFLOXACIN, TINIDAZOLE
# 5108                      ATAZANAVIR
# 431            NYSTATIN , MICONAZOLE
# 2003  POTASSUIM CITRATE, CITRIC ACID
# 4128             METOPROLOL TARTRATE
#
#                                              ACTIVE ING  Unnamed: 6  \
# 1225              CIPROFLOXACIN 500MG; TINIDAZOLE 600MG         NaN
# 5108  ATAZANAVIR ( AS SULFATE) EQ. TO ATAZANAVIR RIT...         NaN
# 431                                NYSTATIN, MICONAZOLE         NaN
# ...

# %%
drug_for_website.reset_index(drop=True, inplace=True)

# %%
drug_for_website.drop(drug_for_website.columns[5], axis=1, inplace=True)

# %%
drug_for_website.drop(['GROUP'], axis=1, inplace=True)

# %%
drug_for_website.drop(['ACTIVE ING.1'], axis=1, inplace=True)

# %%
drug_for_website.drop(['GENERICS'], axis=1, inplace=True)

# %%
drug_for_website.drop(['PRODUCT CATEGORY'], axis=1, inplace=True)

# %%
col_for_website = drug_for_website.columns.to_list()

# %%
col_for_website
# Out:
# ['PRODUCT NAME',
#  'NAFDAC',
#  'BRAND',
#  'ACTIVE ING',
#  'PHARM CLASS',
#  'ROUTE OF ADMINISTRATION',
#  'STRENGTH',
#  'DOSAGE FORM',
#  'MARKETING CATEGORY',
#  'APPROVED INDICATION',
#  'NAME OF APPLICANT',
#  'COUNTRY OF APPLICANT',
#  'NAME OF MANUFACTURER',
#  'COUNTRY OF MANUFACTURE',
#  'APPROVAL DATE',
#  'EXPIRY DATE']

# %%
#drug_latest.drop(drug_latest.columns[[4,11,13,15,16,19,20,21]], axis=1, inplace=True)

# %%
drug_latest_rearrange.columns = col_for_website

# %%
drug_latest_rearrange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             1036 non-null   object
#  1   NAFDAC                   1034 non-null   object
#  2   BRAND                    1025 non-null   object
#  3   ACTIVE ING               1036 non-null   object
#  4   PHARM CLASS              1036 non-null   object
#  5   ROUTE OF ADMINISTRATION  1036 non-null   object
#  6   STRENGTH                 0 non-null      float64
#  7   DOSAGE FORM              1036 non-null   object
#  8   MARKETING CATEGORY       1026 non-null   object
#  9   APPROVED INDICATION      1035 non-null   object
#  10  NAME OF APPLICANT        1036 non-null   object
#  11  COUNTRY OF APPLICANT     1036 non-null   object
#  12  NAME OF MANUFACTURER     1012 non-null   object
#  13  COUNTRY OF MANUFACTURE   985 non-null    object
# ...

# %%
drug_latest_rearrange['APPROVAL DATE'] = pd.to_datetime(drug_latest_rearrange['APPROVAL DATE'])
# Out:
# <ipython-input-21-3e2b17e5a090>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug_latest_rearrange['APPROVAL DATE'] = pd.to_datetime(drug_latest_rearrange['APPROVAL DATE'])

# %%
drug_latest_rearrange['EXPIRY DATE'] = pd.to_datetime(drug_latest_rearrange['EXPIRY DATE'])
# Out:
# <ipython-input-22-02a73c4e0112>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug_latest_rearrange['EXPIRY DATE'] = pd.to_datetime(drug_latest_rearrange['EXPIRY DATE'])

# %%
pd.set_option('display.max_colwidth', None)
drug_latest_rearrange.sample(n=5, random_state=42)
# Out:
#                                         PRODUCT NAME   NAFDAC  \
# 622                                     TRAMADOL 100  B4-5058
# 109                         OLAL MULTIVITAMIN TABLET  A4-2071
# 649  AZARGA 10 MG/ML + 5 MG/ML EYE DROPS, SUSPENSION  B4-5549
# 458                                KUINOPRIL TABLETS  04-9631
# 541                            CLARITEK TABLET 500MG  B4-6050
#
#                                                                BRAND  \
# 622                                            TRAMADOL HYDROCLORIDE
# 109                                                    MULTIVITAMINS
# 649  BRINZOLAMIDE  10 MG/ML + TIMOLOL  5 MG/ML EYE DROPS, SUSPENSION
# 458                                               LISINOPRIL TABLETS
# 541                                             CLARITHROMYCIN 500MG
#
# ...

# %%
pd.set_option('display.max_rows', None)
drug_latest_rearrange
# Out:
#                                                                                  PRODUCT NAME  \
# 0                                                      SAMJONES CLARITHROMYCIN TABLETS 500 MG
# 1                                                                                       PIMAG
# 2                                                                          POLYGYNAX  CAPSULE
# 3                                                                            KETESSE TABLETS.
# 4                        LAMIVUDINE/NEVIRAPINE/ZIDOVUDINE 30MG/50MG/60MG DISPERSIBLE  TABLETS
# 5                                                          CANDESARTAN/HCT SANDOZ 16MG/12.5MG
# 6                                                                            CANDID V1 TABLET
# 7                                                                        PULMOCEF 250 TABLETS
# 8                                                                        PULMOCEF 500 TABLETS
# ...

# %%
drug_latest_rearrange.insert(11, "COUNTRY", 'NIGERIA')

# %%
drug_latest_rearrange.head(5)
# Out:
#                                                            PRODUCT NAME  \
# 0                                SAMJONES CLARITHROMYCIN TABLETS 500 MG
# 1                                                                 PIMAG
# 2                                                    POLYGYNAX  CAPSULE
# 3                                                      KETESSE TABLETS.
# 4  LAMIVUDINE/NEVIRAPINE/ZIDOVUDINE 30MG/50MG/60MG DISPERSIBLE  TABLETS
#
#       NAFDAC                                                 BRAND  \
# 0  A4-100035                              CLARITHROMYCIN USP 500MG
# 1  A4-100036  ALUMINIUM HYDROXIDE, MAGNESIUM HYDROXIDE,SIMETHICONE
# 2    O4-3009         NEOMYCIN SULFATE, POLYMYXIN SULFATE, NYSTATIN
# 3   B4-3530.                         DEXKETOPROFEN TROMETAMOL 25MG
# 4    A4-3119                                                   NIL
#
# ...

# %%
drug_napams = drug_latest_rearrange.drop(drug_latest_rearrange.columns[12], axis=1)

# %%
drug_napams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             1036 non-null   object
#  1   NAFDAC                   1034 non-null   object
#  2   BRAND                    1025 non-null   object
#  3   ACTIVE ING               1036 non-null   object
#  4   PHARM CLASS              1036 non-null   object
#  5   ROUTE OF ADMINISTRATION  1036 non-null   object
#  6   STRENGTH                 0 non-null      float64
#  7   DOSAGE FORM              1036 non-null   object
#  8   MARKETING CATEGORY       1026 non-null   object
#  9   APPROVED INDICATION      1035 non-null   object
#  10  NAME OF APPLICANT        1036 non-null   object
#  11  COUNTRY                  1036 non-null   object
#  12  NAME OF MANUFACTURER     1012 non-null   object
#  13  COUNTRY OF MANUFACTURE   985 non-null    object
# ...

# %%
drug_napams.rename(columns={'COUNTRY':'COUNTRY OF APPLICANT'}, inplace=True)

# %%
drug_napams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             1036 non-null   object
#  1   NAFDAC                   1034 non-null   object
#  2   BRAND                    1025 non-null   object
#  3   ACTIVE ING               1036 non-null   object
#  4   PHARM CLASS              1036 non-null   object
#  5   ROUTE OF ADMINISTRATION  1036 non-null   object
#  6   STRENGTH                 0 non-null      float64
#  7   DOSAGE FORM              1036 non-null   object
#  8   MARKETING CATEGORY       1026 non-null   object
#  9   APPROVED INDICATION      1035 non-null   object
#  10  NAME OF APPLICANT        1036 non-null   object
#  11  COUNTRY OF APPLICANT     1036 non-null   object
#  12  NAME OF MANUFACTURER     1012 non-null   object
#  13  COUNTRY OF MANUFACTURE   985 non-null    object
# ...

# %%
drug_napams.sample(n=5, random_state=42)
# Out:
#                                         PRODUCT NAME   NAFDAC  \
# 622                                     TRAMADOL 100  B4-5058
# 109                         OLAL MULTIVITAMIN TABLET  A4-2071
# 649  AZARGA 10 MG/ML + 5 MG/ML EYE DROPS, SUSPENSION  B4-5549
# 458                                KUINOPRIL TABLETS  04-9631
# 541                            CLARITEK TABLET 500MG  B4-6050
#
#                                                                BRAND  \
# 622                                            TRAMADOL HYDROCLORIDE
# 109                                                    MULTIVITAMINS
# 649  BRINZOLAMIDE  10 MG/ML + TIMOLOL  5 MG/ML EYE DROPS, SUSPENSION
# 458                                               LISINOPRIL TABLETS
# 541                                             CLARITHROMYCIN 500MG
#
# ...

# %%
pharmclass = drug_napams['PHARM CLASS'].sort_values().unique()

# %%
pharmclass
# Out:
# array(['-- SELECT --', 'ACE INHIBITOR', 'AMEBICIDE', 'ANALGESICS',
#        'ANTHELMINTICS', 'ANTI-INFECTIVES', 'ANTIBIOTIC', 'ANTICANCER',
#        'ANTICOAGULANT', 'ANTIDEPRESSANT', 'ANTIDIABETIC',
#        'ANTIDIARRHEALS',
#        'ANTIDOTES AND OTHER SUBSTANCES USED IN POISONING', 'ANTIFUNGALS',
#        'ANTIHISTAMINE', 'ANTIHISTAMINES AND ANTIALLERGICS',
#        'ANTIMALARIAL', 'ANTINEOPLASTIC AND ADJUVANTS', 'ANTIPLATELET',
#        'ANTIPSYCHOTIC', 'ANTITUSSIVES', 'ANTIVIRAL', 'BETA BLOCKER',
#        'BLOOD PRODUCTS AND DRUGS AFFECTING THE BLOOD', 'BRONCHODILATOR',
#        'CARDIOVASCULAR DRUGS', 'CENTRAL NERVOUS SYSTEM DRUGS',
#        'DECONGESTANT', 'DERMATOLOGICAL AGENTS', 'DIURETIC/ANTIDIURETIC',
#        'DRUGS FOR CORRECTING WATER ELECTROLYTE AND ACID-BASE DISTURBANCES',
#        'DRUGS USED IN ANAESTHESIA',
#        'DRUGS USED IN ENDOCRINE DISORDERS AND CONTRACEPTIVES',
#        'DRUGS USED IN MUSCULOSKELETAL AND JOINT DISEASES',
# ...

# %%
nopharmclass = drug_napams[drug_napams['PHARM CLASS'].isin(['-- SELECT --','MISCELLANEOUS'])]

# %%
nopharmclass
# Out:
#                                              PRODUCT NAME      NAFDAC  \
# 11                                       OSTOFER CAPSULES     B4-4325
# 68                        EVANS BAROQUE PARACETAMOL 500MG  A11-100011
# 95                                          AFRAMIN DROPS     A4-8780
# 134                                            ARPETUMIN   A11-100035
# 151                                 UNABEN-C 200MG TABLET  A11-100052
# 172                                    NEMECLOX 250MG/5ML     A4-8509
# 176                                               UNABEN      04-9938
# 203                                          MANTRA SYRUP   A4 - 3950
# 204                              LA-TESEN TABLETS - COMBI     A4-2767
# 212                    AVROMAL 20/120 DISPERSIBLE TABLETS     B4-4301
# 240                                ARTEMEF 80/480 TABLETS     A4-2734
# 243                                     KIFARU 100 TABLET     B4-4268
# ...

# %%
len(nopharmclass)
# Out:
# 60

# %%
noNRN = drug_napams[drug_napams['NAFDAC'].isnull()]

# %%
noNRN
# Out:
#                   PRODUCT NAME NAFDAC                  BRAND  \
# 86   EMZOR NYSTATIN SUSPENSION    NaN  NYSTATIN 100,000IU/ML
# 684                    DETONIC    NaN                DETONIC
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               ACTIVE ING  \
# ...

# %%
marketingCat = drug_napams['MARKETING CATEGORY'].sort_values().unique()

# %%
marketingCat
# Out:
# array(['OTC', 'OVER THE COUNTER (OTC)', 'POM 1', 'POM 2',
#        'PRESCRIPTION ONLY MEDICINE (POM)', nan], dtype=object)

# %%
drug_napams['MARKETING CATEGORY'].replace({'OTC':'OVER THE COUNTER (OTC)', 'POM 1':'PRESCRIPTION ONLY MEDICINE (POM)', 'POM 2':'PRESCRIPTION ONLY MEDICINE (POM)'}, inplace=True)

# %%
marketingCat2 = drug_napams['MARKETING CATEGORY'].sort_values().unique()

# %%
marketingCat2
# Out:
# array(['OVER THE COUNTER (OTC)', 'PRESCRIPTION ONLY MEDICINE (POM)', nan],
#       dtype=object)

# %%
nomarketingCategory = drug_napams[drug_napams['MARKETING CATEGORY'].isnull()]

# %%
nomarketingCategory
# Out:
#                                      PRODUCT NAME   NAFDAC  \
# 5              CANDESARTAN/HCT SANDOZ 16MG/12.5MG  B4-3524
# 204                      LA-TESEN TABLETS - COMBI  A4-2767
# 206                                       FIDVITE  04-5097
# 536                                MIXANAL CAPLET  04-4184
# 685                RGI DOXCYCLINE 100MG CAPSULES   A4-2490
# 773             VITABOL CHEWABLE VITAMIN C TABLET  04-2805
# 821  OSPAMOX 125MG/5ML POWDER FOR ORAL SUSPENSION  B4-3580
# 875                                   ASTHATOR 10  B4-1308
# 876                                    ASTHATOR 5  B4-1262
# 935                             LIFEPRONE  CAPLET  A4-0709
#
#                                 BRAND  \
# 5              CANDESARTAN CILEXETIL
# 204                          LA-TESEN
# 206                           FIDVITE
# 536                           MIXANAL
# 685                  DOXCYCLINE 100MG
# 773                  VITAMIN C TABLET
# 821                       AMOXICILLIN
# ...

# %%
# %run null_values.py

# %%
nullcols(drug_napams)
# Out:
# NAFDAC                       2
# BRAND                       11
# STRENGTH                  1036
# MARKETING CATEGORY          10
# APPROVED INDICATION          1
# NAME OF MANUFACTURER        24
# COUNTRY OF MANUFACTURE      51
# APPROVAL DATE                1
# EXPIRY DATE                  1
# dtype: int64

# %%
approvedIndication = drug_napams[drug_napams['APPROVED INDICATION'].isnull()]

# %%
approvedIndication
# Out:
#                  PRODUCT NAME     NAFDAC              BRAND  \
# 338  ALPHACAINE 100 INJECTION  A4 - 4022  LOCAL ANAESTHESIA
#
#                                                ACTIVE ING  \
# 338  LIDOCAINE HYDROCHLORIDE 20MG/ML, EPINEPHRINE 10PG/ML
#
#                    PHARM CLASS ROUTE OF ADMINISTRATION  STRENGTH DOSAGE FORM  \
# 338  DRUGS USED IN ANAESTHESIA   INTRAVENOUS INJECTION       NaN   INJECTION
#
#                    MARKETING CATEGORY APPROVED INDICATION  \
# 338  PRESCRIPTION ONLY MEDICINE (POM)                 NaN
#
#           NAME OF APPLICANT COUNTRY OF APPLICANT  \
# 338  DAVONA NIGERIA LIMITED              NIGERIA
#
#              NAME OF MANUFACTURER COUNTRY OF MANUFACTURE APPROVAL DATE  \
# 338  DFL NDUSTRIA E COMERCIO S.A.                 BRAZIL    2021-05-07
#
#     EXPIRY DATE
# 338  2026-05-06

# %%
nameManufacturer = drug_napams[drug_napams['NAME OF MANUFACTURER'].isnull()]

# %%
nameManufacturer
# Out:
#                                       PRODUCT NAME    NAFDAC  \
# 50                              AQUIXIM SUSPENSION   B4-5761
# 265                          CLAVULIST 1000 TABLET   B4-6023
# 330                           ACENAC TABLETS 100MG   A4-4192
# 333                                    AQUIXIM 400   B4-5760
# 334                             CFXCLAV 325 TABLET   B4-6026
# 335                                     CEEZEX 500   B4-5741
# 478            CLAVULIN POWDER FOR ORAL SUSPENSION   A4-3022
# 479                         CLAVULIN 625MG TABLETS   A4-3477
# 523   JAWASIL ANTACID SUSPENSION (ORANGE FLAVOUR)   A11-0141
# 596                                   EMXIDINE GEL   B4-0593
# 597                         RGI CIPRO CAPLET 500MG   A4-2571
# 658                                    RAPICLAV-1G   A4-4489
# 729                              TRIAXIN INJECTION   04-8886
# 734                     TELDURET 40/12.5MG TABLETS   B4-6334
# ...

# %%
countryManufacturer = drug_napams[drug_napams['COUNTRY OF MANUFACTURE'].isnull()]

# %%
countryManufacturer
# Out:
#                                              PRODUCT NAME     NAFDAC  \
# 37                                                KOYODOX    B4-3219
# 38                                    AXACEF 250MG TABLET    04-5980
# 50                                     AQUIXIM SUSPENSION    B4-5761
# 265                                 CLAVULIST 1000 TABLET    B4-6023
# 330                                  ACENAC TABLETS 100MG    A4-4192
# 333                                           AQUIXIM 400    B4-5760
# 334                                    CFXCLAV 325 TABLET    B4-6026
# 335                                            CEEZEX 500    B4-5741
# 413                                     IBUMED SUSPENSION    A4-3786
# 464                         BAYLO KIT CAPSULES & TABLETS   A4-100052
# 468                                  GLIPVAS MET TABLETS   A4-100056
# 478                   CLAVULIN POWDER FOR ORAL SUSPENSION    A4-3022
# 479                                CLAVULIN 625MG TABLETS    A4-3477
# ...

# %%
approvalDate = drug_napams[drug_napams['APPROVAL DATE'].isnull()]

# %%
approvalDate
# Out:
#     PRODUCT NAME   NAFDAC    BRAND  \
# 206      FIDVITE  04-5097  FIDVITE
#
#                                                                                  ACTIVE ING  \
# 206  VITAMIN A 3,000IU, B1 2.0MG, B2 2.0MG, B6 2.0MG, NICOTINAMIDE 10.0MG ,VITAMIN D3 400IU
#
#     PHARM CLASS ROUTE OF ADMINISTRATION  STRENGTH DOSAGE FORM  \
# 206    VITAMINS                    ORAL       NaN       SYRUP
#
#     MARKETING CATEGORY              APPROVED INDICATION  \
# 206                NaN  DIETARY SUPPLEMENT FOR CHILDREN
#
#          NAME OF APPLICANT COUNTRY OF APPLICANT   NAME OF MANUFACTURER  \
# 206  FIDSON HEALTHCARE PLC              NIGERIA  FIDSON HEALTHCARE PLC
#
#     COUNTRY OF MANUFACTURE APPROVAL DATE EXPIRY DATE
# 206                NIGERIA           NaT         NaT

# %%
expiryDate = drug_napams[drug_napams['EXPIRY DATE'].isnull()]

# %%
expiryDate
# Out:
#     PRODUCT NAME   NAFDAC    BRAND  \
# 206      FIDVITE  04-5097  FIDVITE
#
#                                                                                  ACTIVE ING  \
# 206  VITAMIN A 3,000IU, B1 2.0MG, B2 2.0MG, B6 2.0MG, NICOTINAMIDE 10.0MG ,VITAMIN D3 400IU
#
#     PHARM CLASS ROUTE OF ADMINISTRATION  STRENGTH DOSAGE FORM  \
# 206    VITAMINS                    ORAL       NaN       SYRUP
#
#     MARKETING CATEGORY              APPROVED INDICATION  \
# 206                NaN  DIETARY SUPPLEMENT FOR CHILDREN
#
#          NAME OF APPLICANT COUNTRY OF APPLICANT   NAME OF MANUFACTURER  \
# 206  FIDSON HEALTHCARE PLC              NIGERIA  FIDSON HEALTHCARE PLC
#
#     COUNTRY OF MANUFACTURE APPROVAL DATE EXPIRY DATE
# 206                NIGERIA           NaT         NaT

# %%
noBrand = drug_napams.loc[drug_napams['BRAND'].isnull(), :]

# %%
noStrength = drug_napams.loc[drug_napams['STRENGTH'].isnull(), :]

# %%
# %whos
# Out:
# Variable                Type         Data/Info
# ----------------------------------------------
# approvalDate            DataFrame        PRODUCT NAME   NAFDAC<...>        NaT         NaT
# approvedIndication      DataFrame                     PRODUCT <...>DATE  \n338  2026-05-06
# col_for_website         list         n=16
# countryManufacturer     DataFrame                             <...> 2021-09-28  2026-09-27
# drug_for_website        DataFrame                             <...> 2020-11-30  2025-11-29
# drug_latest             DataFrame                             <...> 2021-09-28  2026-09-27
# drug_latest_rearrange   DataFrame                             <...> 2021-09-28  2026-09-27
# drug_napams             DataFrame                             <...> 2021-09-28  2026-09-27
# expiryDate              DataFrame        PRODUCT NAME   NAFDAC<...>        NaT         NaT
# marketingCat            ndarray      6: 6 elems, type `object`, 48 bytes
# ...

# %%
with pd.ExcelWriter('cleaning_drug2021.xlsx') as writer1:
    noNRN.to_excel(writer1, sheet_name = 'nafdac-number')
    noBrand.to_excel(writer1, sheet_name = 'brand')
    nopharmclass.to_excel(writer1, sheet_name = 'pharm-class')
    noStrength.to_excel(writer1, sheet_name = 'strength')
    nomarketingCategory.to_excel(writer1, sheet_name = 'marketing-category')
    approvedIndication.to_excel(writer1, sheet_name = 'approved-indication')
    nameManufacturer.to_excel(writer1, sheet_name = 'name-manufacturer')
    countryManufacturer.to_excel(writer1, sheet_name = 'country-manufacturer')
    approvalDate.to_excel(writer1, sheet_name = 'approval-date')
    expiryDate.to_excel(writer1, sheet_name = 'expiry-date')

# %%
capa_template = pd.read_excel('GBT_CAPA_Proposed_Template.xlsx', index_col=0)

# %%
capa_template.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 1 to 10
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Brand Name                  10 non-null     object
#  1   NAFDAC REG NO. (NRN)        10 non-null     object
#  2   Active Ingredient           10 non-null     object
#  3   STRENGTH                    10 non-null     object
#  4   Dosage Form                 10 non-null     object
#  5   Route                       10 non-null     object
#  6   Marketing Status            10 non-null     object
#  7   Applicant Holder Full Name  10 non-null     object
#  8   Applicant Holder Address    10 non-null     object
#  9   Manufacturer Name           10 non-null     object
#  10  Manufacturer Address        10 non-null     object
#  11  COUNTRY                     10 non-null     object
#  12  Approval Date               10 non-null     object
# ...

# %%
capa_template.sample(n=5, random_state=42)
# Out:
#                              Brand Name NAFDAC REG NO. (NRN)  \
# 9                            PENTAZINE               A4-0025
# 2                             IMATINIB               B4-9586
# 6  WOODS' PEPPERMINT ANTITUSSIVE SYRUP               B4-9627
# 1                             IMATINIB               B4-8071
# 8                             DICLOWIN               A4-7921
#
#                            Active Ingredient       STRENGTH Dosage Form  \
# 9                          PROMETHAZINE HCL            50MG   INJECTION
# 2                                  IMATINIB           100MG     TABLETS
# 6  DEXTROMETHORPAN HBR; DIPHENHYDRAMINE HCL   7.5MG; 12.5MG      LIQUID
# 1                                  IMATINIB           400MG     TABLETS
# 8                         DICLOFENAC SODIUM        75MG/3ML   INJECTION
#
#         Route Marketing Status Applicant Holder Full Name  \
# 9  PARENTERAL               RX        CHUPET PHARM CO LTD
# ...
