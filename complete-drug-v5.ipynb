# %%
import pandas as pd
import numpy as np

# %%
drug = pd.read_excel('new-drug-v4.xlsx', index_col=0)

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5854 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5854 non-null   object
# ...

# %%
drug.iloc[3172]
# Out:
# PRODUCT NAME                                                                            OSWORTH PARACETAMOL TABLET
# NAFDAC                                                                                                     A4-4053
# BRAND                                                                                                      OSWORTH
# GENERICS                                                                                               PARACETAMOL
# PRODUCT CATEGORY                                                                                        HUMAN DRUG
# PHARM CLASS                                                                                ANALGESIC & ANTIPYRETIC
# ROUTE OF ADMINISTRATION                                                                                       ORAL
# GROUP                                                                                                         DRUG
# ...

# %%
expCountry = drug['COUNTRY.1']

# %%
expCountry.unique()
# Out:
# array(['NIGERIA', 'SOUTH AFRICA', 'CHINA', 'PAKISTAN', 'UNITED KINGDOM',
#        'ITALY', 'INDIA', 'IRAN', 'VIETNAM', 'RUSSIA', 'EGYPT', 'PORTUGAL',
#        'SPAIN', 'BANGLADESH', 'KENYA', 'INDONESIA', 'THAILAND', 'FRANCE',
#        'AUSTRIA', 'IRELAND', 'GERMANY', 'UNITED KINDGOM', 'SWEDEN',
#        'SWITZERLAND', 'MALAYSIA', 'THE NETHERLANDS', 'JORDAN',
#        'UNITED STATES OF AMERICA', 'GHANA', 'TANZANIA', 'KOREA', 'CANADA',
#        'CYPRUS', 'BELGIUM', 'POLAND', 'GREECE', 'EU', 'PUERTO RICO',
#        'BULGARIA', 'LEBANON', 'PERU', 'AUSTRALIA', 'MALTA', 'TURKEY',
#        'ISRAEL', 'UAE', 'CZECH REPUBLIC', 'SYRIA', 'MACEDONIA', 'ROMANIA',
#        'FINLAND', 'UKRAINE', 'SLOVENIA', 'UGANDA'], dtype=object)

# %%
expCountry.nunique()
# Out:
# 54

# %%
expCountry.value_counts()
# Out:
# INDIA                       3025
# NIGERIA                     1506
# CHINA                        576
# PAKISTAN                      89
# GERMANY                       83
# BANGLADESH                    68
# UNITED KINDGOM                47
# FRANCE                        43
# JORDAN                        38
# ITALY                         33
# SWITZERLAND                   27
# UNITED KINGDOM                22
# EGYPT                         21
# SOUTH AFRICA                  18
# MALAYSIA                      17
# SPAIN                         17
# VIETNAM                       17
# INDONESIA                     16
# GHANA                         14
# PORTUGAL                      13
# SWEDEN                        13
# POLAND                        12
# BELGIUM                       12
# TANZANIA                      12
# KENYA                         10
# UNITED STATES OF AMERICA      10
# IRELAND                       10
# KOREA                          8
# ...

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5854 entries, 0 to 5853
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             5854 non-null   object
#  1   NAFDAC                   5854 non-null   object
#  2   BRAND                    5854 non-null   object
#  3   GENERICS                 5854 non-null   object
#  4   PRODUCT CATEGORY         5854 non-null   object
#  5   PHARM CLASS              5854 non-null   object
#  6   ROUTE OF ADMINISTRATION  5854 non-null   object
#  7   GROUP                    5854 non-null   object
#  8   ACTIVE ING               5854 non-null   object
#  9   STRENGTH                 5724 non-null   object
#  10  PRESENTATION             5828 non-null   object
#  11  DOSAGE FORM              5854 non-null   object
#  12  PACK SIZE                5842 non-null   object
#  13  MARKETING CATEGORY       5854 non-null   object
# ...

# %%
drug.loc[drug['BRAND'] == 'DANA-CPM']
# Out:
#         PRODUCT NAME            NAFDAC     BRAND                  GENERICS  \
# 1215  DANA-CPM SYRUP  NO NAFDAC NUMBER  DANA-CPM  CHLORPHENIRAMINE MALEATE
#
#      PRODUCT CATEGORY    PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 1215       HUMAN DRUG  ANTIHISTAMINE                    ORAL  DRUG
#
#                              ACTIVE ING STRENGTH  ...  APPROVED INDICATION  \
# 1215  CHLORPHENIRAMINE MALEATE 2MG /5ML  2MG/5ML  ...  RELIEF FROM ALLERGY
#
#      NAME OF APPLICANT                               APPLICANT ADDRESS  \
# 1215    DANA PHARM LTD  SHIRORO DAM ROAD, MAITUMBI, MINNA, NIGER STATE
#
#       COUNTRY NAME OF MANUFACTURER MANUFACTURER ADDRESS COUNTRY.1  \
# 1215  NIGERIA    SAME AS APPLICANT    SAME AS APPLICANT   NIGERIA
#
#             APPROVAL DATE EXPIRY DATE  date_time
# 1215  2017-08-08 00:00:00  2022-08-07 2017-08-08
#
# [1 rows x 24 columns]

# %%
pharmclass = drug['PHARM CLASS'].unique()

# %%
len(pharmclass)
# Out:
# 786

# %%
route = drug['ROUTE OF ADMINISTRATION'].unique()

# %%
len(route)
# Out:
# 33

# %%
group = drug['GROUP']

# %%
group.unique()
# Out:
# array(['DRUG'], dtype=object)

# %%
strength = drug['STRENGTH']

# %%
strength
# Out:
# 0                54MG, 5MCG, 200MCG, 2MG, 4MG, 2MG, 0.4MG
# 1                54MG, 3MG, 2MG, 5MCG, 200MCG, 5MG, 0.4MG
# 2            120MG, 1MG, 1MG, 2MG, 1MCG, 5MG, 15MG, 100MG
# 3       40MG, 23.4MG, 0.98MG, 0.39MG, 3.92MG, 0.39MG, ...
# 4                                     250MG, 250MG, 250MG
#                               ...
# 5849                                                935MG
# 5850                                               1000MG
# 5851     10000IU, VITAMIN D3 200IU, VITAMIN B1 1MG, 2 1MG
# 5852    2500IU, L-LEUCINE 18.3MG, PYRIDOXINE HYDROCHLO...
# 5853                                       4MG, 25MG, 5MG
# Name: STRENGTH, Length: 5854, dtype: object

# %%
presentation = drug['PRESENTATION']

# %%
presentation
# Out:
# 0                SYRUP, X 100ML
# 1       SYRUP, X 100ML, X 300ML
# 2       SYRUP, X 100ML, X 200ML
# 3                SYRUP, X 200ML
# 4           SUSPENSION, X 200ML
#                  ...
# 5849              CAPSULE3 X 10
# 5850              CAPSULE2 X 15
# 5851             CAPSULE 2 X 15
# 5852            LIQUID1 X 200ML
# 5853            LIQUID1 X 200ML
# Name: PRESENTATION, Length: 5854, dtype: object

# %%
dosage = drug['DOSAGE FORM'].unique()

# %%
pharmList = list(pharmclass)

# %%
pharmFrame = pd.DataFrame(pharmList, columns=['PHARM CLASS'])

# %%
doseList = list(dosage)

# %%
doseFrame = pd.DataFrame(doseList, columns=['DOSAGE FORM'])

# %%
doseFrame
# Out:
#            DOSAGE FORM
# 0                SYRUP
# 1           SUSPENSION
# 2             SOLUTION
# 3               LIQUID
# 4             CAPSULE,
# ..                 ...
# 140    SOFGEL CAPSULES
# 141      FOR INJECTION
# 142  CAPSULES & TABLET
# 143        SUSPENSION,
# 144            LINCTUS
#
# [145 rows x 1 columns]

# %%
with pd.ExcelWriter('drug-data-list.xlsx') as writer:
    pharmFrame.to_excel(writer, sheet_name = 'pharm-class')
    doseFrame.to_excel(writer, sheet_name = 'dosage-form')

# %%
packsize = drug['PACK SIZE']

# %%
packsize
# Out:
# 0              1 X 100ML
# 1       X 100ML, X 300ML
# 2       X 100ML, X 200ML
# 3                X 200ML
# 4                X 200ML
#               ...
# 5849              3 X 10
# 5850              2 X 15
# 5851              2 X 15
# 5852           1 X 200ML
# 5853           1 X 200ML
# Name: PACK SIZE, Length: 5854, dtype: object

# %%
marketingcat = drug['MARKETING CATEGORY']

# %%
marketingcat.unique()
# Out:
# array(['OVER THE COUNTER (OTC)', 'PRESCRIPTION ONLY MEDICINE (POM)'],
#       dtype=object)

# %%
drug.iloc[3780,:]
# Out:
# PRODUCT NAME                                                CELOPRO CAPSULES
# NAFDAC                                                               B4-9895
# BRAND                                                                CELOPRO
# GENERICS                                    CARBONYL IRON + VITAMIN+SELENIUM
# PRODUCT CATEGORY                                                  HUMAN DRUG
# PHARM CLASS                                                           NSAIDS
# ROUTE OF ADMINISTRATION                                                 ORAL
# GROUP                                                                   DRUG
# ACTIVE ING                                                         CELECOXIB
# STRENGTH                                                               200MG
# PRESENTATION                                                   CAPSULE, 1X10
# DOSAGE FORM                                                          CAPSULE
# ...

# %%
presentation[0]
# Out:
# 'SYRUP, X 100ML'

# %%
type(presentation)
# Out:
# pandas.core.series.Series

# %%
presentation = presentation[0]

# %%
presentation.split(',')
# Out:
# ['SYRUP', ' X 100ML']

# %%
pd.set_option('display.max_colwidth', 20)
pd.set_option('display.max_column', None)
drug.iloc[2,:]
# Out:
# PRODUCT NAME                     JAWARON TONIC
# NAFDAC                                 04-2037
# BRAND                                  JAWARON
# GENERICS                   FERRIC GLUCONATE...
# PRODUCT CATEGORY                    HUMAN DRUG
# PHARM CLASS                NUTRITIONAL SUPP...
# ROUTE OF ADMINISTRATION                   ORAL
# GROUP                                     DRUG
# ACTIVE ING                 FERRIC GLUCONATE...
# STRENGTH                   120MG, 1MG, 1MG,...
# PRESENTATION               SYRUP, X 100ML, ...
# DOSAGE FORM                              SYRUP
# PACK SIZE                     X 100ML, X 200ML
# MARKETING CATEGORY         OVER THE COUNTER...
# APPROVED INDICATION        PREVENTION OF AN...
# NAME OF APPLICANT          JAWA INTERNATION...
# APPLICANT ADDRESS          PLOT 6 ABIMBOLA ...
# COUNTRY                                NIGERIA
# NAME OF MANUFACTURER       JAWA INTERNATION...
# MANUFACTURER ADDRESS       PLOT 6 ABIMBOLA ...
# ...

# %%
treated = pd.read_excel('treated.xlsx',sheet_name=None, index_col=0)

# %%
treated.keys()
# Out:
# dict_keys(['strength', 'presentation', 'dosage-form', 'packsize', 'marketing-category', 'approved-indication', 'applicant', 'address-applicant', 'missing-approval-date'])

# %%
approval = pd.read_excel('treated.xlsx',sheet_name='missing-approval-date',index_col=0,parse_dates=['APPROVAL DATE'])

# %%
approval.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 1293 to 5738
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PRODUCT NAME             7 non-null      object
#  1   NAFDAC                   7 non-null      object
#  2   BRAND                    7 non-null      object
#  3   GENERICS                 7 non-null      object
#  4   PRODUCT CATEGORY         7 non-null      object
#  5   PHARM CLASS              7 non-null      object
#  6   ROUTE OF ADMINISTRATION  7 non-null      object
#  7   GROUP                    7 non-null      object
#  8   ACTIVE ING               7 non-null      object
#  9   STRENGTH                 7 non-null      object
#  10  PRESENTATION             7 non-null      object
#  11  DOSAGE FORM              7 non-null      object
#  12  PACK SIZE                7 non-null      object
#  13  MARKETING CATEGORY       7 non-null      object
# ...

# %%
approval
# Out:
#              PRODUCT NAME   NAFDAC      BRAND             GENERICS  \
# 1293   SPEDRA 100 TABLETS  B4-7413     SPEDRA             AVANAFIL
# 3860          VOLIGEL GEL  C4-0013    VOLIGEL  DICLOFENAC DIETH...
# 3862     WATE-ON EMULSION  04-1232    WATE-ON  NICOTINAMIDE+ MU...
# 3969    OCEXONE INJECTION  A4-9169    OCEXONE          CEFTRIAXONE
# 3973   CEDFLOXAC INFUSION  B4-4736  CEDFLOXAC        CIPROFLOXACIN
# 5638  HANBET METRONIDA...  A4-8794     HANBET  METRONIDAZOLE 50...
# 5738       AVROMAL TABLET  A4-4050    AVROMAL  ARTEMETHER, LUME...
#
#      PRODUCT CATEGORY          PHARM CLASS ROUTE OF ADMINISTRATION  GROUP  \
# 1293       HUMAN DRUG  TYPE 5 PHOSPHODI...                 ORAL     DRUGS
# 3860       HUMAN DRUG            ANALGESIC              TOPICAL      DRUG
# 3862       HUMAN DRUG         MULTIVITAMIN              TOPICAL      DRUG
# 3969       HUMAN DRUG           ANTIBIOTIC  INTRAVENOUS/INTR...      DRUG
# ...

# %%
drug.index[drug['date_time'].isnull()].tolist()
# Out:
# [1293, 3860, 3862, 3969, 3973, 5638, 5738]

# %%
list(approval.index)
# Out:
# [1293, 3860, 3862, 3969, 3973, 5638, 5738]

# %%
dict(zip(drug.index,drug['APPROVAL DATE']))
# Out:
# {0: '2016-07-28 00:00:00',
#  1: '2016-07-28 00:00:00',
#  2: '2016-07-28 00:00:00',
#  3: '2016-07-28 00:00:00',
#  4: '2016-08-25 00:00:00',
#  5: '2016-10-05 00:00:00',
#  6: '2016-10-05 00:00:00',
#  7: '2016-10-05 00:00:00',
#  8: '2016-10-05 00:00:00',
#  9: '2016-10-05 00:00:00',
#  10: '2016-10-05 00:00:00',
#  11: '2016-10-05 00:00:00',
#  12: '2016-10-05 00:00:00',
#  13: '2016-10-05 00:00:00',
#  14: '2016-10-05 00:00:00',
#  15: '2016-11-15 00:00:00',
#  16: '2016-11-15 00:00:00',
#  17: '2016-11-15 00:00:00',
#  18: '2016-11-15 00:00:00',
#  19: '2016-11-15 00:00:00',
#  20: '2016-11-15 00:00:00',
#  21: '2016-11-15 00:00:00',
#  22: '2016-11-15 00:00:00',
#  23: '2016-11-15 00:00:00',
#  24: '2016-11-15 00:00:00',
#  25: '2016-11-15 00:00:00',
#  26: '2016-11-15 00:00:00',
#  27: '2016-11-15 00:00:00',
#  28: '2016-11-15 00:00:00',
#  29: '2016-11-15 00:00:00',
#  30: '2016-11-15 00:00:00',
#  31: '2016-11-15 00:00:00',
#  32: '2016-11-15 00:00:00',
# ...

# %%
dict(zip(approval.index,approval['APPROVAL DATE']))
# Out:
# {1293: Timestamp('2017-08-29 00:00:00'),
#  3860: Timestamp('2019-09-26 00:00:00'),
#  3862: Timestamp('2019-09-26 00:00:00'),
#  3969: Timestamp('2019-12-20 00:00:00'),
#  3973: Timestamp('2019-12-20 00:00:00'),
#  5638: Timestamp('2020-12-21 00:00:00'),
#  5738: Timestamp('2020-11-10 00:00:00')}

# %%
tmp_d = {}

# %%
tmp_d.update(dict(zip(drug.index,drug['APPROVAL DATE'])))

# %%
tmp_d[1293]
# Out:
# 'FRANCE'

# %%
tmp_d.update(dict(zip(approval.index,approval['APPROVAL DATE'])))

# %%
tmp_d[1293]
# Out:
# Timestamp('2017-08-29 00:00:00')

# %%
drug['APPROVAL DATE'] = pd.DataFrame(tmp_d.items())

# %%
drug['APPROVAL DATE'].replace(tmp_d, inplace=True)

# %%
drug.iloc[5738]
# Out:
# PRODUCT NAME                    AVROMAL TABLET
# NAFDAC                                 A4-4050
# BRAND                                  AVROMAL
# GENERICS                   ARTEMETHER, LUME...
# PRODUCT CATEGORY                    HUMAN DRUG
# PHARM CLASS                        ANTIMALARIA
# ROUTE OF ADMINISTRATION                   ORAL
# GROUP                                     DRUG
# ACTIVE ING                 ARTEMETHER , LUM...
# STRENGTH                                 240MG
# PRESENTATION                      TABLET1 X 12
# DOSAGE FORM                             TABLET
# PACK SIZE                               1 X 12
# MARKETING CATEGORY         OVER THE COUNTER...
# APPROVED INDICATION        TREATMENT OF UNC...
# NAME OF APPLICANT              AVRO PHARMA LTD
# APPLICANT ADDRESS          11, KAARA STREET...
# COUNTRY                                NIGERIA
# NAME OF MANUFACTURER        SKG PHARMA LIMITED
# MANUFACTURER ADDRESS       7/9, SAPARA STRE...
# ...

# %%
#indexes = drug.loc[drug.NAFDAC.isin(approval.NAFDAC.values)].index
#drug.at[indexes, 'APPROVAL DATE'] = approval['APPROVAL DATE'].values

# %%
# %run null_values.py

# %%
nullcols(drug)
# Out:
# STRENGTH               130
# PRESENTATION            26
# PACK SIZE               12
# APPROVED INDICATION      1
# NAME OF APPLICANT       23
# APPLICANT ADDRESS        2
# date_time                7
# dtype: int64

# %%
app_address = pd.read_excel('treated.xlsx', sheet_name='address-applicant', index_col=0)

# %%
app_address
# Out:
#            PRODUCT NAME   NAFDAC     BRAND             GENERICS  \
# 2850  VITASOPT EYE DROP  B4-9091  VITASOPT  DORZOLAMIDE +TIM...
# 3043            GEMTERO  B4-8260   GEMTERO          GEMCITABINE
#
#      PRODUCT CATEGORY          PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 2850       HUMAN DRUG  INTRAOCULAR PRES...           OPHTHALMIC     DRUG
# 3043       HUMAN DRUG  ANTI-NEOPLASTIC ...          INTRAVENOUS     DRUG
#
#                ACTIVE ING  STRENGTH         PRESENTATION          DOSAGE FORM  \
# 2850  DORZOLAMIDE 2%, ...  2%, 0.5%    EYE DROP, 1 X 5ML  OPHTHALMIC SOLUTION
# 3043          GEMCITABINE        1G  POWDER FOR INJEC...  POWDER FOR INJEC...
#
#      PACK SIZE   MARKETING CATEGORY  APPROVED INDICATION    NAME OF APPLICANT  \
# 2850   1 X 5ML  PRESCRIPTION ONL...  TREATMENT OF GLA...  VITACARE PHARMAC...
# 3043    1 VIAL  PRESCRIPTION ONL...  TREATMENT OF CANCER  HETERO LABS NIG....
#
# ...

# %%
add_app = {}

# %%
add_app.update(dict(zip(drug.index,drug['APPLICANT ADDRESS'])))

# %%
add_app[2850]
# Out:
# nan

# %%
add_app.update(dict(zip(app_address.index,app_address['APPLICANT ADDRESS'])))

# %%
add_app[2850]
# Out:
# '33, ANYIKA STREET, AWADA OBOSI, ANAMBRA STATE..'

# %%
drug.iloc[2850]
# Out:
# PRODUCT NAME                 VITASOPT EYE DROP
# NAFDAC                                 B4-9091
# BRAND                                 VITASOPT
# GENERICS                   DORZOLAMIDE +TIM...
# PRODUCT CATEGORY                    HUMAN DRUG
# PHARM CLASS                INTRAOCULAR PRES...
# ROUTE OF ADMINISTRATION             OPHTHALMIC
# GROUP                                     DRUG
# ACTIVE ING                 DORZOLAMIDE 2%, ...
# STRENGTH                              2%, 0.5%
# PRESENTATION                 EYE DROP, 1 X 5ML
# DOSAGE FORM                OPHTHALMIC SOLUTION
# PACK SIZE                              1 X 5ML
# MARKETING CATEGORY         PRESCRIPTION ONL...
# APPROVED INDICATION        TREATMENT OF GLA...
# NAME OF APPLICANT          VITACARE PHARMAC...
# APPLICANT ADDRESS                          NaN
# COUNTRY                                NIGERIA
# NAME OF MANUFACTURER          ARISTOPHARMA LTD
# MANUFACTURER ADDRESS       PLOT NO 21, ROAD...
# ...

# %%
drug['APPLICANT ADDRESS'] = pd.DataFrame(add_app.items())

# %%
drug['APPLICANT ADDRESS'].replace(add_app, inplace=True)

# %%
drug.iloc[2850]
# Out:
# PRODUCT NAME                 VITASOPT EYE DROP
# NAFDAC                                 B4-9091
# BRAND                                 VITASOPT
# GENERICS                   DORZOLAMIDE +TIM...
# PRODUCT CATEGORY                    HUMAN DRUG
# PHARM CLASS                INTRAOCULAR PRES...
# ROUTE OF ADMINISTRATION             OPHTHALMIC
# GROUP                                     DRUG
# ACTIVE ING                 DORZOLAMIDE 2%, ...
# STRENGTH                              2%, 0.5%
# PRESENTATION                 EYE DROP, 1 X 5ML
# DOSAGE FORM                OPHTHALMIC SOLUTION
# PACK SIZE                              1 X 5ML
# MARKETING CATEGORY         PRESCRIPTION ONL...
# APPROVED INDICATION        TREATMENT OF GLA...
# NAME OF APPLICANT          VITACARE PHARMAC...
# APPLICANT ADDRESS          33, ANYIKA STREE...
# COUNTRY                                NIGERIA
# NAME OF MANUFACTURER          ARISTOPHARMA LTD
# MANUFACTURER ADDRESS       PLOT NO 21, ROAD...
# ...

# %%
applicant = treated['applicant']

# %%
type(applicant)
# Out:
# pandas.core.frame.DataFrame

# %%
applicant
# Out:
#              PRODUCT NAME    NAFDAC              BRAND             GENERICS  \
# 633      JADURON CAPSULES   A4-4061            JADURON  FERRIC AMMONIUM ...
# 1348  BIORAJ PARACETAM...  A11-0323             BIORAJ  PARACETAMOL, DIC...
# 1349  JAWALK ORAL SOLU...  A11-0138             JAWALK  POTASSIUM CITRAT...
# 1350       PECRITON SYRUP  A11-0325           PECRITON  CHLORPHENIRAMINE...
# 1351      GARYLONG TABLET   B4-3550           GARYLONG  CYPROHEPTADINE H...
# 1352  ANNMOX AMOXICILL...  A11-0326             ANNMOX          AMOXICILLIN
# 1353        MOBITIN SYRUP  A11-0115            MOBITIN  CHLORPHENIRAMINE...
# 1354    MYZITH 500 TABLET  A11-0327             MYZITH         AZITHROMYCIN
# 1355       VARSPAR TABLET   A4-5476            VARSPAR       AMLODIPINE 5MG
# 1356         NESTIN CREAM   04-6365             NESTIN         CLOTRIMAZOLE
# 1357       VARSPAR TABLET   A4-5475            VARSPAR           AMLODIPINE
# ...

# %%
drug[drug['NAFDAC'] == 'A11-0332']
# Out:
#         PRODUCT NAME    NAFDAC    BRAND             GENERICS PRODUCT CATEGORY  \
# 1038  BRADTEM CAPLET  A11-0332  BRADTEM  DIHYDROARTEMISIN...       HUMAN DRUG
#
#        PHARM CLASS ROUTE OF ADMINISTRATION GROUP           ACTIVE ING  \
# 1038  ANTIMALARIAL                 ORAL     DRUG  DIHYDROARTEMISIN...
#
#          STRENGTH   PRESENTATION DOSAGE FORM PACK SIZE   MARKETING CATEGORY  \
# 1038  40MG, 320MG  CAPLET, 1 X 8      CAPLET     1 X 8  OVER THE COUNTER...
#
#       APPROVED INDICATION    NAME OF APPLICANT    APPLICANT ADDRESS  COUNTRY  \
# 1038  TREATMENT OF MAL...  BRADFORD PHARMAC...  9A, BALOGUN STRE...  NIGERIA
#
#      NAME OF MANUFACTURER MANUFACTURER ADDRESS COUNTRY.1        APPROVAL DATE  \
# 1038    ECOMED PHARMA LTD  32, LYNSON CHEMI...   NIGERIA  2017-02-08 00:00:00
#
#      EXPIRY DATE  date_time
# 1038  2022-02-07 2017-02-08

# %%
##drug.drop(1602, inplace=True)

# %%
drug[drug['NAFDAC'] == 'A11-0328']
# Out:
#         PRODUCT NAME    NAFDAC    BRAND             GENERICS PRODUCT CATEGORY  \
# 1602  BRADTEM CAPLET  A11-0328  BRADTEM  DIHYDROARTEMISIN...       HUMAN DRUG
#
#        PHARM CLASS ROUTE OF ADMINISTRATION GROUP           ACTIVE ING  \
# 1602  ANTIMALARIAL                 ORAL     DRUG  DIHYDROARTEMISIN...
#
#          STRENGTH   PRESENTATION DOSAGE FORM PACK SIZE   MARKETING CATEGORY  \
# 1602  40MG, 320MG  CAPLET, 1 X 8     CAPLET,     1 X 8  OVER THE COUNTER...
#
#       APPROVED INDICATION NAME OF APPLICANT    APPLICANT ADDRESS  COUNTRY  \
# 1602  TREATMENT OF MAL...               NaN  9A, BALOGUN STRE...  NIGERIA
#
#      NAME OF MANUFACTURER MANUFACTURER ADDRESS COUNTRY.1        APPROVAL DATE  \
# 1602    ECOMED PHARMA LTD  32, LYNSON CHEMI...   NIGERIA  2017-02-08 00:00:00
#
#      EXPIRY DATE  date_time
# 1602  2022-02-07 2017-02-08

# %%
drug.iloc[1602]
# Out:
# PRODUCT NAME                    BRADTEM CAPLET
# NAFDAC                                A11-0328
# BRAND                                  BRADTEM
# GENERICS                   DIHYDROARTEMISIN...
# PRODUCT CATEGORY                    HUMAN DRUG
# PHARM CLASS                       ANTIMALARIAL
# ROUTE OF ADMINISTRATION                   ORAL
# GROUP                                     DRUG
# ACTIVE ING                 DIHYDROARTEMISIN...
# STRENGTH                           40MG, 320MG
# PRESENTATION                     CAPLET, 1 X 8
# DOSAGE FORM                            CAPLET,
# PACK SIZE                                1 X 8
# MARKETING CATEGORY         OVER THE COUNTER...
# APPROVED INDICATION        TREATMENT OF MAL...
# NAME OF APPLICANT                          NaN
# APPLICANT ADDRESS          9A, BALOGUN STRE...
# COUNTRY                                NIGERIA
# NAME OF MANUFACTURER         ECOMED PHARMA LTD
# MANUFACTURER ADDRESS       32, LYNSON CHEMI...
# ...

# %%
name_app = {}

# %%
name_app.update(dict(zip(drug.index,drug['NAME OF APPLICANT'])))

# %%
name_app[633]
# Out:
# nan

# %%
name_app.update(dict(zip(applicant.index,applicant['NAME OF APPLICANT'])))

# %%
name_app[633]
# Out:
# 'PAL PHARMA IND LTD'

# %%
drug['NAME OF APPLICANT'] = pd.DataFrame(name_app.items())

# %%
drug['NAME OF APPLICANT'].replace(name_app,inplace=True)

# %%
drug.iloc[[1598,1599]]
# Out:
#              PRODUCT NAME    NAFDAC   BRAND             GENERICS  \
# 1598  HYSTOL ANTISEPTI...  A11-0321  HYSTOL  CHLOROXYLENOL,OL...
# 1599  EFOBI METHYLATED...  A11-0322   EFOBI  ETHANOL, WOOD NA...
#
#      PRODUCT CATEGORY   PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 1598       HUMAN DRUG  DISINFECTANT              TOPICAL     DRUG
# 1599       HUMAN DRUG    ANTISEPTIC              TOPICAL     DRUG
#
#                ACTIVE ING             STRENGTH       PRESENTATION DOSAGE FORM  \
# 1598  CHLOROXYLENOL B....  4.8% W/W, 8.38% ...  LIQUID, 1 X 250ML     LIQUID,
# 1599  ETHANOL 95%, WOO...              95%, 5%  LIQUID, 1 X 200ML     LIQUID,
#
#       PACK SIZE   MARKETING CATEGORY  APPROVED INDICATION NAME OF APPLICANT  \
# 1598  1 X 250ML  OVER THE COUNTER...  HOUSEHOLD DISINF...               NaN
# 1599  1 X 200ML  OVER THE COUNTER...  HOUSEHOLD ANTISE...               NaN
#
#         APPLICANT ADDRESS  COUNTRY NAME OF MANUFACTURER MANUFACTURER ADDRESS  \
# ...

# %%
drug.iloc[[1598,1599],15] = 'EFOBI NIGERIA LTD'

# %%
drug.iloc[[1598,1599]]
# Out:
#              PRODUCT NAME    NAFDAC   BRAND             GENERICS  \
# 1598  HYSTOL ANTISEPTI...  A11-0321  HYSTOL  CHLOROXYLENOL,OL...
# 1599  EFOBI METHYLATED...  A11-0322   EFOBI  ETHANOL, WOOD NA...
#
#      PRODUCT CATEGORY   PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 1598       HUMAN DRUG  DISINFECTANT              TOPICAL     DRUG
# 1599       HUMAN DRUG    ANTISEPTIC              TOPICAL     DRUG
#
#                ACTIVE ING             STRENGTH       PRESENTATION DOSAGE FORM  \
# 1598  CHLOROXYLENOL B....  4.8% W/W, 8.38% ...  LIQUID, 1 X 250ML     LIQUID,
# 1599  ETHANOL 95%, WOO...              95%, 5%  LIQUID, 1 X 200ML     LIQUID,
#
#       PACK SIZE   MARKETING CATEGORY  APPROVED INDICATION  NAME OF APPLICANT  \
# 1598  1 X 250ML  OVER THE COUNTER...  HOUSEHOLD DISINF...  EFOBI NIGERIA LTD
# 1599  1 X 200ML  OVER THE COUNTER...  HOUSEHOLD ANTISE...  EFOBI NIGERIA LTD
#
#         APPLICANT ADDRESS  COUNTRY NAME OF MANUFACTURER MANUFACTURER ADDRESS  \
# ...

# %%
indication = treated['approved-indication']

# %%
pd.set_option('display.max_colwidth', None)
indication
# Out:
#               PRODUCT NAME   NAFDAC      BRAND   GENERICS PRODUCT CATEGORY  \
# 3579   MIDAZOLAM INJECTION  B4-9661  MIDAZOLAM  MIDAZOLAM       HUMAN DRUG
# 4100  GRAPROFEN SUSPENSION  A4-8078  GRAPROFEN  IBUPROFEN       HUMAN DRUG
#
#      PHARM CLASS    ROUTE OF ADMINISTRATION GROUP    ACTIVE ING   STRENGTH  \
# 3579    SEDATIVE  INTRAVENOUS/INTRAMUSCULAR  DRUG     MIDAZOLAM       15MG
# 4100       NSAID                       ORAL  DRUG  IBUPROFEN BP  100MG/5ML
#
#                     PRESENTATION DOSAGE FORM          PACK SIZE  \
# 3579  INJECTION, 5 AMPOULES X3ML   INJECTION  5 AMPOULES OF 3ML
# 4100          SUSPENSION,1X100ML  SUSPENSION          1 X 100ML
#
#               MARKETING CATEGORY  \
# 3579  PRESCRIPTION ONLY MEDICINE
# 4100            OVER THE COUNTER
#
#                                             APPROVED INDICATION  \
# 3579  FOR PREOPERATIVE SEDATION/ANXIOLYSIS/ANESTHESIA INDUCTION
# 4100                           FOR PAIN, FEVER AND INFLAMMATION
#
# ...

# %%
app_ind = {}

# %%
app_ind.update(dict(zip(drug.index,drug['APPROVED INDICATION'])))

# %%
app_ind[3579]
# Out:
# 'FOR ANXIOLYTIC, SEDATION'

# %%
app_ind.update(dict(zip(indication.index,indication['APPROVED INDICATION'])))

# %%
app_ind[3579]
# Out:
# 'FOR PREOPERATIVE SEDATION/ANXIOLYSIS/ANESTHESIA INDUCTION'

# %%
drug['APPROVED INDICATION'] = pd.DataFrame(app_ind.items())

# %%
drug['APPROVED INDICATION'].replace(app_ind, inplace=True)

# %%
drug.iloc[[3579,4100]]
# Out:
#               PRODUCT NAME   NAFDAC      BRAND   GENERICS PRODUCT CATEGORY  \
# 3579   MIDAZOLAM INJECTION  B4-9661  MIDAZOLAM  MIDAZOLAM       HUMAN DRUG
# 4100  GRAPROFEN SUSPENSION  A4-8078  GRAPROFEN  IBUPROFEN       HUMAN DRUG
#
#      PHARM CLASS    ROUTE OF ADMINISTRATION GROUP    ACTIVE ING   STRENGTH  \
# 3579    SEDATIVE  INTRAVENOUS/INTRAMUSCULAR  DRUG     MIDAZOLAM       15MG
# 4100       NSAID                       ORAL  DRUG  IBUPROFEN BP  100MG/5ML
#
#                     PRESENTATION DOSAGE FORM          PACK SIZE  \
# 3579  INJECTION, 5 AMPOULES X3ML   INJECTION  5 AMPOULES OF 3ML
# 4100          SUSPENSION,1X100ML  SUSPENSION          1 X 100ML
#
#                     MARKETING CATEGORY  \
# 3579  PRESCRIPTION ONLY MEDICINE (POM)
# 4100            OVER THE COUNTER (OTC)
#
#                                             APPROVED INDICATION  \
# 3579  FOR PREOPERATIVE SEDATION/ANXIOLYSIS/ANESTHESIA INDUCTION
# ...

# %%
mc = treated['marketing-category']

# %%
mc
# Out:
#                PRODUCT NAME   NAFDAC           BRAND  \
# 1683  SHREE MANSIFED TABLET  B4-6719  SHREE MANSIFED
#
#                       GENERICS PRODUCT CATEGORY     PHARM CLASS  \
# 1683  CHLORPHENIRAMINE MALEATE       HUMAN DRUG  ANTI HISTAMINE
#
#      ROUTE OF ADMINISTRATION  GROUP                ACTIVE ING STRENGTH  \
# 1683                    ORAL  DRUGS  CHLORPHENIRAMINE MALEATE      4MG
#
#           PRESENTATION DOSAGE FORM PACK SIZE MARKETING CATEGORY  \
# 1683  TABLETS, 10 X 10     TABLETS   10 X 10                POM
#
#                 APPROVED INDICATION        NAME OF APPLICANT  \
# 1683  RELIEF OF ALLERGIC CONDITIONS  SHREE ALOE PHARM CO LTD
#
#                                                     APPLICANT ADDRESS  \
# 1683  F46, NWANGENE STREET HOUSING ESTATE FEGGE ONITSHA ANAMBRA STATE
#
#       COUNTRY   NAME OF MANUFACTURER  \
# 1683  NIGERIA  IMPUSLE PHARM PVT LTD
#
#                                                                   MANUFACTURER ADDRESS  \
# ...

# %%
mc['MARKETING CATEGORY'].replace({'POM':'PRESCRIPTION ONLY MEDICINE (POM)'},inplace=True)

# %%
mc
# Out:
#                PRODUCT NAME   NAFDAC           BRAND  \
# 1683  SHREE MANSIFED TABLET  B4-6719  SHREE MANSIFED
#
#                       GENERICS PRODUCT CATEGORY     PHARM CLASS  \
# 1683  CHLORPHENIRAMINE MALEATE       HUMAN DRUG  ANTI HISTAMINE
#
#      ROUTE OF ADMINISTRATION  GROUP                ACTIVE ING STRENGTH  \
# 1683                    ORAL  DRUGS  CHLORPHENIRAMINE MALEATE      4MG
#
#           PRESENTATION DOSAGE FORM PACK SIZE  \
# 1683  TABLETS, 10 X 10     TABLETS   10 X 10
#
#                     MARKETING CATEGORY            APPROVED INDICATION  \
# 1683  PRESCRIPTION ONLY MEDICINE (POM)  RELIEF OF ALLERGIC CONDITIONS
#
#             NAME OF APPLICANT  \
# 1683  SHREE ALOE PHARM CO LTD
#
#                                                     APPLICANT ADDRESS  \
# 1683  F46, NWANGENE STREET HOUSING ESTATE FEGGE ONITSHA ANAMBRA STATE
#
#       COUNTRY   NAME OF MANUFACTURER  \
# 1683  NIGERIA  IMPUSLE PHARM PVT LTD
#
# ...

# %%
marCat = {}

# %%
type(treated)
# Out:
# dict

# %%
marCat.update(dict(zip(drug.index,drug['MARKETING CATEGORY'])))

# %%
marCat[1683]
# Out:
# 'OVER THE COUNTER (OTC)'

# %%
marCat.update(dict(zip(mc.index,mc['MARKETING CATEGORY'])))

# %%
marCat[1683]
# Out:
# 'PRESCRIPTION ONLY MEDICINE (POM)'

# %%
drug['MARKETING CATEGORY'] = pd.DataFrame(marCat.items())

# %%
drug['MARKETING CATEGORY'].replace(marCat, inplace=True)

# %%
drug.iloc[1683]
# Out:
# PRODUCT NAME                                                                          SHREE MANSIFED TABLET
# NAFDAC                                                                                              B4-6719
# BRAND                                                                                        SHREE MANSIFED
# GENERICS                                                                           CHLORPHENIRAMINE MALEATE
# PRODUCT CATEGORY                                                                                 HUMAN DRUG
# PHARM CLASS                                                                                  ANTI HISTAMINE
# ROUTE OF ADMINISTRATION                                                                                ORAL
# GROUP                                                                                                  DRUG
# ACTIVE ING                                                                         CHLORPHENIRAMINE MALEATE
# ...

# %%
packsize = treated['packsize']

# %%
packsize
# Out:
#                                   PRODUCT NAME    NAFDAC         BRAND  \
# 279   SOFTHEALTH COD LIVER OIL CAPSULES 1000MG   B4-6635    SOFTHEALTH
# 731                           CETIL 250 TABLET   B4-6259     CETIL 250
# 844                        EGLOFEDIPINE TABLET   B4-6269  EGLOFEDIPINE
# 845                         ODASOL-20 CAPSULES   B4-6270     ODASOL-20
# 1057                  BEXALOL STERILE EYE DROP   B4-7090       BEXALOL
# 2368    BIRON-12 HAEMATINIC WITH VITAMIN SYRUP  A11-0666      BIRON-12
# 3039                        NOVACAN-50 TABLETS   04-7690       NOVACAN
# 3196             WOODS' PEPPERMINT EXPECTORANT   B4-9628        WOODS'
# 3780                          CELOPRO CAPSULES   B4-9895       CELOPRO
# 4861                        OMEPRAZOLE CAPSULE   C4-0135    OMEPRAZOLE
# 4862       MAYATEO DICLOFENAC POTASSIUM TABLET   C4-0136       MAYATEO
# 4863                  MAYANIL PROGUANIL TABLET   C4-0137       MAYANIL
#
# ...

# %%
mrkt = drug['MARKETING CATEGORY']

# %%
mrkt.unique()
# Out:
# array(['OVER THE COUNTER (OTC)', 'PRESCRIPTION ONLY MEDICINE (POM)'],
#       dtype=object)

# %%
null_MC = drug.loc[drug['MARKETING CATEGORY'].isnull(), :]

# %%
null_MC
# Out:
# Empty DataFrame
# Columns: [PRODUCT NAME, NAFDAC, BRAND, GENERICS, PRODUCT CATEGORY, PHARM CLASS, ROUTE OF ADMINISTRATION, GROUP, ACTIVE ING, STRENGTH, PRESENTATION, DOSAGE FORM, PACK SIZE, MARKETING CATEGORY, APPROVED INDICATION, NAME OF APPLICANT, APPLICANT ADDRESS, COUNTRY, NAME OF MANUFACTURER, MANUFACTURER ADDRESS, COUNTRY.1, APPROVAL DATE, EXPIRY DATE, date_time]
# Index: []

# %%
pksize = {}

# %%
pksize.update(dict(zip(drug.index,drug['PACK SIZE'])))

# %%
pksize[279]
# Out:
# nan

# %%
pksize.update(dict(zip(packsize.index,packsize['PACK SIZE'])))

# %%
pksize[279]
# Out:
# '2X15'

# %%
drug['PACK SIZE'] = pd.DataFrame(pksize.items())

# %%
drug['PACK SIZE'].replace(pksize,inplace=True)

# %%
drug.iloc[12]
# Out:
# PRODUCT NAME                                                           VAMA ORAL REHYDRATION SALT
# NAFDAC                                                                                    A4-2080
# BRAND                                                                                        VAMA
# GENERICS                   SODIUM CHLORIDE, POTASSIUM CHLORIDE, SODIUM CITRATE, ANHYDROUS GLUCOSE
# PRODUCT CATEGORY                                                                       HUMAN DRUG
# PHARM CLASS                                                                        ANTI-DIARRHOEA
# ROUTE OF ADMINISTRATION                                                                      ORAL
# GROUP                                                                                        DRUG
# ACTIVE ING                 SODIUM CHLORIDE, POTASSIUM CHLORIDE, SODIUM CITRATE, ANHYDROUS GLUCOSE
# STRENGTH                                                                  2.6G, 1.5G, 2.9G, 13.5G
# ...

# %%
dosage = treated['dosage-form']

# %%
list(dosage.index)
# Out:
# [293, 631, 632, 869, 870, 1744, 2474, 3780]

# %%
type(dosage)
# Out:
# pandas.core.frame.DataFrame

# %%
dosage
# Out:
#                            PRODUCT NAME   NAFDAC          BRAND  \
# 293   CHIMEXBON GENTAMICIN EYE/EAR DROP  B4-6687      CHIMEXBON
# 631               CEFUNAT 250MG TABLETS  04-5298  CEFUNAT 250MG
# 632                       JADURON TONIC  A4-3457        JADURON
# 869                       BRUXINE 50GMS  04-3514        BRUXINE
# 870              VAMI'S VITAMINS POWDER  04-8310         VAMI'S
# 1744                           GENPAYNE  B4-6775       GENPAYNE
# 2474                   SALBUTAMOL 100MG  B4-8493      UNBRANDED
# 3780                   CELOPRO CAPSULES  B4-9895        CELOPRO
#
#                                            GENERICS PRODUCT CATEGORY  \
# 293                                      GENTAMICIN       HUMAN DRUG
# 631                               CEFUROXIME AXETIL       HUMAN DRUG
# 632                 FERRIC AMMONIUM CITRATE USP ETC       HUMAN DRUG
# 869                                  OXYTETACYCLINE         VET DRUG
# ...

# %%
drug.iloc[[293, 631, 632, 869, 870, 1744, 2474, 3780]]
# Out:
#                            PRODUCT NAME   NAFDAC          BRAND  \
# 293   CHIMEXBON GENTAMICIN EYE/EAR DROP  B4-6687      CHIMEXBON
# 631               CEFUNAT 250MG TABLETS  04-5298  CEFUNAT 250MG
# 632                       JADURON TONIC  A4-3457        JADURON
# 869                       BRUXINE 50GMS  04-3514        BRUXINE
# 870              VAMI'S VITAMINS POWDER  04-8310         VAMI'S
# 1744                           GENPAYNE  B4-6775       GENPAYNE
# 2474                   SALBUTAMOL 100MG  B4-8493      UNBRANDED
# 3780                   CELOPRO CAPSULES  B4-9895        CELOPRO
#
#                                            GENERICS PRODUCT CATEGORY  \
# 293                                      GENTAMICIN       HUMAN DRUG
# 631                               CEFUROXIME AXETIL       HUMAN DRUG
# 632                 FERRIC AMMONIUM CITRATE USP ETC       HUMAN DRUG
# 869                                  OXYTETACYCLINE       HUMAN DRUG
# ...

# %%
drug.iloc[293]
# Out:
# PRODUCT NAME                                                           CHIMEXBON GENTAMICIN EYE/EAR DROP
# NAFDAC                                                                                           B4-6687
# BRAND                                                                                          CHIMEXBON
# GENERICS                                                                                      GENTAMICIN
# PRODUCT CATEGORY                                                                              HUMAN DRUG
# PHARM CLASS                                                                                  ANTIBIOTICS
# ROUTE OF ADMINISTRATION                                                                      OCULAR/OTIC
# GROUP                                                                                               DRUG
# ACTIVE ING                                                                           GENTAMICIN 0.3% W/V
# ...

# %%
dose = {}

# %%
dose.update(dict(zip(drug.index,drug['DOSAGE FORM'])))

# %%
dose[293]
# Out:
# 'DROPS'

# %%
dose.update(dict(zip(dosage.index,dosage['DOSAGE FORM'])))

# %%
dose[293]
# Out:
# 'EYE/EAR DROP'

# %%
drug['DOSAGE FORM'] = pd.DataFrame(dose.items())

# %%
drug['DOSAGE FORM'].replace(dose,inplace=True)

# %%
drug.iloc[293]
# Out:
# PRODUCT NAME                                                           CHIMEXBON GENTAMICIN EYE/EAR DROP
# NAFDAC                                                                                           B4-6687
# BRAND                                                                                          CHIMEXBON
# GENERICS                                                                                      GENTAMICIN
# PRODUCT CATEGORY                                                                              HUMAN DRUG
# PHARM CLASS                                                                                  ANTIBIOTICS
# ROUTE OF ADMINISTRATION                                                                      OCULAR/OTIC
# GROUP                                                                                               DRUG
# ACTIVE ING                                                                           GENTAMICIN 0.3% W/V
# ...

# %%
pres_tion = treated['presentation']

# %%
pres_tion
# Out:
#                               PRODUCT NAME   NAFDAC          BRAND  \
# 631                  CEFUNAT 250MG TABLETS  04-5298  CEFUNAT 250MG
# 632                          JADURON TONIC  A4-3457        JADURON
# 714                        AMCIN INJECTION  B4-6216          AMCIN
# 763                    FRAFENAC 50 CAPSULE  A4-2688    FRAFENAC 50
# 836                   CRESTOR 40MG TABLETS  A4-5405   CRESTOR 40MG
# 837                       RADOFLOX TABLETS  A4-3914       RADOFLOX
# 869                          BRUXINE 50GMS  04-3514        BRUXINE
# 870                 VAMI'S VITAMINS POWDER  04-8310         VAMI'S
# 1744                              GENPAYNE  B4-6775       GENPAYNE
# 1777  OMEPRAZOLE DELAYED-RELEASED CAPSULES  B4-9447      UNBRANDED
# 1827  EMPROFEN IBUPROFEN SOFTGELS CAPSULES  A4-9467       EMPROFEN
# 2153           MEDLEY ATORVASTATIN TABLETS  B4-8186         MEDLEY
# 3237                         CINEX TABLETS  B4-9640          CINEX
# ...

# %%
len(pres_tion)
# Out:
# 26

# %%
present = {}

# %%
present.update(dict(zip(drug.index,drug['PRESENTATION'])))

# %%
present[3817]
# Out:
# nan

# %%
present.update(dict(zip(pres_tion.index,pres_tion['PRESENTATION'])))

# %%
present[3817]
# Out:
# '1 X 4ML'

# %%
drug['PRESENTATION'] = pd.DataFrame(present.items())

# %%
drug['PRESENTATION'].replace(present,inplace=True)

# %%
drug.iloc[3817]
# Out:
# PRODUCT NAME                                                                                 SURVANTA INTRATRACHEAL
# NAFDAC                                                                                                      B4-9922
# BRAND                                                                                                      SURVANTA
# GENERICS                                                                                                  BERACTANT
# PRODUCT CATEGORY                                                                                         HUMAN DRUG
# PHARM CLASS                                                                                    PULMONARY SURFACTANT
# ROUTE OF ADMINISTRATION                                                                               INTRATRACHEAL
# GROUP                                                                                                          DRUG
# ...

# %%
strengths = treated['strength']

# %%
pd.set_option('display.max_row',None)
strengths
# Out:
#                                                             PRODUCT NAME  \
# 19                                            CHEWABLE VIT A,C,D3 TABLET
# 103                                                    NUEL YEAST TABLET
# 278                                                   GINOFORCE CAPSULES
# 281                                                   PREGNAFIT CAPSULES
# 284                                                     VERAGIN CAPSULES
# 285                                                     GINSTAR CAPSULES
# 374                                               HOME PLUS DISINFECTANT
# 483                                        MCFORIS CEFTRIAXONE SODIUM 1G
# 545                                                  RITEPRIL 10 TABLETS
# 556                                         TELMISARTAN TABLETS USP 40MG
# 560                                                      VISPRIL TABLETS
# 578                                                 TRIMETRO IV INFUSION
# ...

# %%
drug_str  = {}

# %%
drug_str.update(dict(zip(drug.index,drug['STRENGTH'])))

# %%
drug_str[483]
# Out:
# nan

# %%
drug_str.update(dict(zip(strengths.index,strengths['STRENGTH'])))

# %%
drug_str[483]
# Out:
# '1GRAM/AMPOULE'

# %%
drug['STRENGTH'] = pd.DataFrame(drug_str.items())

# %%
drug['STRENGTH'].replace(drug_str, inplace=True)

# %%
drug.to_excel('new-drug-v5.xlsx')

# %%
drugs = pd.read_excel('new-drug-v5.xlsx', index_col=0)

# %%
nullcols(drugs)
# Out:
# STRENGTH               96
# APPROVED INDICATION     1
# NAME OF APPLICANT       2
# date_time               7
# dtype: int64

# %%
null_approved = drug.loc[drug['APPROVED INDICATION'].isnull(),:]

# %%
null_approved
# Out:
#                     PRODUCT NAME   NAFDAC    BRAND     GENERICS  \
# 3172  OSWORTH PARACETAMOL TABLET  A4-4053  OSWORTH  PARACETAMOL
#
#      PRODUCT CATEGORY              PHARM CLASS ROUTE OF ADMINISTRATION GROUP  \
# 3172       HUMAN DRUG  ANALGESIC & ANTIPYRETIC                    ORAL  DRUG
#
#        ACTIVE ING STRENGTH      PRESENTATION DOSAGE FORM PACK SIZE  \
# 3172  PARACETAMOL    500MG  TABLET, 1 X 1000      TABLET  1 X 1000
#
#           MARKETING CATEGORY APPROVED INDICATION        NAME OF APPLICANT  \
# 3172  OVER THE COUNTER (OTC)                 NaN  OSWORTH NIGERIA LIMITED
#
#                                              APPLICANT ADDRESS  COUNTRY  \
# 3172  3/5, SAPARA STREET, IKEJA INDUSTRIAL ESTATE, LAGOS STATE  NIGERIA
#
#      NAME OF MANUFACTURER  \
# 3172  MAY & BAKER NIGERIA
#
#                                                                          MANUFACTURER ADDRESS  \
# ...
